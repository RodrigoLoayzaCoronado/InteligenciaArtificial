# %%
import gymnasium as gym
import numpy as np

# %% [markdown]
# `nv = gym.make('Taxi-v3', render_mode='ansi')`:
#
# - `gym.make('Taxi-v3')`: Esta función crea una instancia del entorno **Taxi-v3**, que es un entorno de aprendizaje por refuerzo en el que el agente controla un taxi que debe recoger y dejar a un pasajero en una cuadrícula.
#
# - `render_mode='ansi'`: Este argumento indica que el entorno debe renderizarse en **modo texto** (ANSI) en lugar de gráficos visuales. En este caso, la salida se muestra como texto, que puedes imprimir en la consola para ver el estado del entorno sin necesidad de una interfaz gráfica.

# %%
env = gym.make('Taxi-v3', render_mode='ansi')
env
# Out:
# <TimeLimit<OrderEnforcing<PassiveEnvChecker<TaxiEnv<Taxi-v3>>>>>

# %% [markdown]
# - `episodes = 500`: Cada episodio representa una secuencia de pasos donde el agente intenta completar su tarea.
#
# - `alpha = 0.618`: Establece la **tasa de aprendizaje**. Este parámetro controla cuánto impacto tiene una nueva información sobre el valor Q existente. Un valor más alto hace que el agente aprenda más rápido de las recompensas recientes.
#
# - `Q = np.zeros([env.observation_space.n, env.action_space.n])`:
#   - Crea una **tabla Q inicializada en ceros**, de tamaño `[número de estados, número de acciones]`.
#   - `env.observation_space.n` da el **número de posibles estados** en el entorno, y `env.action_space.n` proporciona el **número de acciones posibles**.
#   - Esta tabla Q almacenará las **estimaciones de recompensa esperada** para cada combinación de estado y acción.
#
# - `rewards_per_episode = []`: Inicializa una **lista vacía** para registrar la **recompensa total** obtenida en cada episodio. Esto permite hacer un seguimiento del desempeño del agente a lo largo del tiempo.

# %%
# Inicialización del entorno y parámetros
episodes = 500  # Número total de episodios de entrenamiento
alpha = 0.618  # Tasa de aprendizaje
Q = np.zeros([env.observation_space.n, env.action_space.n])  # Tabla Q inicializada en ceros
# Lista para almacenar las recompensas totales por episodio
rewards_per_episode = []

# %% [markdown]
# INTEGRANTES
# - Pinto Barrón Oswaldo Dennis
# - Alvarez Alain Jonathan
# - Limon Carballo Aldrin
# - Salinas Doria Medina Valentina
# - Loaiza Coronado Rodrigo Jairo

# %% [markdown]
# # AGENTE GREEDY
#
# **Agente greedy** porque, en cada paso, el agente elige la acción con el valor Q más alto en el estado actual. Esto significa que siempre selecciona la mejor acción conocida según su tabla Q, sin explorar otras opciones. Este comportamiento se describe como "greedy" porque el agente prioriza la **explotación de acciones que ya parecen óptimas**, sin realizar exploración adicional.
#
# ### Explicación de cada línea del código:
#
# - `for episode in range(1, episodes + 1)`: Inicia el **bucle de entrenamiento**, repitiendo el proceso para cada episodio.
#
# - `done = False, truncated = False`: Inicializa las variables `done` y `truncated` para controlar si el episodio ha terminado.
#
# - `G, reward = 0, 0`: Inicializa `G` (recompensa total del episodio) y `reward` en 0.
#
# - `state, _ = env.reset()`: Reinicia el entorno y obtiene el **estado inicial** para el nuevo episodio.
#
# - `pasos = 0`: Inicializa el contador de **pasos del episodio actual** en 0.
#
# ### Bucle de Pasos en el Episodio
# - `while reward != 20 and not truncated`: Ejecuta el bucle de pasos hasta que se obtenga una **recompensa de 20** (indicando el objetivo completado) o el episodio sea truncado.
#
# - `action = np.argmax(Q[state])`: Selecciona la **acción con el valor Q más alto** en el estado actual, lo que implementa una **política greedy** (sin exploración).
#
# - `state2, reward, done, truncated, info = env.step(action)`: Ejecuta la acción en el entorno y obtiene:
#
#   - `state2`: Nuevo **estado** después de realizar la acción.
#   - `reward`: **Recompensa** obtenida por realizar la acción.
#   - `done`: Indica si se ha **completado el episodio**.
#   - `truncated`: Indica si el **episodio fue truncado** por alguna razón (límite de tiempo, etc.).
#
# - `Q[state, action] += alpha * (reward + np.max(Q[state2]) - Q[state, action])`: Actualiza el valor Q para el **par estado-acción**:
#
#   - Calcula el **valor Q nuevo** usando la recompensa obtenida y el valor Q del mejor estado siguiente (`np.max(Q[state2])`).
#   - La tasa de aprendizaje `alpha` controla cuánto afecta esta actualización a `Q[state, action]`.
#
# - `G += reward`: Acumula la **recompensa obtenida** en `G` para el total del episodio.
#
# - `state = state2`: Actualiza `state` al nuevo estado (`state2`) para el próximo paso.
#
# - `pasos += 1`: Incrementa el **contador de pasos**.
#
# ### Después del Bucle de Pasos
# - `rewards_per_episode.append(G)`: Guarda la **recompensa total obtenida en el episodio** (`G`) en la lista `rewards_per_episode`.
#
# - `if episode % 100 == 0: print(f"Recompensa total en el episodio {episode}: {G}")`: Imprime la **recompensa total** cada 100 episodios para monitorear el progreso del agente.

# %%
for episode in range(1, episodes + 1):
    done = False
    truncated = False
    G, reward = 0, 0
    state, _ = env.reset()
    pasos = 0
    # Bucle de pasos para el episodio actual
    while reward != 20 and not truncated:
        # Elige la acción con el valor Q más alto (política greedy)
        action = np.argmax(Q[state])
        
        # Ejecuta la acción en el entorno y observa el nuevo estado y recompensa
        state2, reward, done, truncated, info = env.step(action)
        
        # Actualiza el valor Q usando la fórmula de Q-learning (sin exploración)
        Q[state, action] += alpha * (reward + np.max(Q[state2]) - Q[state, action])
        
        # Acumula la recompensa y actualiza el estado actual
        G += reward
        state = state2
        pasos += 1
    # Almacenar la recompensa total del episodio
    rewards_per_episode.append(G)
    # Imprimir la recompensa total en episodios específicos (100, 200, 300, etc.)
    if episode % 100 == 0:
        print(f"Recompensa total en el episodio {episode}: {G}")
# Out:
# Recompensa total en el episodio 100: -35
# Recompensa total en el episodio 200: 7
# Recompensa total en el episodio 300: -17
# Recompensa total en el episodio 400: 8
# Recompensa total en el episodio 500: 7

# %% [markdown]
# ### Conclusión del Comportamiento del Agente Greedy
#
# El **agente greedy** ha logrado mejorar su desempeño inicial a lo largo del tiempo, pero podría estar **atrapado en una solución subóptima**. Al seleccionar siempre la acción con el mayor valor Q en cada estado, el agente no explora nuevas posibilidades y se enfoca en explotar la mejor estrategia que ha aprendido. Esto puede llevar a que no encuentre la **estrategia óptima** si su política inicial tenía algunos valores de Q incorrectos.
#
# La **estabilización alrededor de cero** indica que el agente ha aprendido a completar el objetivo de manera más eficiente, aunque con algunos episodios en los que acumula ligeras penalizaciones, probablemente debido a **pequeñas variaciones en el entorno** o **decisiones subóptimas** en ciertos estados.

# %%
import matplotlib.pyplot as plt
# Graficar las recompensas acumuladas por episodio
plt.plot(rewards_per_episode)
plt.xlabel('Episodios')
plt.ylabel('Recompensa total')
plt.title('Recompensas Totales por Episodio')
plt.show()

# %%
print(pasos)
print(reward)
# Out:
# 14
# 20

# %%
def decode_taxi_state(state):
    # Obtener el destino usando el módulo 4
    destination = state % 4
    state //= 4
    
    # Obtener la ubicación del pasajero usando el módulo 5
    passenger_location = state % 5
    state //= 5
    
    # Obtener la columna del taxi usando el módulo 5
    taxi_col = state % 5
    state //= 5
    
    # El valor restante es la fila del taxi
    taxi_row = state
    
    return {
        "taxi_row": taxi_row,
        "taxi_col": taxi_col,
        "passenger_location": passenger_location,
        "destination": destination
    }

# %%
listaEstados = []
done = False
truncated = False
G, reward = 0,0
state, _ = env.reset()
firstState = state
pasos = 0
listaEstados.append(state)
print("First State: ", firstState)
while reward != 20 and truncated != True:
        action = np.argmax(Q[state]) #1
        state2, reward, done, truncated, info = env.step(action) #2
        pasos += 1
        # Q[state,action] += alpha * (reward + np.max(Q[state2]) - Q[state,action]) #3
        print('State: ', state)
        print('pasos: ', pasos)
        G += reward
        state = state2  
        listaEstados.append(state)
# Out:
# First State:  93
# State:  93
# pasos:  1
# State:  93
# pasos:  2
# State:  93
# pasos:  3
# State:  93
# pasos:  4
# State:  93
# pasos:  5
# State:  93
# pasos:  6
# State:  93
# pasos:  7
# State:  93
# pasos:  8
# State:  93
# pasos:  9
# State:  93
# pasos:  10
# State:  93
# pasos:  11
# State:  93
# pasos:  12
# State:  93
# pasos:  13
# State:  93
# pasos:  14
# State:  93
# pasos:  15
# State:  93
# pasos:  16
# State:  93
# pasos:  17
# State:  93
# pasos:  18
# State:  93
# pasos:  19
# State:  93
# pasos:  20
# State:  93
# pasos:  21
# State:  93
# pasos:  22
# State:  93
# pasos:  23
# State:  93
# pasos:  24
# State:  93
# pasos:  25
# State:  93
# pasos:  26
# State:  93
# pasos:  27
# State:  93
# pasos:  28
# State:  93
# pasos:  29
# State:  93
# pasos:  30
# State:  93
# pasos:  31
# State:  93
# pasos:  32
# State:  93
# pasos:  33
# State:  93
# pasos:  34
# State:  93
# pasos:  35
# State:  93
# pasos:  36
# State:  93
# pasos:  37
# State:  93
# pasos:  38
# State:  93
# pasos:  39
# State:  93
# pasos:  40
# State:  93
# pasos:  41
# State:  93
# pasos:  42
# State:  93
# pasos:  43
# State:  93
# pasos:  44
# State:  93
# pasos:  45
# State:  93
# pasos:  46
# State:  93
# pasos:  47
# State:  93
# pasos:  48
# State:  93
# pasos:  49
# State:  93
# pasos:  50
# State:  93
# pasos:  51
# State:  93
# pasos:  52
# State:  93
# pasos:  53
# State:  93
# pasos:  54
# State:  93
# pasos:  55
# State:  93
# pasos:  56
# State:  93
# pasos:  57
# State:  93
# pasos:  58
# State:  93
# pasos:  59
# State:  93
# pasos:  60
# State:  93
# pasos:  61
# State:  93
# pasos:  62
# State:  93
# pasos:  63
# State:  93
# pasos:  64
# State:  93
# pasos:  65
# State:  93
# pasos:  66
# State:  93
# pasos:  67
# State:  93
# pasos:  68
# State:  93
# pasos:  69
# State:  93
# pasos:  70
# State:  93
# pasos:  71
# State:  93
# pasos:  72
# State:  93
# pasos:  73
# State:  93
# pasos:  74
# State:  93
# pasos:  75
# State:  93
# pasos:  76
# State:  93
# pasos:  77
# State:  93
# pasos:  78
# State:  93
# pasos:  79
# State:  93
# pasos:  80
# State:  93
# pasos:  81
# State:  93
# pasos:  82
# State:  93
# pasos:  83
# State:  93
# pasos:  84
# State:  93
# pasos:  85
# State:  93
# pasos:  86
# State:  93
# pasos:  87
# State:  93
# pasos:  88
# State:  93
# pasos:  89
# State:  93
# pasos:  90
# State:  93
# pasos:  91
# State:  93
# pasos:  92
# State:  93
# pasos:  93
# State:  93
# pasos:  94
# State:  93
# pasos:  95
# State:  93
# pasos:  96
# State:  93
# pasos:  97
# State:  93
# pasos:  98
# State:  93
# pasos:  99
# State:  93
# pasos:  100
# State:  93
# pasos:  101
# State:  93
# pasos:  102
# State:  93
# pasos:  103
# State:  93
# pasos:  104
# State:  93
# pasos:  105
# State:  93
# pasos:  106
# State:  93
# pasos:  107
# State:  93
# pasos:  108
# State:  93
# pasos:  109
# State:  93
# pasos:  110
# State:  93
# pasos:  111
# State:  93
# pasos:  112
# State:  93
# pasos:  113
# State:  93
# pasos:  114
# State:  93
# pasos:  115
# State:  93
# pasos:  116
# State:  93
# pasos:  117
# State:  93
# pasos:  118
# State:  93
# pasos:  119
# State:  93
# pasos:  120
# State:  93
# pasos:  121
# State:  93
# pasos:  122
# State:  93
# pasos:  123
# State:  93
# pasos:  124
# State:  93
# pasos:  125
# State:  93
# pasos:  126
# State:  93
# pasos:  127
# State:  93
# pasos:  128
# State:  93
# pasos:  129
# State:  93
# pasos:  130
# State:  93
# pasos:  131
# State:  93
# pasos:  132
# State:  93
# pasos:  133
# State:  93
# pasos:  134
# State:  93
# pasos:  135
# State:  93
# pasos:  136
# State:  93
# pasos:  137
# State:  93
# pasos:  138
# State:  93
# pasos:  139
# State:  93
# pasos:  140
# State:  93
# pasos:  141
# State:  93
# pasos:  142
# State:  93
# pasos:  143
# State:  93
# pasos:  144
# State:  93
# pasos:  145
# State:  93
# pasos:  146
# State:  93
# pasos:  147
# State:  93
# pasos:  148
# State:  93
# pasos:  149
# State:  93
# pasos:  150
# State:  93
# pasos:  151
# State:  93
# pasos:  152
# State:  93
# pasos:  153
# State:  93
# pasos:  154
# State:  93
# pasos:  155
# State:  93
# pasos:  156
# State:  93
# pasos:  157
# State:  93
# pasos:  158
# State:  93
# pasos:  159
# State:  93
# pasos:  160
# State:  93
# pasos:  161
# State:  93
# pasos:  162
# State:  93
# pasos:  163
# State:  93
# pasos:  164
# State:  93
# pasos:  165
# State:  93
# pasos:  166
# State:  93
# pasos:  167
# State:  93
# pasos:  168
# State:  93
# pasos:  169
# State:  93
# pasos:  170
# State:  93
# pasos:  171
# State:  93
# pasos:  172
# State:  93
# pasos:  173
# State:  93
# pasos:  174
# State:  93
# pasos:  175
# State:  93
# pasos:  176
# State:  93
# pasos:  177
# State:  93
# pasos:  178
# State:  93
# pasos:  179
# State:  93
# pasos:  180
# State:  93
# pasos:  181
# State:  93
# pasos:  182
# State:  93
# pasos:  183
# State:  93
# pasos:  184
# State:  93
# pasos:  185
# State:  93
# pasos:  186
# State:  93
# pasos:  187
# State:  93
# pasos:  188
# State:  93
# pasos:  189
# State:  93
# pasos:  190
# State:  93
# pasos:  191
# State:  93
# pasos:  192
# State:  93
# pasos:  193
# State:  93
# pasos:  194
# State:  93
# pasos:  195
# State:  93
# pasos:  196
# State:  93
# pasos:  197
# State:  93
# pasos:  198
# State:  93
# pasos:  199
# State:  93
# pasos:  200

# %%
for estado in listaEstados:
    env.reset()
    env.unwrapped.s = estado
    decoded_state = decode_taxi_state(estado)
    print(decoded_state)  
    print(env.render())
# Out:
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 3, 'destination': 1}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# # EPSILON GREEDY
# - `episodes = 500`: Define el **número total de episodios** en el entrenamiento, lo cual determina cuántas veces el agente intentará completar la tarea en el entorno.
#
# - `alpha = 0.618`: Establece la **tasa de aprendizaje**. Este parámetro controla cuánto afecta una nueva información (recompensa obtenida y valor futuro esperado) al valor Q actual. Un valor más alto permite que el agente **aprenda más rápidamente** de las recompensas recientes.
#
# - `epsilon = 1.0`: Inicializa el valor de **epsilon**, que representa la **probabilidad de exploración** (seleccionar una acción aleatoria) en lugar de explotación (elegir la acción con el mayor valor Q conocido). Un epsilon alto al inicio fomenta la **exploración**.
#
# - `epsilon_decay = 0.995`: Define el **factor de decaimiento de epsilon**. Después de cada episodio, epsilon se multiplica por este valor, **reduciendo gradualmente la probabilidad de exploración**. Esto permite que el agente explore al inicio y, con el tiempo, se concentre en explotar las mejores acciones conocidas.
#
# - `min_epsilon = 0.01`: Especifica el **valor mínimo de epsilon**. Esto garantiza que el agente no deje de explorar por completo. Incluso después de mucho entrenamiento, siempre existe una pequeña probabilidad de que explore, lo cual puede ser útil para **evitar soluciones subóptimas**.
#
# - `Q = np.zeros([env.observation_space.n, env.action_space.n])`: Inicializa la **tabla Q con ceros**, donde:
#
#   - `env.observation_space.n` representa el **número de estados** en el entorno.
#   - `env.action_space.n` representa el **número de acciones** posibles en cada estado.
#
#   Esta tabla se usa para almacenar el **valor Q estimado** de cada par estado-acción, lo que ayuda al agente a decidir la **acción óptima**.

# %%
episodes = 1000  # Número total de episodios de entrenamiento
alpha = 0.618  # Tasa de aprendizaje
epsilon = 1.0  # Valor inicial de epsilon para exploración
epsilon_decay = 0.995  # Factor de decaimiento de epsilon
min_epsilon = 0.01  # Valor mínimo de epsilon
Q = np.zeros([env.observation_space.n, env.action_space.n])  # Tabla Q inicializada en ceros

# %% [markdown]
# ### Bucle de Entrenamiento
#
# - `for episode in range(1, episodes + 1)`: Inicia el **bucle de entrenamiento**, ejecutando el proceso de aprendizaje para cada episodio hasta completar el número total (`episodes`).
#
# - `done = False, truncated = False`: Inicializa los **indicadores de finalización** (`done`) y **truncamiento** (`truncated`) del episodio en `False`. Estos se actualizarán cuando el episodio termine.
#
# - `G, reward = 0, 0`: Inicializa `G` (la **recompensa acumulada** del episodio) y `reward` (la **recompensa de cada paso**) en 0.
#
# - `state, _ = env.reset()`: Reinicia el entorno y obtiene el **estado inicial** del episodio.
#
# - `pasos = 0`: Inicializa el **contador de pasos** en 0 para llevar el registro de cuántos movimientos hace el agente en el episodio actual.
#
# ### Bucle de Pasos en el Episodio
#
# - `while reward != 20 and not truncated`: Ejecuta el bucle de pasos hasta que se alcance una **recompensa de 20** (indicando éxito) o el episodio sea **truncado**.
#
# - `if np.random.rand() < epsilon`: Aquí se decide si el agente **explorará o explotará**:
#   - Si el valor aleatorio generado es menor que `epsilon`, el agente explora seleccionando una acción aleatoria.
#
#   - `action = env.action_space.sample()`: Cuando explora, el agente selecciona una **acción al azar** usando `env.action_space.sample()`.
#
# - `else: action = np.argmax(Q[state])`: Si el valor aleatorio es mayor que `epsilon`, el agente **explota** eligiendo la **acción con el valor Q más alto** en el estado actual (`np.argmax(Q[state])`), siguiendo su política actual.
#
# - `state2, reward, done, truncated, info = env.step(action)`: Ejecuta la acción seleccionada y obtiene:
#   - `state2`: El **nuevo estado** tras la acción.
#   - `reward`: La **recompensa obtenida**.
#   - `done`: Indica si el **objetivo ha sido alcanzado**.
#   - `truncated`: Indica si el episodio fue **truncado** por otras razones.
#   - `info`: Información adicional del entorno (no se usa aquí).
#
# - `reward = reward + 1`: Suma 1 a la recompensa para el paso actual.
#
# - `Q[state, action] += alpha * (reward + np.max(Q[state2]) - Q[state, action])`: Actualiza el **valor Q** para el par estado-acción:
#   - La actualización se basa en la **fórmula de Q-learning**, utilizando la recompensa obtenida (`reward`) y el valor Q máximo en el estado siguiente (`np.max(Q[state2])`).
#   - `alpha` controla cuánto afecta esta actualización al valor Q actual.
#
# - `G += reward`: Acumula la **recompensa obtenida** en `G` para el total del episodio.
#
# - `state = state2`: Actualiza `state` al **nuevo estado** (`state2`) para el próximo paso.
#
# - `pasos += 1`: Incrementa el **contador de pasos** en 1.
#
# ### Finalización del Episodio
#
# - `rewards_per_episode.append(G)`: Al final del episodio, añade la **recompensa total acumulada** (`G`) a la lista `rewards_per_episode`.
#
# - `epsilon = max(min_epsilon, epsilon * epsilon_decay)`: Reduce `epsilon` de forma gradual, multiplicándolo por `epsilon_decay`. Esto disminuye la **probabilidad de exploración** a lo largo del tiempo. El valor se mantiene por encima de `min_epsilon` para asegurar que siempre haya una pequeña probabilidad de explorar.

# %%
# Lista para almacenar las recompensas totales por episodio
rewards_per_episode = []

for episode in range(1, episodes + 1):
    done = False
    truncated = False
    G, reward = 0, 0
    state, _ = env.reset()
    pasos = 0

    # Bucle de pasos para el episodio actual
    while reward != 20 and not truncated:
        # Decisión epsilon-greedy: exploración o explotación
        if np.random.rand() < epsilon:
            action = env.action_space.sample()  # Exploración: elige una acción aleatoria
        else:
            action = np.argmax(Q[state])  # Explotación: elige la mejor acción conocida
        
        # Ejecuta la acción en el entorno y observa el nuevo estado y recompensa
        state2, reward, done, truncated, info = env.step(action)
        
        # Actualiza el valor Q usando la fórmula de Q-learning
        Q[state, action] += alpha * (reward + np.max(Q[state2]) - Q[state, action])
        
        # Acumula la recompensa y actualiza el estado actual
        G += reward
        state = state2
        pasos += 1

    # Almacenar la recompensa total del episodio
    rewards_per_episode.append(G)

    # Reducir epsilon gradualmente hasta un valor mínimo (epsilon decay)
    epsilon = max(min_epsilon, epsilon * epsilon_decay)

    # Imprimir la recompensa total y el valor de epsilon en cada episodio
    print(f"Episodio {episode}: Recompensa total = {G}, Epsilon = {epsilon:.4f}")
# Out:
# Episodio 1: Recompensa total = -650, Epsilon = 0.9950
# Episodio 2: Recompensa total = -614, Epsilon = 0.9900
# Episodio 3: Recompensa total = -884, Epsilon = 0.9851
# Episodio 4: Recompensa total = -794, Epsilon = 0.9801
# Episodio 5: Recompensa total = -767, Epsilon = 0.9752
# Episodio 6: Recompensa total = -776, Epsilon = 0.9704
# Episodio 7: Recompensa total = -630, Epsilon = 0.9655
# Episodio 8: Recompensa total = -785, Epsilon = 0.9607
# Episodio 9: Recompensa total = -713, Epsilon = 0.9559
# Episodio 10: Recompensa total = -767, Epsilon = 0.9511
# Episodio 11: Recompensa total = -749, Epsilon = 0.9464
# Episodio 12: Recompensa total = -731, Epsilon = 0.9416
# Episodio 13: Recompensa total = -776, Epsilon = 0.9369
# Episodio 14: Recompensa total = -794, Epsilon = 0.9322
# Episodio 15: Recompensa total = -599, Epsilon = 0.9276
# Episodio 16: Recompensa total = -758, Epsilon = 0.9229
# Episodio 17: Recompensa total = -686, Epsilon = 0.9183
# Episodio 18: Recompensa total = -767, Epsilon = 0.9137
# Episodio 19: Recompensa total = -767, Epsilon = 0.9092
# Episodio 20: Recompensa total = -740, Epsilon = 0.9046
# Episodio 21: Recompensa total = -785, Epsilon = 0.9001
# Episodio 22: Recompensa total = -785, Epsilon = 0.8956
# Episodio 23: Recompensa total = -623, Epsilon = 0.8911
# Episodio 24: Recompensa total = -695, Epsilon = 0.8867
# Episodio 25: Recompensa total = -713, Epsilon = 0.8822
# Episodio 26: Recompensa total = -659, Epsilon = 0.8778
# Episodio 27: Recompensa total = -776, Epsilon = 0.8734
# Episodio 28: Recompensa total = -713, Epsilon = 0.8691
# Episodio 29: Recompensa total = -884, Epsilon = 0.8647
# Episodio 30: Recompensa total = -686, Epsilon = 0.8604
# Episodio 31: Recompensa total = -605, Epsilon = 0.8561
# Episodio 32: Recompensa total = -812, Epsilon = 0.8518
# Episodio 33: Recompensa total = -704, Epsilon = 0.8475
# Episodio 34: Recompensa total = -686, Epsilon = 0.8433
# Episodio 35: Recompensa total = -722, Epsilon = 0.8391
# Episodio 36: Recompensa total = -650, Epsilon = 0.8349
# Episodio 37: Recompensa total = -776, Epsilon = 0.8307
# Episodio 38: Recompensa total = -650, Epsilon = 0.8266
# Episodio 39: Recompensa total = -650, Epsilon = 0.8224
# Episodio 40: Recompensa total = -668, Epsilon = 0.8183
# Episodio 41: Recompensa total = -731, Epsilon = 0.8142
# Episodio 42: Recompensa total = -776, Epsilon = 0.8102
# Episodio 43: Recompensa total = -722, Epsilon = 0.8061
# Episodio 44: Recompensa total = -722, Epsilon = 0.8021
# Episodio 45: Recompensa total = -632, Epsilon = 0.7981
# Episodio 46: Recompensa total = -758, Epsilon = 0.7941
# Episodio 47: Recompensa total = -659, Epsilon = 0.7901
# Episodio 48: Recompensa total = -677, Epsilon = 0.7862
# Episodio 49: Recompensa total = -875, Epsilon = 0.7822
# Episodio 50: Recompensa total = -740, Epsilon = 0.7783
# Episodio 51: Recompensa total = -659, Epsilon = 0.7744
# Episodio 52: Recompensa total = -632, Epsilon = 0.7705
# Episodio 53: Recompensa total = -749, Epsilon = 0.7667
# Episodio 54: Recompensa total = -614, Epsilon = 0.7629
# Episodio 55: Recompensa total = -641, Epsilon = 0.7590
# Episodio 56: Recompensa total = -686, Epsilon = 0.7553
# Episodio 57: Recompensa total = -713, Epsilon = 0.7515
# Episodio 58: Recompensa total = -585, Epsilon = 0.7477
# Episodio 59: Recompensa total = -596, Epsilon = 0.7440
# Episodio 60: Recompensa total = -713, Epsilon = 0.7403
# Episodio 61: Recompensa total = -695, Epsilon = 0.7366
# Episodio 62: Recompensa total = -587, Epsilon = 0.7329
# Episodio 63: Recompensa total = -515, Epsilon = 0.7292
# Episodio 64: Recompensa total = -632, Epsilon = 0.7256
# Episodio 65: Recompensa total = -713, Epsilon = 0.7219
# Episodio 66: Recompensa total = -467, Epsilon = 0.7183
# Episodio 67: Recompensa total = -659, Epsilon = 0.7147
# Episodio 68: Recompensa total = -560, Epsilon = 0.7112
# Episodio 69: Recompensa total = -559, Epsilon = 0.7076
# Episodio 70: Recompensa total = -540, Epsilon = 0.7041
# Episodio 71: Recompensa total = -587, Epsilon = 0.7005
# Episodio 72: Recompensa total = -479, Epsilon = 0.6970
# Episodio 73: Recompensa total = -501, Epsilon = 0.6936
# Episodio 74: Recompensa total = -668, Epsilon = 0.6901
# Episodio 75: Recompensa total = -569, Epsilon = 0.6866
# Episodio 76: Recompensa total = -614, Epsilon = 0.6832
# Episodio 77: Recompensa total = -135, Epsilon = 0.6798
# Episodio 78: Recompensa total = -587, Epsilon = 0.6764
# Episodio 79: Recompensa total = -41, Epsilon = 0.6730
# Episodio 80: Recompensa total = -82, Epsilon = 0.6696
# Episodio 81: Recompensa total = -410, Epsilon = 0.6663
# Episodio 82: Recompensa total = -474, Epsilon = 0.6630
# Episodio 83: Recompensa total = -218, Epsilon = 0.6597
# Episodio 84: Recompensa total = -410, Epsilon = 0.6564
# Episodio 85: Recompensa total = -274, Epsilon = 0.6531
# Episodio 86: Recompensa total = -581, Epsilon = 0.6498
# Episodio 87: Recompensa total = -596, Epsilon = 0.6466
# Episodio 88: Recompensa total = -650, Epsilon = 0.6433
# Episodio 89: Recompensa total = -278, Epsilon = 0.6401
# Episodio 90: Recompensa total = -650, Epsilon = 0.6369
# Episodio 91: Recompensa total = -578, Epsilon = 0.6337
# Episodio 92: Recompensa total = -440, Epsilon = 0.6306
# Episodio 93: Recompensa total = -423, Epsilon = 0.6274
# Episodio 94: Recompensa total = -458, Epsilon = 0.6243
# Episodio 95: Recompensa total = -358, Epsilon = 0.6211
# Episodio 96: Recompensa total = -522, Epsilon = 0.6180
# Episodio 97: Recompensa total = -155, Epsilon = 0.6149
# Episodio 98: Recompensa total = -587, Epsilon = 0.6119
# Episodio 99: Recompensa total = -596, Epsilon = 0.6088
# Episodio 100: Recompensa total = -542, Epsilon = 0.6058
# Episodio 101: Recompensa total = -470, Epsilon = 0.6027
# Episodio 102: Recompensa total = -279, Epsilon = 0.5997
# Episodio 103: Recompensa total = -506, Epsilon = 0.5967
# Episodio 104: Recompensa total = -484, Epsilon = 0.5937
# Episodio 105: Recompensa total = -578, Epsilon = 0.5908
# Episodio 106: Recompensa total = -478, Epsilon = 0.5878
# Episodio 107: Recompensa total = -105, Epsilon = 0.5849
# Episodio 108: Recompensa total = -4, Epsilon = 0.5820
# Episodio 109: Recompensa total = -44, Epsilon = 0.5790
# Episodio 110: Recompensa total = -632, Epsilon = 0.5762
# Episodio 111: Recompensa total = -560, Epsilon = 0.5733
# Episodio 112: Recompensa total = -454, Epsilon = 0.5704
# Episodio 113: Recompensa total = -274, Epsilon = 0.5676
# Episodio 114: Recompensa total = -223, Epsilon = 0.5647
# Episodio 115: Recompensa total = -128, Epsilon = 0.5619
# Episodio 116: Recompensa total = -452, Epsilon = 0.5591
# Episodio 117: Recompensa total = -129, Epsilon = 0.5563
# Episodio 118: Recompensa total = -677, Epsilon = 0.5535
# Episodio 119: Recompensa total = -168, Epsilon = 0.5507
# Episodio 120: Recompensa total = -37, Epsilon = 0.5480
# Episodio 121: Recompensa total = -70, Epsilon = 0.5452
# Episodio 122: Recompensa total = -551, Epsilon = 0.5425
# Episodio 123: Recompensa total = -35, Epsilon = 0.5398
# Episodio 124: Recompensa total = -27, Epsilon = 0.5371
# Episodio 125: Recompensa total = -114, Epsilon = 0.5344
# Episodio 126: Recompensa total = -18, Epsilon = 0.5318
# Episodio 127: Recompensa total = -125, Epsilon = 0.5291
# Episodio 128: Recompensa total = -36, Epsilon = 0.5264
# Episodio 129: Recompensa total = -453, Epsilon = 0.5238
# Episodio 130: Recompensa total = -551, Epsilon = 0.5212
# Episodio 131: Recompensa total = -165, Epsilon = 0.5186
# Episodio 132: Recompensa total = -413, Epsilon = 0.5160
# Episodio 133: Recompensa total = -411, Epsilon = 0.5134
# Episodio 134: Recompensa total = -100, Epsilon = 0.5108
# Episodio 135: Recompensa total = -524, Epsilon = 0.5083
# Episodio 136: Recompensa total = -211, Epsilon = 0.5058
# Episodio 137: Recompensa total = -220, Epsilon = 0.5032
# Episodio 138: Recompensa total = -112, Epsilon = 0.5007
# Episodio 139: Recompensa total = -497, Epsilon = 0.4982
# Episodio 140: Recompensa total = -148, Epsilon = 0.4957
# Episodio 141: Recompensa total = -8, Epsilon = 0.4932
# Episodio 142: Recompensa total = 1, Epsilon = 0.4908
# Episodio 143: Recompensa total = -388, Epsilon = 0.4883
# Episodio 144: Recompensa total = -228, Epsilon = 0.4859
# Episodio 145: Recompensa total = -149, Epsilon = 0.4834
# Episodio 146: Recompensa total = -378, Epsilon = 0.4810
# Episodio 147: Recompensa total = -497, Epsilon = 0.4786
# Episodio 148: Recompensa total = -238, Epsilon = 0.4762
# Episodio 149: Recompensa total = -80, Epsilon = 0.4738
# Episodio 150: Recompensa total = -283, Epsilon = 0.4715
# Episodio 151: Recompensa total = -128, Epsilon = 0.4691
# Episodio 152: Recompensa total = -20, Epsilon = 0.4668
# Episodio 153: Recompensa total = -232, Epsilon = 0.4644
# Episodio 154: Recompensa total = -443, Epsilon = 0.4621
# Episodio 155: Recompensa total = -376, Epsilon = 0.4598
# Episodio 156: Recompensa total = -25, Epsilon = 0.4575
# Episodio 157: Recompensa total = -261, Epsilon = 0.4552
# Episodio 158: Recompensa total = -461, Epsilon = 0.4529
# Episodio 159: Recompensa total = -91, Epsilon = 0.4507
# Episodio 160: Recompensa total = -208, Epsilon = 0.4484
# Episodio 161: Recompensa total = -28, Epsilon = 0.4462
# Episodio 162: Recompensa total = -298, Epsilon = 0.4440
# Episodio 163: Recompensa total = -30, Epsilon = 0.4417
# Episodio 164: Recompensa total = -158, Epsilon = 0.4395
# Episodio 165: Recompensa total = -440, Epsilon = 0.4373
# Episodio 166: Recompensa total = -96, Epsilon = 0.4351
# Episodio 167: Recompensa total = -104, Epsilon = 0.4330
# Episodio 168: Recompensa total = -116, Epsilon = 0.4308
# Episodio 169: Recompensa total = -89, Epsilon = 0.4286
# Episodio 170: Recompensa total = -175, Epsilon = 0.4265
# Episodio 171: Recompensa total = -25, Epsilon = 0.4244
# Episodio 172: Recompensa total = -19, Epsilon = 0.4223
# Episodio 173: Recompensa total = -115, Epsilon = 0.4201
# Episodio 174: Recompensa total = -195, Epsilon = 0.4180
# Episodio 175: Recompensa total = -124, Epsilon = 0.4159
# Episodio 176: Recompensa total = -25, Epsilon = 0.4139
# Episodio 177: Recompensa total = -128, Epsilon = 0.4118
# Episodio 178: Recompensa total = -13, Epsilon = 0.4097
# Episodio 179: Recompensa total = -130, Epsilon = 0.4077
# Episodio 180: Recompensa total = -106, Epsilon = 0.4057
# Episodio 181: Recompensa total = -33, Epsilon = 0.4036
# Episodio 182: Recompensa total = 1, Epsilon = 0.4016
# Episodio 183: Recompensa total = -114, Epsilon = 0.3996
# Episodio 184: Recompensa total = -469, Epsilon = 0.3976
# Episodio 185: Recompensa total = -28, Epsilon = 0.3956
# Episodio 186: Recompensa total = -116, Epsilon = 0.3936
# Episodio 187: Recompensa total = -219, Epsilon = 0.3917
# Episodio 188: Recompensa total = 8, Epsilon = 0.3897
# Episodio 189: Recompensa total = -310, Epsilon = 0.3878
# Episodio 190: Recompensa total = -122, Epsilon = 0.3858
# Episodio 191: Recompensa total = -79, Epsilon = 0.3839
# Episodio 192: Recompensa total = -12, Epsilon = 0.3820
# Episodio 193: Recompensa total = -488, Epsilon = 0.3801
# Episodio 194: Recompensa total = -195, Epsilon = 0.3782
# Episodio 195: Recompensa total = -8, Epsilon = 0.3763
# Episodio 196: Recompensa total = -171, Epsilon = 0.3744
# Episodio 197: Recompensa total = -109, Epsilon = 0.3725
# Episodio 198: Recompensa total = -93, Epsilon = 0.3707
# Episodio 199: Recompensa total = -46, Epsilon = 0.3688
# Episodio 200: Recompensa total = -54, Epsilon = 0.3670
# Episodio 201: Recompensa total = -24, Epsilon = 0.3651
# Episodio 202: Recompensa total = -398, Epsilon = 0.3633
# Episodio 203: Recompensa total = -112, Epsilon = 0.3615
# Episodio 204: Recompensa total = -40, Epsilon = 0.3597
# Episodio 205: Recompensa total = -38, Epsilon = 0.3579
# Episodio 206: Recompensa total = -196, Epsilon = 0.3561
# Episodio 207: Recompensa total = -4, Epsilon = 0.3543
# Episodio 208: Recompensa total = -43, Epsilon = 0.3525
# Episodio 209: Recompensa total = -30, Epsilon = 0.3508
# Episodio 210: Recompensa total = -66, Epsilon = 0.3490
# Episodio 211: Recompensa total = -48, Epsilon = 0.3473
# Episodio 212: Recompensa total = -57, Epsilon = 0.3455
# Episodio 213: Recompensa total = -32, Epsilon = 0.3438
# Episodio 214: Recompensa total = 9, Epsilon = 0.3421
# Episodio 215: Recompensa total = -276, Epsilon = 0.3404
# Episodio 216: Recompensa total = -4, Epsilon = 0.3387
# Episodio 217: Recompensa total = -161, Epsilon = 0.3370
# Episodio 218: Recompensa total = -209, Epsilon = 0.3353
# Episodio 219: Recompensa total = -32, Epsilon = 0.3336
# Episodio 220: Recompensa total = 10, Epsilon = 0.3320
# Episodio 221: Recompensa total = -29, Epsilon = 0.3303
# Episodio 222: Recompensa total = -4, Epsilon = 0.3286
# Episodio 223: Recompensa total = -41, Epsilon = 0.3270
# Episodio 224: Recompensa total = -82, Epsilon = 0.3254
# Episodio 225: Recompensa total = -89, Epsilon = 0.3237
# Episodio 226: Recompensa total = -4, Epsilon = 0.3221
# Episodio 227: Recompensa total = -84, Epsilon = 0.3205
# Episodio 228: Recompensa total = -48, Epsilon = 0.3189
# Episodio 229: Recompensa total = -85, Epsilon = 0.3173
# Episodio 230: Recompensa total = 2, Epsilon = 0.3157
# Episodio 231: Recompensa total = 1, Epsilon = 0.3141
# Episodio 232: Recompensa total = -55, Epsilon = 0.3126
# Episodio 233: Recompensa total = -44, Epsilon = 0.3110
# Episodio 234: Recompensa total = -26, Epsilon = 0.3095
# Episodio 235: Recompensa total = -27, Epsilon = 0.3079
# Episodio 236: Recompensa total = 13, Epsilon = 0.3064
# Episodio 237: Recompensa total = -18, Epsilon = 0.3048
# Episodio 238: Recompensa total = 5, Epsilon = 0.3033
# Episodio 239: Recompensa total = -95, Epsilon = 0.3018
# Episodio 240: Recompensa total = -109, Epsilon = 0.3003
# Episodio 241: Recompensa total = -33, Epsilon = 0.2988
# Episodio 242: Recompensa total = -21, Epsilon = 0.2973
# Episodio 243: Recompensa total = 7, Epsilon = 0.2958
# Episodio 244: Recompensa total = -47, Epsilon = 0.2943
# Episodio 245: Recompensa total = -4, Epsilon = 0.2929
# Episodio 246: Recompensa total = -4, Epsilon = 0.2914
# Episodio 247: Recompensa total = -11, Epsilon = 0.2899
# Episodio 248: Recompensa total = -66, Epsilon = 0.2885
# Episodio 249: Recompensa total = -32, Epsilon = 0.2870
# Episodio 250: Recompensa total = -51, Epsilon = 0.2856
# Episodio 251: Recompensa total = -73, Epsilon = 0.2842
# Episodio 252: Recompensa total = -53, Epsilon = 0.2828
# Episodio 253: Recompensa total = -4, Epsilon = 0.2813
# Episodio 254: Recompensa total = -103, Epsilon = 0.2799
# Episodio 255: Recompensa total = -58, Epsilon = 0.2785
# Episodio 256: Recompensa total = -18, Epsilon = 0.2771
# Episodio 257: Recompensa total = -99, Epsilon = 0.2758
# Episodio 258: Recompensa total = 4, Epsilon = 0.2744
# Episodio 259: Recompensa total = -31, Epsilon = 0.2730
# Episodio 260: Recompensa total = 5, Epsilon = 0.2716
# Episodio 261: Recompensa total = -79, Epsilon = 0.2703
# Episodio 262: Recompensa total = -183, Epsilon = 0.2689
# Episodio 263: Recompensa total = -1, Epsilon = 0.2676
# Episodio 264: Recompensa total = -22, Epsilon = 0.2663
# Episodio 265: Recompensa total = -29, Epsilon = 0.2649
# Episodio 266: Recompensa total = -10, Epsilon = 0.2636
# Episodio 267: Recompensa total = 11, Epsilon = 0.2623
# Episodio 268: Recompensa total = -28, Epsilon = 0.2610
# Episodio 269: Recompensa total = -46, Epsilon = 0.2597
# Episodio 270: Recompensa total = -9, Epsilon = 0.2584
# Episodio 271: Recompensa total = -22, Epsilon = 0.2571
# Episodio 272: Recompensa total = -3, Epsilon = 0.2558
# Episodio 273: Recompensa total = -45, Epsilon = 0.2545
# Episodio 274: Recompensa total = -88, Epsilon = 0.2532
# Episodio 275: Recompensa total = -31, Epsilon = 0.2520
# Episodio 276: Recompensa total = -50, Epsilon = 0.2507
# Episodio 277: Recompensa total = -107, Epsilon = 0.2495
# Episodio 278: Recompensa total = -12, Epsilon = 0.2482
# Episodio 279: Recompensa total = -17, Epsilon = 0.2470
# Episodio 280: Recompensa total = -8, Epsilon = 0.2457
# Episodio 281: Recompensa total = -23, Epsilon = 0.2445
# Episodio 282: Recompensa total = 11, Epsilon = 0.2433
# Episodio 283: Recompensa total = -1, Epsilon = 0.2421
# Episodio 284: Recompensa total = -21, Epsilon = 0.2409
# Episodio 285: Recompensa total = -9, Epsilon = 0.2397
# Episodio 286: Recompensa total = -9, Epsilon = 0.2385
# Episodio 287: Recompensa total = -18, Epsilon = 0.2373
# Episodio 288: Recompensa total = -10, Epsilon = 0.2361
# Episodio 289: Recompensa total = 11, Epsilon = 0.2349
# Episodio 290: Recompensa total = 1, Epsilon = 0.2337
# Episodio 291: Recompensa total = -32, Epsilon = 0.2326
# Episodio 292: Recompensa total = -3, Epsilon = 0.2314
# Episodio 293: Recompensa total = 9, Epsilon = 0.2302
# Episodio 294: Recompensa total = 3, Epsilon = 0.2291
# Episodio 295: Recompensa total = -9, Epsilon = 0.2279
# Episodio 296: Recompensa total = -44, Epsilon = 0.2268
# Episodio 297: Recompensa total = -13, Epsilon = 0.2257
# Episodio 298: Recompensa total = 11, Epsilon = 0.2245
# Episodio 299: Recompensa total = -27, Epsilon = 0.2234
# Episodio 300: Recompensa total = -8, Epsilon = 0.2223
# Episodio 301: Recompensa total = 8, Epsilon = 0.2212
# Episodio 302: Recompensa total = -16, Epsilon = 0.2201
# Episodio 303: Recompensa total = 0, Epsilon = 0.2190
# Episodio 304: Recompensa total = 12, Epsilon = 0.2179
# Episodio 305: Recompensa total = -32, Epsilon = 0.2168
# Episodio 306: Recompensa total = -10, Epsilon = 0.2157
# Episodio 307: Recompensa total = -2, Epsilon = 0.2146
# Episodio 308: Recompensa total = 9, Epsilon = 0.2136
# Episodio 309: Recompensa total = 4, Epsilon = 0.2125
# Episodio 310: Recompensa total = -1, Epsilon = 0.2114
# Episodio 311: Recompensa total = -1, Epsilon = 0.2104
# Episodio 312: Recompensa total = -23, Epsilon = 0.2093
# Episodio 313: Recompensa total = -44, Epsilon = 0.2083
# Episodio 314: Recompensa total = -41, Epsilon = 0.2072
# Episodio 315: Recompensa total = -4, Epsilon = 0.2062
# Episodio 316: Recompensa total = 10, Epsilon = 0.2052
# Episodio 317: Recompensa total = 7, Epsilon = 0.2041
# Episodio 318: Recompensa total = -14, Epsilon = 0.2031
# Episodio 319: Recompensa total = 4, Epsilon = 0.2021
# Episodio 320: Recompensa total = -30, Epsilon = 0.2011
# Episodio 321: Recompensa total = 4, Epsilon = 0.2001
# Episodio 322: Recompensa total = -103, Epsilon = 0.1991
# Episodio 323: Recompensa total = -8, Epsilon = 0.1981
# Episodio 324: Recompensa total = -39, Epsilon = 0.1971
# Episodio 325: Recompensa total = 2, Epsilon = 0.1961
# Episodio 326: Recompensa total = -32, Epsilon = 0.1951
# Episodio 327: Recompensa total = 8, Epsilon = 0.1942
# Episodio 328: Recompensa total = 2, Epsilon = 0.1932
# Episodio 329: Recompensa total = -17, Epsilon = 0.1922
# Episodio 330: Recompensa total = -14, Epsilon = 0.1913
# Episodio 331: Recompensa total = -34, Epsilon = 0.1903
# Episodio 332: Recompensa total = -21, Epsilon = 0.1893
# Episodio 333: Recompensa total = 1, Epsilon = 0.1884
# Episodio 334: Recompensa total = -17, Epsilon = 0.1875
# Episodio 335: Recompensa total = -4, Epsilon = 0.1865
# Episodio 336: Recompensa total = -67, Epsilon = 0.1856
# Episodio 337: Recompensa total = -8, Epsilon = 0.1847
# Episodio 338: Recompensa total = -75, Epsilon = 0.1837
# Episodio 339: Recompensa total = 11, Epsilon = 0.1828
# Episodio 340: Recompensa total = 1, Epsilon = 0.1819
# Episodio 341: Recompensa total = 0, Epsilon = 0.1810
# Episodio 342: Recompensa total = 4, Epsilon = 0.1801
# Episodio 343: Recompensa total = -1, Epsilon = 0.1792
# Episodio 344: Recompensa total = -18, Epsilon = 0.1783
# Episodio 345: Recompensa total = -10, Epsilon = 0.1774
# Episodio 346: Recompensa total = 1, Epsilon = 0.1765
# Episodio 347: Recompensa total = 1, Epsilon = 0.1756
# Episodio 348: Recompensa total = -8, Epsilon = 0.1748
# Episodio 349: Recompensa total = -1, Epsilon = 0.1739
# Episodio 350: Recompensa total = -14, Epsilon = 0.1730
# Episodio 351: Recompensa total = -13, Epsilon = 0.1721
# Episodio 352: Recompensa total = -3, Epsilon = 0.1713
# Episodio 353: Recompensa total = -9, Epsilon = 0.1704
# Episodio 354: Recompensa total = -11, Epsilon = 0.1696
# Episodio 355: Recompensa total = 6, Epsilon = 0.1687
# Episodio 356: Recompensa total = -19, Epsilon = 0.1679
# Episodio 357: Recompensa total = 7, Epsilon = 0.1670
# Episodio 358: Recompensa total = 3, Epsilon = 0.1662
# Episodio 359: Recompensa total = -5, Epsilon = 0.1654
# Episodio 360: Recompensa total = 2, Epsilon = 0.1646
# Episodio 361: Recompensa total = 6, Epsilon = 0.1637
# Episodio 362: Recompensa total = 7, Epsilon = 0.1629
# Episodio 363: Recompensa total = -5, Epsilon = 0.1621
# Episodio 364: Recompensa total = 9, Epsilon = 0.1613
# Episodio 365: Recompensa total = 14, Epsilon = 0.1605
# Episodio 366: Recompensa total = -25, Epsilon = 0.1597
# Episodio 367: Recompensa total = -24, Epsilon = 0.1589
# Episodio 368: Recompensa total = -8, Epsilon = 0.1581
# Episodio 369: Recompensa total = -71, Epsilon = 0.1573
# Episodio 370: Recompensa total = -22, Epsilon = 0.1565
# Episodio 371: Recompensa total = -15, Epsilon = 0.1557
# Episodio 372: Recompensa total = 11, Epsilon = 0.1549
# Episodio 373: Recompensa total = 10, Epsilon = 0.1542
# Episodio 374: Recompensa total = -33, Epsilon = 0.1534
# Episodio 375: Recompensa total = -3, Epsilon = 0.1526
# Episodio 376: Recompensa total = 7, Epsilon = 0.1519
# Episodio 377: Recompensa total = -17, Epsilon = 0.1511
# Episodio 378: Recompensa total = -23, Epsilon = 0.1504
# Episodio 379: Recompensa total = 5, Epsilon = 0.1496
# Episodio 380: Recompensa total = -3, Epsilon = 0.1489
# Episodio 381: Recompensa total = -14, Epsilon = 0.1481
# Episodio 382: Recompensa total = -17, Epsilon = 0.1474
# Episodio 383: Recompensa total = 2, Epsilon = 0.1466
# Episodio 384: Recompensa total = 2, Epsilon = 0.1459
# Episodio 385: Recompensa total = -2, Epsilon = 0.1452
# Episodio 386: Recompensa total = 8, Epsilon = 0.1444
# Episodio 387: Recompensa total = -34, Epsilon = 0.1437
# Episodio 388: Recompensa total = -38, Epsilon = 0.1430
# Episodio 389: Recompensa total = 6, Epsilon = 0.1423
# Episodio 390: Recompensa total = -26, Epsilon = 0.1416
# Episodio 391: Recompensa total = 7, Epsilon = 0.1409
# Episodio 392: Recompensa total = 10, Epsilon = 0.1402
# Episodio 393: Recompensa total = -6, Epsilon = 0.1395
# Episodio 394: Recompensa total = -4, Epsilon = 0.1388
# Episodio 395: Recompensa total = 8, Epsilon = 0.1381
# Episodio 396: Recompensa total = -15, Epsilon = 0.1374
# Episodio 397: Recompensa total = 5, Epsilon = 0.1367
# Episodio 398: Recompensa total = -29, Epsilon = 0.1360
# Episodio 399: Recompensa total = -11, Epsilon = 0.1353
# Episodio 400: Recompensa total = 10, Epsilon = 0.1347
# Episodio 401: Recompensa total = 1, Epsilon = 0.1340
# Episodio 402: Recompensa total = -12, Epsilon = 0.1333
# Episodio 403: Recompensa total = 12, Epsilon = 0.1326
# Episodio 404: Recompensa total = -12, Epsilon = 0.1320
# Episodio 405: Recompensa total = -33, Epsilon = 0.1313
# Episodio 406: Recompensa total = 11, Epsilon = 0.1307
# Episodio 407: Recompensa total = -15, Epsilon = 0.1300
# Episodio 408: Recompensa total = -5, Epsilon = 0.1294
# Episodio 409: Recompensa total = -12, Epsilon = 0.1287
# Episodio 410: Recompensa total = -5, Epsilon = 0.1281
# Episodio 411: Recompensa total = -2, Epsilon = 0.1274
# Episodio 412: Recompensa total = -7, Epsilon = 0.1268
# Episodio 413: Recompensa total = 11, Epsilon = 0.1262
# Episodio 414: Recompensa total = 10, Epsilon = 0.1255
# Episodio 415: Recompensa total = 5, Epsilon = 0.1249
# Episodio 416: Recompensa total = -2, Epsilon = 0.1243
# Episodio 417: Recompensa total = -14, Epsilon = 0.1237
# Episodio 418: Recompensa total = -9, Epsilon = 0.1230
# Episodio 419: Recompensa total = 3, Epsilon = 0.1224
# Episodio 420: Recompensa total = -4, Epsilon = 0.1218
# Episodio 421: Recompensa total = 4, Epsilon = 0.1212
# Episodio 422: Recompensa total = -5, Epsilon = 0.1206
# Episodio 423: Recompensa total = -3, Epsilon = 0.1200
# Episodio 424: Recompensa total = 11, Epsilon = 0.1194
# Episodio 425: Recompensa total = 12, Epsilon = 0.1188
# Episodio 426: Recompensa total = -2, Epsilon = 0.1182
# Episodio 427: Recompensa total = -6, Epsilon = 0.1176
# Episodio 428: Recompensa total = 9, Epsilon = 0.1170
# Episodio 429: Recompensa total = 3, Epsilon = 0.1164
# Episodio 430: Recompensa total = 14, Epsilon = 0.1159
# Episodio 431: Recompensa total = -5, Epsilon = 0.1153
# Episodio 432: Recompensa total = -4, Epsilon = 0.1147
# Episodio 433: Recompensa total = 4, Epsilon = 0.1141
# Episodio 434: Recompensa total = -7, Epsilon = 0.1136
# Episodio 435: Recompensa total = 3, Epsilon = 0.1130
# Episodio 436: Recompensa total = 5, Epsilon = 0.1124
# Episodio 437: Recompensa total = 0, Epsilon = 0.1119
# Episodio 438: Recompensa total = -8, Epsilon = 0.1113
# Episodio 439: Recompensa total = 13, Epsilon = 0.1107
# Episodio 440: Recompensa total = 8, Epsilon = 0.1102
# Episodio 441: Recompensa total = 5, Epsilon = 0.1096
# Episodio 442: Recompensa total = 8, Epsilon = 0.1091
# Episodio 443: Recompensa total = -6, Epsilon = 0.1085
# Episodio 444: Recompensa total = 2, Epsilon = 0.1080
# Episodio 445: Recompensa total = -4, Epsilon = 0.1075
# Episodio 446: Recompensa total = -5, Epsilon = 0.1069
# Episodio 447: Recompensa total = 13, Epsilon = 0.1064
# Episodio 448: Recompensa total = 12, Epsilon = 0.1059
# Episodio 449: Recompensa total = 9, Epsilon = 0.1053
# Episodio 450: Recompensa total = -8, Epsilon = 0.1048
# Episodio 451: Recompensa total = 9, Epsilon = 0.1043
# Episodio 452: Recompensa total = -17, Epsilon = 0.1038
# Episodio 453: Recompensa total = -8, Epsilon = 0.1032
# Episodio 454: Recompensa total = 6, Epsilon = 0.1027
# Episodio 455: Recompensa total = -6, Epsilon = 0.1022
# Episodio 456: Recompensa total = -14, Epsilon = 0.1017
# Episodio 457: Recompensa total = 0, Epsilon = 0.1012
# Episodio 458: Recompensa total = -5, Epsilon = 0.1007
# Episodio 459: Recompensa total = 5, Epsilon = 0.1002
# Episodio 460: Recompensa total = 8, Epsilon = 0.0997
# Episodio 461: Recompensa total = 7, Epsilon = 0.0992
# Episodio 462: Recompensa total = -17, Epsilon = 0.0987
# Episodio 463: Recompensa total = 4, Epsilon = 0.0982
# Episodio 464: Recompensa total = 10, Epsilon = 0.0977
# Episodio 465: Recompensa total = -8, Epsilon = 0.0972
# Episodio 466: Recompensa total = 1, Epsilon = 0.0967
# Episodio 467: Recompensa total = 8, Epsilon = 0.0962
# Episodio 468: Recompensa total = -20, Epsilon = 0.0958
# Episodio 469: Recompensa total = 10, Epsilon = 0.0953
# Episodio 470: Recompensa total = 8, Epsilon = 0.0948
# Episodio 471: Recompensa total = 10, Epsilon = 0.0943
# Episodio 472: Recompensa total = 9, Epsilon = 0.0939
# Episodio 473: Recompensa total = -22, Epsilon = 0.0934
# Episodio 474: Recompensa total = 7, Epsilon = 0.0929
# Episodio 475: Recompensa total = 0, Epsilon = 0.0925
# Episodio 476: Recompensa total = 8, Epsilon = 0.0920
# Episodio 477: Recompensa total = 13, Epsilon = 0.0915
# Episodio 478: Recompensa total = 11, Epsilon = 0.0911
# Episodio 479: Recompensa total = -2, Epsilon = 0.0906
# Episodio 480: Recompensa total = -8, Epsilon = 0.0902
# Episodio 481: Recompensa total = 12, Epsilon = 0.0897
# Episodio 482: Recompensa total = -10, Epsilon = 0.0893
# Episodio 483: Recompensa total = 10, Epsilon = 0.0888
# Episodio 484: Recompensa total = -1, Epsilon = 0.0884
# Episodio 485: Recompensa total = 5, Epsilon = 0.0879
# Episodio 486: Recompensa total = -9, Epsilon = 0.0875
# Episodio 487: Recompensa total = -9, Epsilon = 0.0871
# Episodio 488: Recompensa total = 10, Epsilon = 0.0866
# Episodio 489: Recompensa total = -2, Epsilon = 0.0862
# Episodio 490: Recompensa total = 3, Epsilon = 0.0858
# Episodio 491: Recompensa total = 0, Epsilon = 0.0853
# Episodio 492: Recompensa total = 5, Epsilon = 0.0849
# Episodio 493: Recompensa total = -6, Epsilon = 0.0845
# Episodio 494: Recompensa total = 11, Epsilon = 0.0841
# Episodio 495: Recompensa total = 6, Epsilon = 0.0836
# Episodio 496: Recompensa total = 10, Epsilon = 0.0832
# Episodio 497: Recompensa total = 7, Epsilon = 0.0828
# Episodio 498: Recompensa total = 8, Epsilon = 0.0824
# Episodio 499: Recompensa total = 5, Epsilon = 0.0820
# Episodio 500: Recompensa total = 8, Epsilon = 0.0816
# Episodio 501: Recompensa total = 9, Epsilon = 0.0812
# Episodio 502: Recompensa total = 11, Epsilon = 0.0808
# Episodio 503: Recompensa total = 4, Epsilon = 0.0804
# Episodio 504: Recompensa total = 14, Epsilon = 0.0800
# Episodio 505: Recompensa total = 6, Epsilon = 0.0796
# Episodio 506: Recompensa total = 13, Epsilon = 0.0792
# Episodio 507: Recompensa total = 2, Epsilon = 0.0788
# Episodio 508: Recompensa total = -3, Epsilon = 0.0784
# Episodio 509: Recompensa total = 7, Epsilon = 0.0780
# Episodio 510: Recompensa total = 3, Epsilon = 0.0776
# Episodio 511: Recompensa total = 9, Epsilon = 0.0772
# Episodio 512: Recompensa total = 9, Epsilon = 0.0768
# Episodio 513: Recompensa total = 8, Epsilon = 0.0764
# Episodio 514: Recompensa total = 7, Epsilon = 0.0760
# Episodio 515: Recompensa total = 3, Epsilon = 0.0757
# Episodio 516: Recompensa total = 7, Epsilon = 0.0753
# Episodio 517: Recompensa total = -4, Epsilon = 0.0749
# Episodio 518: Recompensa total = 10, Epsilon = 0.0745
# Episodio 519: Recompensa total = 6, Epsilon = 0.0742
# Episodio 520: Recompensa total = -5, Epsilon = 0.0738
# Episodio 521: Recompensa total = -2, Epsilon = 0.0734
# Episodio 522: Recompensa total = 12, Epsilon = 0.0731
# Episodio 523: Recompensa total = 12, Epsilon = 0.0727
# Episodio 524: Recompensa total = 4, Epsilon = 0.0723
# Episodio 525: Recompensa total = 5, Epsilon = 0.0720
# Episodio 526: Recompensa total = 7, Epsilon = 0.0716
# Episodio 527: Recompensa total = -11, Epsilon = 0.0712
# Episodio 528: Recompensa total = 9, Epsilon = 0.0709
# Episodio 529: Recompensa total = 12, Epsilon = 0.0705
# Episodio 530: Recompensa total = -7, Epsilon = 0.0702
# Episodio 531: Recompensa total = 5, Epsilon = 0.0698
# Episodio 532: Recompensa total = 10, Epsilon = 0.0695
# Episodio 533: Recompensa total = 1, Epsilon = 0.0691
# Episodio 534: Recompensa total = 11, Epsilon = 0.0688
# Episodio 535: Recompensa total = 7, Epsilon = 0.0684
# Episodio 536: Recompensa total = 6, Epsilon = 0.0681
# Episodio 537: Recompensa total = 9, Epsilon = 0.0678
# Episodio 538: Recompensa total = -15, Epsilon = 0.0674
# Episodio 539: Recompensa total = 8, Epsilon = 0.0671
# Episodio 540: Recompensa total = 11, Epsilon = 0.0668
# Episodio 541: Recompensa total = 7, Epsilon = 0.0664
# Episodio 542: Recompensa total = 7, Epsilon = 0.0661
# Episodio 543: Recompensa total = 10, Epsilon = 0.0658
# Episodio 544: Recompensa total = 6, Epsilon = 0.0654
# Episodio 545: Recompensa total = 5, Epsilon = 0.0651
# Episodio 546: Recompensa total = 4, Epsilon = 0.0648
# Episodio 547: Recompensa total = 6, Epsilon = 0.0645
# Episodio 548: Recompensa total = 6, Epsilon = 0.0641
# Episodio 549: Recompensa total = -3, Epsilon = 0.0638
# Episodio 550: Recompensa total = 12, Epsilon = 0.0635
# Episodio 551: Recompensa total = 8, Epsilon = 0.0632
# Episodio 552: Recompensa total = 9, Epsilon = 0.0629
# Episodio 553: Recompensa total = 4, Epsilon = 0.0625
# Episodio 554: Recompensa total = 6, Epsilon = 0.0622
# Episodio 555: Recompensa total = 10, Epsilon = 0.0619
# Episodio 556: Recompensa total = -17, Epsilon = 0.0616
# Episodio 557: Recompensa total = 12, Epsilon = 0.0613
# Episodio 558: Recompensa total = 12, Epsilon = 0.0610
# Episodio 559: Recompensa total = 8, Epsilon = 0.0607
# Episodio 560: Recompensa total = 1, Epsilon = 0.0604
# Episodio 561: Recompensa total = 7, Epsilon = 0.0601
# Episodio 562: Recompensa total = 0, Epsilon = 0.0598
# Episodio 563: Recompensa total = 2, Epsilon = 0.0595
# Episodio 564: Recompensa total = 10, Epsilon = 0.0592
# Episodio 565: Recompensa total = 7, Epsilon = 0.0589
# Episodio 566: Recompensa total = 7, Epsilon = 0.0586
# Episodio 567: Recompensa total = 10, Epsilon = 0.0583
# Episodio 568: Recompensa total = 8, Epsilon = 0.0580
# Episodio 569: Recompensa total = -7, Epsilon = 0.0577
# Episodio 570: Recompensa total = 7, Epsilon = 0.0574
# Episodio 571: Recompensa total = 10, Epsilon = 0.0571
# Episodio 572: Recompensa total = 6, Epsilon = 0.0569
# Episodio 573: Recompensa total = -12, Epsilon = 0.0566
# Episodio 574: Recompensa total = 4, Epsilon = 0.0563
# Episodio 575: Recompensa total = 7, Epsilon = 0.0560
# Episodio 576: Recompensa total = -1, Epsilon = 0.0557
# Episodio 577: Recompensa total = -1, Epsilon = 0.0555
# Episodio 578: Recompensa total = 8, Epsilon = 0.0552
# Episodio 579: Recompensa total = 1, Epsilon = 0.0549
# Episodio 580: Recompensa total = 7, Epsilon = 0.0546
# Episodio 581: Recompensa total = 12, Epsilon = 0.0544
# Episodio 582: Recompensa total = 2, Epsilon = 0.0541
# Episodio 583: Recompensa total = 14, Epsilon = 0.0538
# Episodio 584: Recompensa total = 13, Epsilon = 0.0535
# Episodio 585: Recompensa total = 12, Epsilon = 0.0533
# Episodio 586: Recompensa total = -18, Epsilon = 0.0530
# Episodio 587: Recompensa total = 9, Epsilon = 0.0527
# Episodio 588: Recompensa total = -1, Epsilon = 0.0525
# Episodio 589: Recompensa total = 5, Epsilon = 0.0522
# Episodio 590: Recompensa total = -7, Epsilon = 0.0520
# Episodio 591: Recompensa total = 1, Epsilon = 0.0517
# Episodio 592: Recompensa total = 9, Epsilon = 0.0514
# Episodio 593: Recompensa total = 10, Epsilon = 0.0512
# Episodio 594: Recompensa total = 8, Epsilon = 0.0509
# Episodio 595: Recompensa total = -4, Epsilon = 0.0507
# Episodio 596: Recompensa total = -7, Epsilon = 0.0504
# Episodio 597: Recompensa total = 7, Epsilon = 0.0502
# Episodio 598: Recompensa total = 4, Epsilon = 0.0499
# Episodio 599: Recompensa total = 10, Epsilon = 0.0497
# Episodio 600: Recompensa total = 3, Epsilon = 0.0494
# Episodio 601: Recompensa total = 2, Epsilon = 0.0492
# Episodio 602: Recompensa total = 8, Epsilon = 0.0489
# Episodio 603: Recompensa total = 6, Epsilon = 0.0487
# Episodio 604: Recompensa total = 7, Epsilon = 0.0484
# Episodio 605: Recompensa total = -2, Epsilon = 0.0482
# Episodio 606: Recompensa total = 6, Epsilon = 0.0479
# Episodio 607: Recompensa total = 5, Epsilon = 0.0477
# Episodio 608: Recompensa total = 4, Epsilon = 0.0475
# Episodio 609: Recompensa total = 10, Epsilon = 0.0472
# Episodio 610: Recompensa total = -5, Epsilon = 0.0470
# Episodio 611: Recompensa total = 8, Epsilon = 0.0468
# Episodio 612: Recompensa total = 4, Epsilon = 0.0465
# Episodio 613: Recompensa total = 6, Epsilon = 0.0463
# Episodio 614: Recompensa total = 6, Epsilon = 0.0461
# Episodio 615: Recompensa total = 4, Epsilon = 0.0458
# Episodio 616: Recompensa total = 0, Epsilon = 0.0456
# Episodio 617: Recompensa total = 8, Epsilon = 0.0454
# Episodio 618: Recompensa total = 10, Epsilon = 0.0452
# Episodio 619: Recompensa total = 7, Epsilon = 0.0449
# Episodio 620: Recompensa total = -6, Epsilon = 0.0447
# Episodio 621: Recompensa total = 2, Epsilon = 0.0445
# Episodio 622: Recompensa total = -3, Epsilon = 0.0443
# Episodio 623: Recompensa total = 4, Epsilon = 0.0440
# Episodio 624: Recompensa total = -13, Epsilon = 0.0438
# Episodio 625: Recompensa total = 13, Epsilon = 0.0436
# Episodio 626: Recompensa total = -3, Epsilon = 0.0434
# Episodio 627: Recompensa total = 1, Epsilon = 0.0432
# Episodio 628: Recompensa total = 1, Epsilon = 0.0429
# Episodio 629: Recompensa total = 7, Epsilon = 0.0427
# Episodio 630: Recompensa total = 11, Epsilon = 0.0425
# Episodio 631: Recompensa total = 8, Epsilon = 0.0423
# Episodio 632: Recompensa total = 10, Epsilon = 0.0421
# Episodio 633: Recompensa total = 8, Epsilon = 0.0419
# Episodio 634: Recompensa total = -2, Epsilon = 0.0417
# Episodio 635: Recompensa total = 12, Epsilon = 0.0415
# Episodio 636: Recompensa total = 7, Epsilon = 0.0413
# Episodio 637: Recompensa total = 1, Epsilon = 0.0410
# Episodio 638: Recompensa total = 7, Epsilon = 0.0408
# Episodio 639: Recompensa total = 8, Epsilon = 0.0406
# Episodio 640: Recompensa total = 6, Epsilon = 0.0404
# Episodio 641: Recompensa total = 7, Epsilon = 0.0402
# Episodio 642: Recompensa total = 9, Epsilon = 0.0400
# Episodio 643: Recompensa total = 14, Epsilon = 0.0398
# Episodio 644: Recompensa total = 13, Epsilon = 0.0396
# Episodio 645: Recompensa total = 8, Epsilon = 0.0394
# Episodio 646: Recompensa total = -1, Epsilon = 0.0392
# Episodio 647: Recompensa total = 8, Epsilon = 0.0390
# Episodio 648: Recompensa total = 10, Epsilon = 0.0388
# Episodio 649: Recompensa total = 11, Epsilon = 0.0387
# Episodio 650: Recompensa total = 7, Epsilon = 0.0385
# Episodio 651: Recompensa total = 6, Epsilon = 0.0383
# Episodio 652: Recompensa total = -9, Epsilon = 0.0381
# Episodio 653: Recompensa total = 3, Epsilon = 0.0379
# Episodio 654: Recompensa total = 10, Epsilon = 0.0377
# Episodio 655: Recompensa total = 3, Epsilon = 0.0375
# Episodio 656: Recompensa total = 11, Epsilon = 0.0373
# Episodio 657: Recompensa total = -3, Epsilon = 0.0371
# Episodio 658: Recompensa total = 6, Epsilon = 0.0369
# Episodio 659: Recompensa total = 5, Epsilon = 0.0368
# Episodio 660: Recompensa total = -5, Epsilon = 0.0366
# Episodio 661: Recompensa total = 5, Epsilon = 0.0364
# Episodio 662: Recompensa total = 7, Epsilon = 0.0362
# Episodio 663: Recompensa total = 8, Epsilon = 0.0360
# Episodio 664: Recompensa total = 7, Epsilon = 0.0359
# Episodio 665: Recompensa total = 8, Epsilon = 0.0357
# Episodio 666: Recompensa total = 13, Epsilon = 0.0355
# Episodio 667: Recompensa total = 6, Epsilon = 0.0353
# Episodio 668: Recompensa total = 8, Epsilon = 0.0351
# Episodio 669: Recompensa total = 6, Epsilon = 0.0350
# Episodio 670: Recompensa total = 0, Epsilon = 0.0348
# Episodio 671: Recompensa total = 0, Epsilon = 0.0346
# Episodio 672: Recompensa total = 8, Epsilon = 0.0344
# Episodio 673: Recompensa total = 8, Epsilon = 0.0343
# Episodio 674: Recompensa total = 7, Epsilon = 0.0341
# Episodio 675: Recompensa total = 8, Epsilon = 0.0339
# Episodio 676: Recompensa total = 7, Epsilon = 0.0338
# Episodio 677: Recompensa total = -1, Epsilon = 0.0336
# Episodio 678: Recompensa total = 14, Epsilon = 0.0334
# Episodio 679: Recompensa total = 5, Epsilon = 0.0333
# Episodio 680: Recompensa total = 4, Epsilon = 0.0331
# Episodio 681: Recompensa total = 8, Epsilon = 0.0329
# Episodio 682: Recompensa total = 6, Epsilon = 0.0328
# Episodio 683: Recompensa total = 10, Epsilon = 0.0326
# Episodio 684: Recompensa total = -5, Epsilon = 0.0324
# Episodio 685: Recompensa total = 12, Epsilon = 0.0323
# Episodio 686: Recompensa total = 14, Epsilon = 0.0321
# Episodio 687: Recompensa total = 7, Epsilon = 0.0319
# Episodio 688: Recompensa total = 9, Epsilon = 0.0318
# Episodio 689: Recompensa total = 5, Epsilon = 0.0316
# Episodio 690: Recompensa total = 7, Epsilon = 0.0315
# Episodio 691: Recompensa total = 6, Epsilon = 0.0313
# Episodio 692: Recompensa total = 10, Epsilon = 0.0312
# Episodio 693: Recompensa total = 3, Epsilon = 0.0310
# Episodio 694: Recompensa total = 9, Epsilon = 0.0308
# Episodio 695: Recompensa total = 6, Epsilon = 0.0307
# Episodio 696: Recompensa total = -5, Epsilon = 0.0305
# Episodio 697: Recompensa total = 7, Epsilon = 0.0304
# Episodio 698: Recompensa total = 7, Epsilon = 0.0302
# Episodio 699: Recompensa total = -1, Epsilon = 0.0301
# Episodio 700: Recompensa total = 7, Epsilon = 0.0299
# Episodio 701: Recompensa total = 5, Epsilon = 0.0298
# Episodio 702: Recompensa total = 14, Epsilon = 0.0296
# Episodio 703: Recompensa total = 7, Epsilon = 0.0295
# Episodio 704: Recompensa total = 10, Epsilon = 0.0293
# Episodio 705: Recompensa total = 12, Epsilon = 0.0292
# Episodio 706: Recompensa total = 10, Epsilon = 0.0290
# Episodio 707: Recompensa total = 7, Epsilon = 0.0289
# Episodio 708: Recompensa total = 4, Epsilon = 0.0288
# Episodio 709: Recompensa total = 5, Epsilon = 0.0286
# Episodio 710: Recompensa total = 8, Epsilon = 0.0285
# Episodio 711: Recompensa total = 2, Epsilon = 0.0283
# Episodio 712: Recompensa total = 13, Epsilon = 0.0282
# Episodio 713: Recompensa total = 8, Epsilon = 0.0280
# Episodio 714: Recompensa total = 8, Epsilon = 0.0279
# Episodio 715: Recompensa total = -1, Epsilon = 0.0278
# Episodio 716: Recompensa total = 5, Epsilon = 0.0276
# Episodio 717: Recompensa total = 7, Epsilon = 0.0275
# Episodio 718: Recompensa total = 5, Epsilon = 0.0274
# Episodio 719: Recompensa total = 8, Epsilon = 0.0272
# Episodio 720: Recompensa total = 11, Epsilon = 0.0271
# Episodio 721: Recompensa total = 8, Epsilon = 0.0269
# Episodio 722: Recompensa total = -2, Epsilon = 0.0268
# Episodio 723: Recompensa total = 6, Epsilon = 0.0267
# Episodio 724: Recompensa total = 4, Epsilon = 0.0265
# Episodio 725: Recompensa total = 10, Epsilon = 0.0264
# Episodio 726: Recompensa total = 5, Epsilon = 0.0263
# Episodio 727: Recompensa total = 4, Epsilon = 0.0261
# Episodio 728: Recompensa total = 7, Epsilon = 0.0260
# Episodio 729: Recompensa total = 7, Epsilon = 0.0259
# Episodio 730: Recompensa total = 8, Epsilon = 0.0258
# Episodio 731: Recompensa total = 11, Epsilon = 0.0256
# Episodio 732: Recompensa total = 9, Epsilon = 0.0255
# Episodio 733: Recompensa total = 5, Epsilon = 0.0254
# Episodio 734: Recompensa total = 6, Epsilon = 0.0252
# Episodio 735: Recompensa total = 5, Epsilon = 0.0251
# Episodio 736: Recompensa total = 11, Epsilon = 0.0250
# Episodio 737: Recompensa total = -4, Epsilon = 0.0249
# Episodio 738: Recompensa total = 10, Epsilon = 0.0247
# Episodio 739: Recompensa total = 6, Epsilon = 0.0246
# Episodio 740: Recompensa total = 11, Epsilon = 0.0245
# Episodio 741: Recompensa total = 6, Epsilon = 0.0244
# Episodio 742: Recompensa total = 7, Epsilon = 0.0243
# Episodio 743: Recompensa total = -1, Epsilon = 0.0241
# Episodio 744: Recompensa total = 4, Epsilon = 0.0240
# Episodio 745: Recompensa total = 5, Epsilon = 0.0239
# Episodio 746: Recompensa total = 6, Epsilon = 0.0238
# Episodio 747: Recompensa total = 3, Epsilon = 0.0237
# Episodio 748: Recompensa total = 9, Epsilon = 0.0235
# Episodio 749: Recompensa total = 7, Epsilon = 0.0234
# Episodio 750: Recompensa total = 7, Epsilon = 0.0233
# Episodio 751: Recompensa total = 6, Epsilon = 0.0232
# Episodio 752: Recompensa total = 9, Epsilon = 0.0231
# Episodio 753: Recompensa total = -1, Epsilon = 0.0229
# Episodio 754: Recompensa total = 11, Epsilon = 0.0228
# Episodio 755: Recompensa total = 9, Epsilon = 0.0227
# Episodio 756: Recompensa total = 6, Epsilon = 0.0226
# Episodio 757: Recompensa total = 5, Epsilon = 0.0225
# Episodio 758: Recompensa total = 5, Epsilon = 0.0224
# Episodio 759: Recompensa total = 4, Epsilon = 0.0223
# Episodio 760: Recompensa total = 10, Epsilon = 0.0222
# Episodio 761: Recompensa total = 7, Epsilon = 0.0220
# Episodio 762: Recompensa total = 9, Epsilon = 0.0219
# Episodio 763: Recompensa total = 5, Epsilon = 0.0218
# Episodio 764: Recompensa total = 7, Epsilon = 0.0217
# Episodio 765: Recompensa total = -4, Epsilon = 0.0216
# Episodio 766: Recompensa total = 7, Epsilon = 0.0215
# Episodio 767: Recompensa total = 11, Epsilon = 0.0214
# Episodio 768: Recompensa total = 7, Epsilon = 0.0213
# Episodio 769: Recompensa total = 5, Epsilon = 0.0212
# Episodio 770: Recompensa total = 6, Epsilon = 0.0211
# Episodio 771: Recompensa total = 4, Epsilon = 0.0210
# Episodio 772: Recompensa total = 10, Epsilon = 0.0209
# Episodio 773: Recompensa total = 11, Epsilon = 0.0208
# Episodio 774: Recompensa total = 8, Epsilon = 0.0207
# Episodio 775: Recompensa total = 14, Epsilon = 0.0206
# Episodio 776: Recompensa total = 4, Epsilon = 0.0205
# Episodio 777: Recompensa total = 1, Epsilon = 0.0203
# Episodio 778: Recompensa total = 9, Epsilon = 0.0202
# Episodio 779: Recompensa total = 9, Epsilon = 0.0201
# Episodio 780: Recompensa total = 6, Epsilon = 0.0200
# Episodio 781: Recompensa total = 10, Epsilon = 0.0199
# Episodio 782: Recompensa total = 11, Epsilon = 0.0198
# Episodio 783: Recompensa total = 1, Epsilon = 0.0197
# Episodio 784: Recompensa total = 9, Epsilon = 0.0196
# Episodio 785: Recompensa total = 5, Epsilon = 0.0195
# Episodio 786: Recompensa total = 9, Epsilon = 0.0195
# Episodio 787: Recompensa total = 5, Epsilon = 0.0194
# Episodio 788: Recompensa total = 5, Epsilon = 0.0193
# Episodio 789: Recompensa total = 4, Epsilon = 0.0192
# Episodio 790: Recompensa total = 6, Epsilon = 0.0191
# Episodio 791: Recompensa total = 7, Epsilon = 0.0190
# Episodio 792: Recompensa total = 7, Epsilon = 0.0189
# Episodio 793: Recompensa total = 10, Epsilon = 0.0188
# Episodio 794: Recompensa total = 12, Epsilon = 0.0187
# Episodio 795: Recompensa total = 8, Epsilon = 0.0186
# Episodio 796: Recompensa total = 12, Epsilon = 0.0185
# Episodio 797: Recompensa total = 8, Epsilon = 0.0184
# Episodio 798: Recompensa total = 9, Epsilon = 0.0183
# Episodio 799: Recompensa total = 4, Epsilon = 0.0182
# Episodio 800: Recompensa total = 5, Epsilon = 0.0181
# Episodio 801: Recompensa total = 4, Epsilon = 0.0180
# Episodio 802: Recompensa total = 4, Epsilon = 0.0180
# Episodio 803: Recompensa total = 5, Epsilon = 0.0179
# Episodio 804: Recompensa total = 4, Epsilon = 0.0178
# Episodio 805: Recompensa total = 8, Epsilon = 0.0177
# Episodio 806: Recompensa total = 13, Epsilon = 0.0176
# Episodio 807: Recompensa total = 14, Epsilon = 0.0175
# Episodio 808: Recompensa total = 9, Epsilon = 0.0174
# Episodio 809: Recompensa total = 7, Epsilon = 0.0173
# Episodio 810: Recompensa total = 8, Epsilon = 0.0172
# Episodio 811: Recompensa total = 3, Epsilon = 0.0172
# Episodio 812: Recompensa total = 7, Epsilon = 0.0171
# Episodio 813: Recompensa total = 4, Epsilon = 0.0170
# Episodio 814: Recompensa total = 5, Epsilon = 0.0169
# Episodio 815: Recompensa total = 10, Epsilon = 0.0168
# Episodio 816: Recompensa total = 5, Epsilon = 0.0167
# Episodio 817: Recompensa total = 5, Epsilon = 0.0167
# Episodio 818: Recompensa total = 5, Epsilon = 0.0166
# Episodio 819: Recompensa total = 5, Epsilon = 0.0165
# Episodio 820: Recompensa total = 3, Epsilon = 0.0164
# Episodio 821: Recompensa total = 8, Epsilon = 0.0163
# Episodio 822: Recompensa total = 6, Epsilon = 0.0162
# Episodio 823: Recompensa total = 5, Epsilon = 0.0162
# Episodio 824: Recompensa total = 1, Epsilon = 0.0161
# Episodio 825: Recompensa total = 9, Epsilon = 0.0160
# Episodio 826: Recompensa total = 10, Epsilon = 0.0159
# Episodio 827: Recompensa total = 8, Epsilon = 0.0158
# Episodio 828: Recompensa total = 5, Epsilon = 0.0158
# Episodio 829: Recompensa total = 10, Epsilon = 0.0157
# Episodio 830: Recompensa total = 7, Epsilon = 0.0156
# Episodio 831: Recompensa total = 7, Epsilon = 0.0155
# Episodio 832: Recompensa total = 4, Epsilon = 0.0154
# Episodio 833: Recompensa total = 10, Epsilon = 0.0154
# Episodio 834: Recompensa total = 5, Epsilon = 0.0153
# Episodio 835: Recompensa total = 7, Epsilon = 0.0152
# Episodio 836: Recompensa total = 8, Epsilon = 0.0151
# Episodio 837: Recompensa total = 6, Epsilon = 0.0151
# Episodio 838: Recompensa total = 11, Epsilon = 0.0150
# Episodio 839: Recompensa total = 7, Epsilon = 0.0149
# Episodio 840: Recompensa total = 10, Epsilon = 0.0148
# Episodio 841: Recompensa total = 3, Epsilon = 0.0148
# Episodio 842: Recompensa total = -3, Epsilon = 0.0147
# Episodio 843: Recompensa total = 7, Epsilon = 0.0146
# Episodio 844: Recompensa total = 10, Epsilon = 0.0145
# Episodio 845: Recompensa total = 11, Epsilon = 0.0145
# Episodio 846: Recompensa total = 6, Epsilon = 0.0144
# Episodio 847: Recompensa total = 12, Epsilon = 0.0143
# Episodio 848: Recompensa total = 4, Epsilon = 0.0143
# Episodio 849: Recompensa total = 1, Epsilon = 0.0142
# Episodio 850: Recompensa total = 6, Epsilon = 0.0141
# Episodio 851: Recompensa total = 10, Epsilon = 0.0140
# Episodio 852: Recompensa total = 12, Epsilon = 0.0140
# Episodio 853: Recompensa total = 9, Epsilon = 0.0139
# Episodio 854: Recompensa total = 14, Epsilon = 0.0138
# Episodio 855: Recompensa total = 9, Epsilon = 0.0138
# Episodio 856: Recompensa total = 8, Epsilon = 0.0137
# Episodio 857: Recompensa total = 11, Epsilon = 0.0136
# Episodio 858: Recompensa total = 11, Epsilon = 0.0136
# Episodio 859: Recompensa total = 7, Epsilon = 0.0135
# Episodio 860: Recompensa total = 10, Epsilon = 0.0134
# Episodio 861: Recompensa total = 12, Epsilon = 0.0134
# Episodio 862: Recompensa total = 10, Epsilon = 0.0133
# Episodio 863: Recompensa total = 7, Epsilon = 0.0132
# Episodio 864: Recompensa total = 6, Epsilon = 0.0132
# Episodio 865: Recompensa total = 3, Epsilon = 0.0131
# Episodio 866: Recompensa total = 12, Epsilon = 0.0130
# Episodio 867: Recompensa total = 3, Epsilon = 0.0130
# Episodio 868: Recompensa total = 5, Epsilon = 0.0129
# Episodio 869: Recompensa total = 10, Epsilon = 0.0128
# Episodio 870: Recompensa total = 7, Epsilon = 0.0128
# Episodio 871: Recompensa total = 7, Epsilon = 0.0127
# Episodio 872: Recompensa total = 6, Epsilon = 0.0126
# Episodio 873: Recompensa total = 9, Epsilon = 0.0126
# Episodio 874: Recompensa total = 6, Epsilon = 0.0125
# Episodio 875: Recompensa total = -2, Epsilon = 0.0125
# Episodio 876: Recompensa total = 7, Epsilon = 0.0124
# Episodio 877: Recompensa total = 7, Epsilon = 0.0123
# Episodio 878: Recompensa total = 6, Epsilon = 0.0123
# Episodio 879: Recompensa total = 5, Epsilon = 0.0122
# Episodio 880: Recompensa total = 9, Epsilon = 0.0121
# Episodio 881: Recompensa total = 14, Epsilon = 0.0121
# Episodio 882: Recompensa total = 6, Epsilon = 0.0120
# Episodio 883: Recompensa total = 9, Epsilon = 0.0120
# Episodio 884: Recompensa total = 9, Epsilon = 0.0119
# Episodio 885: Recompensa total = 12, Epsilon = 0.0118
# Episodio 886: Recompensa total = -3, Epsilon = 0.0118
# Episodio 887: Recompensa total = 2, Epsilon = 0.0117
# Episodio 888: Recompensa total = 12, Epsilon = 0.0117
# Episodio 889: Recompensa total = 5, Epsilon = 0.0116
# Episodio 890: Recompensa total = 8, Epsilon = 0.0115
# Episodio 891: Recompensa total = -9, Epsilon = 0.0115
# Episodio 892: Recompensa total = 9, Epsilon = 0.0114
# Episodio 893: Recompensa total = 6, Epsilon = 0.0114
# Episodio 894: Recompensa total = 8, Epsilon = 0.0113
# Episodio 895: Recompensa total = 11, Epsilon = 0.0113
# Episodio 896: Recompensa total = 6, Epsilon = 0.0112
# Episodio 897: Recompensa total = 6, Epsilon = 0.0112
# Episodio 898: Recompensa total = 3, Epsilon = 0.0111
# Episodio 899: Recompensa total = 10, Epsilon = 0.0110
# Episodio 900: Recompensa total = 3, Epsilon = 0.0110
# Episodio 901: Recompensa total = 11, Epsilon = 0.0109
# Episodio 902: Recompensa total = 9, Epsilon = 0.0109
# Episodio 903: Recompensa total = 6, Epsilon = 0.0108
# Episodio 904: Recompensa total = 8, Epsilon = 0.0108
# Episodio 905: Recompensa total = 2, Epsilon = 0.0107
# Episodio 906: Recompensa total = 6, Epsilon = 0.0107
# Episodio 907: Recompensa total = 6, Epsilon = 0.0106
# Episodio 908: Recompensa total = 10, Epsilon = 0.0106
# Episodio 909: Recompensa total = 1, Epsilon = 0.0105
# Episodio 910: Recompensa total = 9, Epsilon = 0.0104
# Episodio 911: Recompensa total = 4, Epsilon = 0.0104
# Episodio 912: Recompensa total = 8, Epsilon = 0.0103
# Episodio 913: Recompensa total = 4, Epsilon = 0.0103
# Episodio 914: Recompensa total = 5, Epsilon = 0.0102
# Episodio 915: Recompensa total = 13, Epsilon = 0.0102
# Episodio 916: Recompensa total = 7, Epsilon = 0.0101
# Episodio 917: Recompensa total = -16, Epsilon = 0.0101
# Episodio 918: Recompensa total = 9, Epsilon = 0.0100
# Episodio 919: Recompensa total = 9, Epsilon = 0.0100
# Episodio 920: Recompensa total = 8, Epsilon = 0.0100
# Episodio 921: Recompensa total = 6, Epsilon = 0.0100
# Episodio 922: Recompensa total = 8, Epsilon = 0.0100
# Episodio 923: Recompensa total = 9, Epsilon = 0.0100
# Episodio 924: Recompensa total = 6, Epsilon = 0.0100
# Episodio 925: Recompensa total = 10, Epsilon = 0.0100
# Episodio 926: Recompensa total = 6, Epsilon = 0.0100
# Episodio 927: Recompensa total = 11, Epsilon = 0.0100
# Episodio 928: Recompensa total = 7, Epsilon = 0.0100
# Episodio 929: Recompensa total = 2, Epsilon = 0.0100
# Episodio 930: Recompensa total = 4, Epsilon = 0.0100
# Episodio 931: Recompensa total = 9, Epsilon = 0.0100
# Episodio 932: Recompensa total = 12, Epsilon = 0.0100
# Episodio 933: Recompensa total = 5, Epsilon = 0.0100
# Episodio 934: Recompensa total = 10, Epsilon = 0.0100
# Episodio 935: Recompensa total = 7, Epsilon = 0.0100
# Episodio 936: Recompensa total = 10, Epsilon = 0.0100
# Episodio 937: Recompensa total = 7, Epsilon = 0.0100
# Episodio 938: Recompensa total = 9, Epsilon = 0.0100
# Episodio 939: Recompensa total = 6, Epsilon = 0.0100
# Episodio 940: Recompensa total = 9, Epsilon = 0.0100
# Episodio 941: Recompensa total = 6, Epsilon = 0.0100
# Episodio 942: Recompensa total = 7, Epsilon = 0.0100
# Episodio 943: Recompensa total = 4, Epsilon = 0.0100
# Episodio 944: Recompensa total = 10, Epsilon = 0.0100
# Episodio 945: Recompensa total = 10, Epsilon = 0.0100
# Episodio 946: Recompensa total = 8, Epsilon = 0.0100
# Episodio 947: Recompensa total = 5, Epsilon = 0.0100
# Episodio 948: Recompensa total = 5, Epsilon = 0.0100
# Episodio 949: Recompensa total = 7, Epsilon = 0.0100
# Episodio 950: Recompensa total = 4, Epsilon = 0.0100
# Episodio 951: Recompensa total = 4, Epsilon = 0.0100
# Episodio 952: Recompensa total = 9, Epsilon = 0.0100
# Episodio 953: Recompensa total = 2, Epsilon = 0.0100
# Episodio 954: Recompensa total = 9, Epsilon = 0.0100
# Episodio 955: Recompensa total = 8, Epsilon = 0.0100
# Episodio 956: Recompensa total = 6, Epsilon = 0.0100
# Episodio 957: Recompensa total = 3, Epsilon = 0.0100
# Episodio 958: Recompensa total = 10, Epsilon = 0.0100
# Episodio 959: Recompensa total = 9, Epsilon = 0.0100
# Episodio 960: Recompensa total = 9, Epsilon = 0.0100
# Episodio 961: Recompensa total = 4, Epsilon = 0.0100
# Episodio 962: Recompensa total = 3, Epsilon = 0.0100
# Episodio 963: Recompensa total = 2, Epsilon = 0.0100
# Episodio 964: Recompensa total = 4, Epsilon = 0.0100
# Episodio 965: Recompensa total = 5, Epsilon = 0.0100
# Episodio 966: Recompensa total = 12, Epsilon = 0.0100
# Episodio 967: Recompensa total = 11, Epsilon = 0.0100
# Episodio 968: Recompensa total = 5, Epsilon = 0.0100
# Episodio 969: Recompensa total = 5, Epsilon = 0.0100
# Episodio 970: Recompensa total = 6, Epsilon = 0.0100
# Episodio 971: Recompensa total = 6, Epsilon = 0.0100
# Episodio 972: Recompensa total = 5, Epsilon = 0.0100
# Episodio 973: Recompensa total = 11, Epsilon = 0.0100
# Episodio 974: Recompensa total = 9, Epsilon = 0.0100
# Episodio 975: Recompensa total = 8, Epsilon = 0.0100
# Episodio 976: Recompensa total = 15, Epsilon = 0.0100
# Episodio 977: Recompensa total = 4, Epsilon = 0.0100
# Episodio 978: Recompensa total = 11, Epsilon = 0.0100
# Episodio 979: Recompensa total = -4, Epsilon = 0.0100
# Episodio 980: Recompensa total = 8, Epsilon = 0.0100
# Episodio 981: Recompensa total = 11, Epsilon = 0.0100
# Episodio 982: Recompensa total = 10, Epsilon = 0.0100
# Episodio 983: Recompensa total = 9, Epsilon = 0.0100
# Episodio 984: Recompensa total = 6, Epsilon = 0.0100
# Episodio 985: Recompensa total = -4, Epsilon = 0.0100
# Episodio 986: Recompensa total = 11, Epsilon = 0.0100
# Episodio 987: Recompensa total = 8, Epsilon = 0.0100
# Episodio 988: Recompensa total = 9, Epsilon = 0.0100
# Episodio 989: Recompensa total = 6, Epsilon = 0.0100
# Episodio 990: Recompensa total = -6, Epsilon = 0.0100
# Episodio 991: Recompensa total = 9, Epsilon = 0.0100
# Episodio 992: Recompensa total = 10, Epsilon = 0.0100
# Episodio 993: Recompensa total = 9, Epsilon = 0.0100
# Episodio 994: Recompensa total = 8, Epsilon = 0.0100
# Episodio 995: Recompensa total = 6, Epsilon = 0.0100
# Episodio 996: Recompensa total = 4, Epsilon = 0.0100
# Episodio 997: Recompensa total = 5, Epsilon = 0.0100
# Episodio 998: Recompensa total = 4, Epsilon = 0.0100
# Episodio 999: Recompensa total = 4, Epsilon = 0.0100
# Episodio 1000: Recompensa total = 12, Epsilon = 0.0100

# %% [markdown]
# ### Tendencia de la Gráfica:
#
# 1. **Al inicio (episodios bajos)**: La **recompensa total es muy negativa**, con grandes variaciones hacia abajo. Esto es característico de un agente que aún está **explorando** y tomando decisiones subóptimas. El alto valor inicial de `epsilon` (1.0) hace que el agente explore mucho, **tomando acciones aleatorias** y, como resultado, acumulando penalizaciones.
#
# 2. **A medida que avanzan los episodios**: Se observa una **mejora en la recompensa total** por episodio, con menos variaciones extremas y una **tendencia hacia valores más cercanos a cero**. Esto indica que el agente está comenzando a **explotar más sus mejores acciones** conocidas (gracias a la disminución de `epsilon`), tomando decisiones más eficientes y acumulando menos penalizaciones.
#
# 3. **En episodios avanzados (a partir de ~300)**: La **recompensa total se estabiliza** alrededor de valores cercanos a cero, con menos picos negativos. Esto muestra que el agente ha aprendido una **política estable y eficiente** para resolver el entorno. Sin embargo, debido al valor mínimo de `epsilon` (0.01), ocasionalmente sigue explorando, lo cual le permite **ajustar su política** y evitar quedarse atrapado en una solución subóptima.
#
# ### Comparación con un Agente Greedy Puro
#
# En comparación con un **agente greedy puro** (sin exploración), el **agente epsilon-greedy**:
#
# - **Explora más al principio**, lo que le permite probar diferentes acciones y **descubrir mejores estrategias** en los primeros episodios.
# - **Converge a una política estable** más rápidamente, ya que el decaimiento de `epsilon` reduce gradualmente la exploración y permite al agente explotar las mejores acciones.
# - **Evita quedarse atrapado en soluciones subóptimas** gracias al pequeño valor de exploración que se mantiene en `min_epsilon`, permitiendo ocasionalmente probar otras acciones.
#
# ### Conclusión
#
# La gráfica muestra que el **agente epsilon-greedy mejora su desempeño** a lo largo del tiempo, con una tendencia a **estabilizarse cerca de cero**. Esto indica que ha aprendido a completar la tarea de manera más eficiente y con menos penalización, beneficiándose del **equilibrio entre exploración y explotación** proporcionado por la estrategia epsilon-greedy.

# %%
# Graficar las recompensas acumuladas por episodio
plt.plot(rewards_per_episode)
plt.xlabel('Episodios')
plt.ylabel('Recompensa total')
plt.title('Recompensas Totales por Episodio (Epsilon-Greedy)')
plt.show()

# %%
listaEstados = []
done = False
truncated = False
G, reward = 0,0
state, _ = env.reset()
firstState = state
pasos = 0
listaEstados.append(state)
print("First State: ", firstState)
while reward != 20 and truncated != True:
        action = np.argmax(Q[state]) #1
        state2, reward, done, truncated, info = env.step(action) #2
        pasos += 1
        # Q[state,action] += alpha * (reward + np.max(Q[state2]) - Q[state,action]) #3
        print('State: ', state)
        print('pasos: ', pasos)
        G += reward
        state = state2  
        listaEstados.append(state)
# Out:
# First State:  108
# State:  108
# pasos:  1
# State:  208
# pasos:  2
# State:  308
# pasos:  3
# State:  408
# pasos:  4
# State:  416
# pasos:  5
# State:  316
# pasos:  6
# State:  216
# pasos:  7
# State:  116
# pasos:  8
# State:  16
# pasos:  9

# %%
for estado in listaEstados:
    env.reset()
    env.unwrapped.s = estado
    decoded_state = decode_taxi_state(estado)
    print(decoded_state)  
    print(env.render())
# Out:
# {'taxi_row': 1, 'taxi_col': 0, 'passenger_location': 2, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 0, 'passenger_location': 2, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 3, 'taxi_col': 0, 'passenger_location': 2, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 4, 'taxi_col': 0, 'passenger_location': 2, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 4, 'taxi_col': 0, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 3, 'taxi_col': 0, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# |_| : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 0, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 1, 'taxi_col': 0, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 0, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 0, 'passenger_location': 0, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# # VALORES INICIALES OPTIMAS
#
# ### Parámetros del Agente
#
# - **episodes = 500**: Define el **número total de episodios en el entrenamiento**, es decir, cuántas veces el agente intentará completar la tarea.
#
# - **alpha = 0.618**: Establece la **tasa de aprendizaje**. Este parámetro controla cuánto impacto tiene la **nueva información** sobre el valor Q existente. Un valor más alto permite que el agente aprenda más rápidamente de las **recompensas recientes**.
#
# - **epsilon = 1.0**: Inicializa el valor de `epsilon` en 1.0, lo cual representa la **probabilidad inicial de que el agente explore** (escoja una acción aleatoria). Esto **fomenta la exploración** al inicio del entrenamiento.
#
# - **epsilon_decay = 0.995**: Define el **factor de decaimiento de `epsilon`**. Después de cada episodio, `epsilon` se multiplica por este valor, **reduciendo gradualmente la probabilidad de exploración**. Esto permite que el agente explore al principio y luego se enfoque en explotar las **mejores acciones conocidas**.
#
# - **min_epsilon = 0.01**: Establece un **valor mínimo de `epsilon`**. Esto asegura que el agente no deje de explorar por completo y que siempre exista una **pequeña probabilidad de elegir una acción aleatoria**, lo cual ayuda a evitar quedarse atrapado en una **solución subóptima**.
#
# - **Q = np.ones([env.observation_space.n, env.action_space.n])**:
#
#   - Inicializa la **tabla Q con valores de 1** en lugar de 0, de tamaño `[número de estados, número de acciones]`.
#   - `env.observation_space.n` representa el **número de estados** en el entorno.
#   - `env.action_space.n` representa el **número de acciones posibles en cada estado**.
#
# ### Importancia de la Inicialización con Valores Optimistas (Q = np.ones(...))
#
# Inicializar la tabla Q con valores de 1 es una técnica conocida como **valores iniciales optimistas**. Al asignar un valor alto (mayor que 0) a todas las acciones, el agente percibe que cualquier acción podría tener una recompensa potencial alta. Esto incentiva la **exploración temprana**, ya que el agente intentará probar diferentes acciones en cada estado para confirmar si realmente pueden producir recompensas altas.
#
# #### Esta estrategia es útil en el aprendizaje por refuerzo porque:
#
# - **Incentiva la exploración temprana**: El agente probará diferentes acciones porque los valores Q iniciales sugieren que todas las acciones son buenas.
#
# - **Reduce el riesgo de converger a una política subóptima**: Al explorar más al principio, el agente tiene más oportunidades de **descubrir las mejores acciones** posibles en cada estado.

# %%
episodes = 1000  # Número total de episodios de entrenamiento
alpha = 0.618  # Tasa de aprendizaje
epsilon = 1.0  # Valor inicial de epsilon para exploración
epsilon_decay = 0.995  # Factor de decaimiento de epsilon
min_epsilon = 0.01  # Valor mínimo de epsilon
Q = np.ones([env.observation_space.n, env.action_space.n])  # Tabla Q inicializada en ceros

# %%
# Lista para almacenar las recompensas totales por episodio
rewards_per_episode = []

for episode in range(1, episodes + 1):
    done = False
    truncated = False
    G, reward = 0, 0
    state, _ = env.reset()
    pasos = 0

    # Bucle de pasos para el episodio actual
    while reward != 20 and not truncated:
        # Decisión epsilon-greedy: exploración o explotación
        if np.random.rand() < epsilon:
            action = env.action_space.sample()  # Exploración: elige una acción aleatoria
        else:
            action = np.argmax(Q[state])  # Explotación: elige la mejor acción conocida
        
        # Ejecuta la acción en el entorno y observa el nuevo estado y recompensa
        state2, reward, done, truncated, info = env.step(action)
        
        # Actualiza el valor Q usando la fórmula de Q-learning
        Q[state, action] += alpha * (reward + np.max(Q[state2]) - Q[state, action])
        
        # Acumula la recompensa y actualiza el estado actual
        G += reward
        state = state2
        pasos += 1

    # Almacenar la recompensa total del episodio
    rewards_per_episode.append(G)

    # Reducir epsilon gradualmente hasta un valor mínimo (epsilon decay)
    epsilon = max(min_epsilon, epsilon * epsilon_decay)

    # Imprimir la recompensa total en episodios específicos (100, 200, 300, etc.)
    if episode % 100 == 0:
        print(f"Recompensa total en el episodio {episode}: {G}")
# Out:
# Recompensa total en el episodio 100: -542
# Recompensa total en el episodio 200: -252
# Recompensa total en el episodio 300: -14
# Recompensa total en el episodio 400: 1
# Recompensa total en el episodio 500: -10
# Recompensa total en el episodio 600: 10
# Recompensa total en el episodio 700: -12
# Recompensa total en el episodio 800: 8
# Recompensa total en el episodio 900: 5
# Recompensa total en el episodio 1000: 7

# %% [markdown]
# ### Análisis de la Gráfica de Recompensas
#
# La gráfica de recompensas muestra que el **agente epsilon-greedy con valores iniciales optimistas** en la tabla Q (iniciando en 1 en lugar de 0) **converge más rápidamente** y obtiene **recompensas menos negativas** en comparación con un agente que inicia en cero.
#
# #### Razones de este Comportamiento:
#
# - **Exploración Temprana Incentivada**: Los valores iniciales altos incentivan una **exploración temprana**. Esto permite al agente **probar diferentes acciones** antes de decidirse por una política específica, ayudándolo a **descubrir mejores estrategias** desde el principio.
#
# - **Prevención de Soluciones Subóptimas**: Al explorar más al inicio, el agente evita quedarse atrapado en una **solución subóptima** basada en valores Q bajos.
#
# #### Resultado:
#
# Como resultado, el agente **estabiliza su desempeño de forma más eficiente**, logrando una política que **minimiza las penalizaciones** y mantiene una **recompensa total más estable** a lo largo de los episodios.

# %%
# Graficar las recompensas acumuladas por episodio
plt.plot(rewards_per_episode)
plt.xlabel('Episodios')
plt.ylabel('Recompensa total')
plt.title('Recompensas Totales por Episodio (Epsilon-Greedy)')
plt.show()

# %%
listaEstados = []
done = False
truncated = False
G, reward = 0,0
state, _ = env.reset()
firstState = state
pasos = 0
listaEstados.append(state)
print("First State: ", firstState)
while reward != 20 and truncated != True:
        action = np.argmax(Q[state]) #1
        state2, reward, done, truncated, info = env.step(action) #2
        pasos += 1
        # Q[state,action] += alpha * (reward + np.max(Q[state2]) - Q[state,action]) #3
        print('State: ', state)
        print('pasos: ', pasos)
        G += reward
        state = state2  
        listaEstados.append(state)
# Out:
# First State:  192
# State:  192
# pasos:  1
# State:  292
# pasos:  2
# State:  272
# pasos:  3
# State:  372
# pasos:  4
# State:  472
# pasos:  5
# State:  476
# pasos:  6
# State:  376
# pasos:  7
# State:  276
# pasos:  8
# State:  256
# pasos:  9
# State:  236
# pasos:  10
# State:  136
# pasos:  11
# State:  116
# pasos:  12
# State:  16
# pasos:  13

# %%
for estado in listaEstados:
    env.reset()
    env.unwrapped.s = estado
    decoded_state = decode_taxi_state(estado)
    print(decoded_state)  
    print(env.render())
# Out:
# {'taxi_row': 1, 'taxi_col': 4, 'passenger_location': 3, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 4, 'passenger_location': 3, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 3, 'passenger_location': 3, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 3, 'taxi_col': 3, 'passenger_location': 3, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 4, 'taxi_col': 3, 'passenger_location': 3, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 4, 'taxi_col': 3, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 3, 'taxi_col': 3, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 3, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 2, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : :_: : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 1, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | :_: : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 1, 'taxi_col': 1, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# | :_| : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 1, 'taxi_col': 0, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# |_: | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 0, 'passenger_location': 4, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 0, 'passenger_location': 0, 'destination': 0}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# ### Parámetros del Agente con Selección de Acciones por Intervalo de Confianza Superior (UCB)
#
# - **episodes = 500**: Define el **número total de episodios en el entrenamiento**, es decir, cuántas veces el agente intentará completar la tarea en el entorno.
#
# - **alpha = 0.618**: Establece la **tasa de aprendizaje**. Este parámetro controla cuánto impacto tiene la **nueva información** (recompensa obtenida y valor futuro esperado) sobre el valor Q existente. Un valor más alto permite que el agente aprenda más rápidamente de las **recompensas recientes**.
#
# - **c = 1.0**: Define el **parámetro de exploración para UCB** (Upper Confidence Bound, o Límite Superior de Confianza). Este parámetro controla el grado de **exploración del agente**.
#   - Valores más altos de `c` fomentan **mayor exploración**.
#   - Valores más bajos priorizan la **explotación de acciones con altos valores Q**.
#
# - **Q = np.zeros([env.observation_space.n, env.action_space.n])**: Inicializa la **tabla Q con valores de 0**, de tamaño `[número de estados, número de acciones]`. Esta tabla almacenará los **valores Q estimados para cada combinación de estado y acción**.
#
# - **action_counts = np.zeros([env.observation_space.n, env.action_space.n])**: Inicializa una **matriz de conteo de acciones** en ceros, con el mismo tamaño que la tabla Q. Este arreglo mantiene el **conteo de veces que cada acción ha sido tomada en cada estado**, lo cual es esencial para el cálculo del **intervalo de confianza superior en UCB**.
#   - Durante el entrenamiento, cada vez que el agente selecciona una acción en un estado determinado, el correspondiente valor en `action_counts` se incrementará en 1.
#
# - **rewards_per_episode = []**: Inicializa una **lista vacía para almacenar la recompensa total obtenida en cada episodio**. Esto permite realizar un **seguimiento del desempeño del agente** a lo largo del tiempo.
#
# ### Explicación de la Selección de Acciones con UCB
#
# El **intervalo de confianza superior (UCB)** incentiva al agente a elegir **acciones que no ha explorado mucho o que han mostrado un buen desempeño**. La fórmula de UCB en este contexto se basa en los valores de Q y en la frecuencia de cada acción
#
# #### Este enfoque permite que el agente:
#
# - **Explore acciones** que han sido elegidas pocas veces por que **c** será más grande, incentivando la exploración).
# - **Explote acciones con altos valores Q** cuando sean las mejores opciones conocidas hasta el momento.

# %%
episodes = 1000  # Número total de episodios de entrenamiento
alpha = 0.618  # Tasa de aprendizaje
c = 1.0  # Parámetro de exploración para UCB
Q = np.zeros([env.observation_space.n, env.action_space.n])  # Tabla Q inicializada en ceros
action_counts = np.zeros([env.observation_space.n, env.action_space.n])  # Conteo de acciones por estado

# Lista para almacenar las recompensas totales por episodio
rewards_per_episode = []

# %% [markdown]
# ### Elección de Acción con UCB
#
# - **if np.any(action_counts[state] == 0)**: Verifica si existe alguna **acción en el estado actual que aún no ha sido explorada**:
#   - **Explora una Acción No Tomada**: Si al menos una acción no ha sido explorada en el estado actual, selecciona la acción menos explorada con `np.argmin(action_counts[state])`.
#
# - **else**: Si todas las acciones han sido **exploradas al menos una vez** en el estado actual:
#   - **total_counts = np.sum(action_counts[state])**: Calcula el **total de veces que cualquier acción ha sido tomada** en este estado, lo que se usa para el cálculo de los intervalos de confianza.
#   - **confidence_bounds = Q[state] + c * np.sqrt(np.log(total_counts) / action_counts[state])**: Calcula el valor de UCB (Upper Confidence Bound) para cada acción en el estado actual:
#     - **Q[state]** es el valor Q actual de cada acción en el estado.
#     - **c * np.sqrt(np.log(total_counts) / action_counts[state])** representa el intervalo de confianza, donde `c` controla el grado de exploración. Este término incentiva la exploración de acciones menos frecuentadas.
#
#   - **action = np.argmax(confidence_bounds)**: Selecciona la acción con el valor máximo de UCB, que combina el valor Q y el intervalo de confianza, promoviendo una estrategia de **exploración-explotación balanceada**.
#
# ### Ejecución de la Acción y Transición de Estado
#
# - **state2, reward, done, truncated, info = env.step(action)**: Ejecuta la acción seleccionada en el entorno, obteniendo:
#   - **state2**: Nuevo estado resultante de la acción.
#   - **reward**: Recompensa obtenida tras la acción.
#   - **done**: Indica si el episodio se ha completado (si se alcanzó un objetivo final).
#   - **truncated**: Indica si el episodio fue truncado por razones externas (límite de tiempo, etc.).
#   - **info**: Información adicional del entorno (no utilizada en este contexto).
#
# ### Actualización de la Tabla Q
#
# - **Q[state, action] += alpha * (reward + np.max(Q[state2]) - Q[state, action])**: Actualiza el valor Q para el par estado-acción utilizando la **fórmula de Q-learning**:
#   - La actualización pondera la **diferencia entre la recompensa obtenida y el valor futuro esperado** (`np.max(Q[state2])`), ajustado por la tasa de aprendizaje `alpha`.

# %%
for episode in range(1, episodes + 1):
    done = False
    truncated = False
    G, reward = 0, 0
    state, _ = env.reset()
    pasos = 0

    contadorAccIlegales = 0
    # Bucle de pasos para el episodio actual
    while reward != 20 and not truncated:
        # Selección de acción con UCB
        if np.any(action_counts[state] == 0):
            # Si alguna acción no se ha tomado, elige una acción no explorada
            action = np.argmin(action_counts[state])
        else:
            # UCB: acción que maximiza el valor Q ajustado por el intervalo de confianza
            total_counts = np.sum(action_counts[state])
            confidence_bounds = Q[state] + c * np.sqrt(np.log(total_counts) / action_counts[state])
            action = np.argmax(confidence_bounds)
        
        # Ejecuta la acción en el entorno y observa el nuevo estado y recompensa
        state2, reward, done, truncated, info = env.step(action)
        if reward == -10:
            contadorAccIlegales += 1
        
        # Actualiza la tabla Q con la fórmula de Q-learning
        Q[state, action] += alpha * (reward + np.max(Q[state2]) - Q[state, action])
        
        # Actualizar conteo de acciones y acumular la recompensa
        action_counts[state, action] += 1
        G += reward
        state = state2
        pasos += 1

    # Almacenar la recompensa total del episodio
    rewards_per_episode.append(G)

    # Imprimir la recompensa total en episodios específicos (100, 200, 300, etc.)
    if episode % 1 == 0:
        print(f"Recompensa total en el episodio {episode}: {G} (Acciones ilegales: {contadorAccIlegales})")
# Out:
# Recompensa total en el episodio 1: -515 (Acciones ilegales: 35)
# Recompensa total en el episodio 2: -497 (Acciones ilegales: 33)
# Recompensa total en el episodio 3: -470 (Acciones ilegales: 30)
# Recompensa total en el episodio 4: -578 (Acciones ilegales: 42)
# Recompensa total en el episodio 5: -542 (Acciones ilegales: 38)
# Recompensa total en el episodio 6: -497 (Acciones ilegales: 33)
# Recompensa total en el episodio 7: -380 (Acciones ilegales: 20)
# Recompensa total en el episodio 8: -353 (Acciones ilegales: 17)
# Recompensa total en el episodio 9: -326 (Acciones ilegales: 14)
# Recompensa total en el episodio 10: -461 (Acciones ilegales: 29)
# Recompensa total en el episodio 11: -227 (Acciones ilegales: 3)
# Recompensa total en el episodio 12: -308 (Acciones ilegales: 12)
# Recompensa total en el episodio 13: -578 (Acciones ilegales: 42)
# Recompensa total en el episodio 14: -533 (Acciones ilegales: 37)
# Recompensa total en el episodio 15: -524 (Acciones ilegales: 36)
# Recompensa total en el episodio 16: -274 (Acciones ilegales: 11)
# Recompensa total en el episodio 17: -290 (Acciones ilegales: 10)
# Recompensa total en el episodio 18: -176 (Acciones ilegales: 7)
# Recompensa total en el episodio 19: -578 (Acciones ilegales: 42)
# Recompensa total en el episodio 20: -254 (Acciones ilegales: 6)
# Recompensa total en el episodio 21: -308 (Acciones ilegales: 12)
# Recompensa total en el episodio 22: -542 (Acciones ilegales: 38)
# Recompensa total en el episodio 23: -344 (Acciones ilegales: 16)
# Recompensa total en el episodio 24: -150 (Acciones ilegales: 2)
# Recompensa total en el episodio 25: -200 (Acciones ilegales: 9)
# Recompensa total en el episodio 26: -200 (Acciones ilegales: 0)
# Recompensa total en el episodio 27: -362 (Acciones ilegales: 18)
# Recompensa total en el episodio 28: -254 (Acciones ilegales: 6)
# Recompensa total en el episodio 29: -200 (Acciones ilegales: 0)
# Recompensa total en el episodio 30: -349 (Acciones ilegales: 19)
# Recompensa total en el episodio 31: -299 (Acciones ilegales: 11)
# Recompensa total en el episodio 32: -416 (Acciones ilegales: 24)
# Recompensa total en el episodio 33: -126 (Acciones ilegales: 0)
# Recompensa total en el episodio 34: -569 (Acciones ilegales: 41)
# Recompensa total en el episodio 35: -317 (Acciones ilegales: 13)
# Recompensa total en el episodio 36: -52 (Acciones ilegales: 0)
# Recompensa total en el episodio 37: -335 (Acciones ilegales: 15)
# Recompensa total en el episodio 38: -307 (Acciones ilegales: 18)
# Recompensa total en el episodio 39: -362 (Acciones ilegales: 18)
# Recompensa total en el episodio 40: -251 (Acciones ilegales: 9)
# Recompensa total en el episodio 41: -200 (Acciones ilegales: 0)
# Recompensa total en el episodio 42: -34 (Acciones ilegales: 0)
# Recompensa total en el episodio 43: -200 (Acciones ilegales: 0)
# Recompensa total en el episodio 44: -56 (Acciones ilegales: 4)
# Recompensa total en el episodio 45: -223 (Acciones ilegales: 16)
# Recompensa total en el episodio 46: -383 (Acciones ilegales: 24)
# Recompensa total en el episodio 47: -421 (Acciones ilegales: 28)
# Recompensa total en el episodio 48: -335 (Acciones ilegales: 15)
# Recompensa total en el episodio 49: -443 (Acciones ilegales: 27)
# Recompensa total en el episodio 50: -45 (Acciones ilegales: 0)
# Recompensa total en el episodio 51: -119 (Acciones ilegales: 0)
# Recompensa total en el episodio 52: -227 (Acciones ilegales: 3)
# Recompensa total en el episodio 53: -105 (Acciones ilegales: 2)
# Recompensa total en el episodio 54: -131 (Acciones ilegales: 1)
# Recompensa total en el episodio 55: -200 (Acciones ilegales: 0)
# Recompensa total en el episodio 56: -200 (Acciones ilegales: 0)
# Recompensa total en el episodio 57: -11 (Acciones ilegales: 0)
# Recompensa total en el episodio 58: -151 (Acciones ilegales: 0)
# Recompensa total en el episodio 59: -171 (Acciones ilegales: 0)
# Recompensa total en el episodio 60: -76 (Acciones ilegales: 6)
# Recompensa total en el episodio 61: -87 (Acciones ilegales: 0)
# Recompensa total en el episodio 62: -70 (Acciones ilegales: 0)
# Recompensa total en el episodio 63: -398 (Acciones ilegales: 22)
# Recompensa total en el episodio 64: -439 (Acciones ilegales: 34)
# Recompensa total en el episodio 65: -127 (Acciones ilegales: 2)
# Recompensa total en el episodio 66: -542 (Acciones ilegales: 38)
# Recompensa total en el episodio 67: -200 (Acciones ilegales: 0)
# Recompensa total en el episodio 68: -242 (Acciones ilegales: 11)
# Recompensa total en el episodio 69: -200 (Acciones ilegales: 0)
# Recompensa total en el episodio 70: -116 (Acciones ilegales: 0)
# Recompensa total en el episodio 71: -22 (Acciones ilegales: 1)
# Recompensa total en el episodio 72: -41 (Acciones ilegales: 0)
# Recompensa total en el episodio 73: -44 (Acciones ilegales: 0)
# Recompensa total en el episodio 74: -20 (Acciones ilegales: 1)
# Recompensa total en el episodio 75: -104 (Acciones ilegales: 0)
# Recompensa total en el episodio 76: -98 (Acciones ilegales: 0)
# Recompensa total en el episodio 77: -218 (Acciones ilegales: 2)
# Recompensa total en el episodio 78: -223 (Acciones ilegales: 12)
# Recompensa total en el episodio 79: -28 (Acciones ilegales: 0)
# Recompensa total en el episodio 80: -1 (Acciones ilegales: 0)
# Recompensa total en el episodio 81: -103 (Acciones ilegales: 1)
# Recompensa total en el episodio 82: -65 (Acciones ilegales: 0)
# Recompensa total en el episodio 83: -127 (Acciones ilegales: 0)
# Recompensa total en el episodio 84: -200 (Acciones ilegales: 0)
# Recompensa total en el episodio 85: -122 (Acciones ilegales: 2)
# Recompensa total en el episodio 86: -542 (Acciones ilegales: 38)
# Recompensa total en el episodio 87: -11 (Acciones ilegales: 0)
# Recompensa total en el episodio 88: -125 (Acciones ilegales: 0)
# Recompensa total en el episodio 89: -63 (Acciones ilegales: 0)
# Recompensa total en el episodio 90: -218 (Acciones ilegales: 2)
# Recompensa total en el episodio 91: -84 (Acciones ilegales: 2)
# Recompensa total en el episodio 92: -106 (Acciones ilegales: 0)
# Recompensa total en el episodio 93: -36 (Acciones ilegales: 0)
# Recompensa total en el episodio 94: -50 (Acciones ilegales: 5)
# Recompensa total en el episodio 95: -133 (Acciones ilegales: 0)
# Recompensa total en el episodio 96: -578 (Acciones ilegales: 42)
# Recompensa total en el episodio 97: -116 (Acciones ilegales: 0)
# Recompensa total en el episodio 98: -159 (Acciones ilegales: 0)
# Recompensa total en el episodio 99: -161 (Acciones ilegales: 0)
# Recompensa total en el episodio 100: -96 (Acciones ilegales: 2)
# Recompensa total en el episodio 101: -513 (Acciones ilegales: 38)
# Recompensa total en el episodio 102: -24 (Acciones ilegales: 0)
# Recompensa total en el episodio 103: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 104: -9 (Acciones ilegales: 0)
# Recompensa total en el episodio 105: -578 (Acciones ilegales: 42)
# Recompensa total en el episodio 106: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 107: -200 (Acciones ilegales: 0)
# Recompensa total en el episodio 108: -28 (Acciones ilegales: 0)
# Recompensa total en el episodio 109: -488 (Acciones ilegales: 32)
# Recompensa total en el episodio 110: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 111: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 112: -143 (Acciones ilegales: 4)
# Recompensa total en el episodio 113: 0 (Acciones ilegales: 0)
# Recompensa total en el episodio 114: -12 (Acciones ilegales: 2)
# Recompensa total en el episodio 115: -9 (Acciones ilegales: 2)
# Recompensa total en el episodio 116: -147 (Acciones ilegales: 7)
# Recompensa total en el episodio 117: -179 (Acciones ilegales: 11)
# Recompensa total en el episodio 118: -115 (Acciones ilegales: 0)
# Recompensa total en el episodio 119: -17 (Acciones ilegales: 0)
# Recompensa total en el episodio 120: -17 (Acciones ilegales: 2)
# Recompensa total en el episodio 121: -163 (Acciones ilegales: 0)
# Recompensa total en el episodio 122: -23 (Acciones ilegales: 0)
# Recompensa total en el episodio 123: -92 (Acciones ilegales: 1)
# Recompensa total en el episodio 124: -121 (Acciones ilegales: 2)
# Recompensa total en el episodio 125: -1 (Acciones ilegales: 0)
# Recompensa total en el episodio 126: -94 (Acciones ilegales: 0)
# Recompensa total en el episodio 127: -13 (Acciones ilegales: 0)
# Recompensa total en el episodio 128: -164 (Acciones ilegales: 0)
# Recompensa total en el episodio 129: -41 (Acciones ilegales: 0)
# Recompensa total en el episodio 130: -19 (Acciones ilegales: 0)
# Recompensa total en el episodio 131: -62 (Acciones ilegales: 0)
# Recompensa total en el episodio 132: -37 (Acciones ilegales: 0)
# Recompensa total en el episodio 133: -12 (Acciones ilegales: 0)
# Recompensa total en el episodio 134: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 135: -46 (Acciones ilegales: 0)
# Recompensa total en el episodio 136: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 137: -14 (Acciones ilegales: 2)
# Recompensa total en el episodio 138: -333 (Acciones ilegales: 18)
# Recompensa total en el episodio 139: -4 (Acciones ilegales: 0)
# Recompensa total en el episodio 140: -471 (Acciones ilegales: 38)
# Recompensa total en el episodio 141: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 142: -2 (Acciones ilegales: 0)
# Recompensa total en el episodio 143: -235 (Acciones ilegales: 20)
# Recompensa total en el episodio 144: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 145: -37 (Acciones ilegales: 3)
# Recompensa total en el episodio 146: -50 (Acciones ilegales: 0)
# Recompensa total en el episodio 147: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 148: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 149: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 150: -38 (Acciones ilegales: 0)
# Recompensa total en el episodio 151: -81 (Acciones ilegales: 0)
# Recompensa total en el episodio 152: -94 (Acciones ilegales: 6)
# Recompensa total en el episodio 153: -20 (Acciones ilegales: 0)
# Recompensa total en el episodio 154: 15 (Acciones ilegales: 0)
# Recompensa total en el episodio 155: -53 (Acciones ilegales: 1)
# Recompensa total en el episodio 156: -67 (Acciones ilegales: 2)
# Recompensa total en el episodio 157: -48 (Acciones ilegales: 0)
# Recompensa total en el episodio 158: -39 (Acciones ilegales: 0)
# Recompensa total en el episodio 159: -56 (Acciones ilegales: 0)
# Recompensa total en el episodio 160: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 161: -2 (Acciones ilegales: 0)
# Recompensa total en el episodio 162: -64 (Acciones ilegales: 0)
# Recompensa total en el episodio 163: -2 (Acciones ilegales: 0)
# Recompensa total en el episodio 164: -44 (Acciones ilegales: 0)
# Recompensa total en el episodio 165: -2 (Acciones ilegales: 0)
# Recompensa total en el episodio 166: -3 (Acciones ilegales: 0)
# Recompensa total en el episodio 167: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 168: -29 (Acciones ilegales: 4)
# Recompensa total en el episodio 169: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 170: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 171: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 172: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 173: -117 (Acciones ilegales: 6)
# Recompensa total en el episodio 174: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 175: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 176: -91 (Acciones ilegales: 0)
# Recompensa total en el episodio 177: -80 (Acciones ilegales: 4)
# Recompensa total en el episodio 178: -45 (Acciones ilegales: 0)
# Recompensa total en el episodio 179: -4 (Acciones ilegales: 0)
# Recompensa total en el episodio 180: -71 (Acciones ilegales: 0)
# Recompensa total en el episodio 181: -8 (Acciones ilegales: 0)
# Recompensa total en el episodio 182: -39 (Acciones ilegales: 0)
# Recompensa total en el episodio 183: -38 (Acciones ilegales: 0)
# Recompensa total en el episodio 184: -65 (Acciones ilegales: 0)
# Recompensa total en el episodio 185: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 186: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 187: -22 (Acciones ilegales: 0)
# Recompensa total en el episodio 188: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 189: -58 (Acciones ilegales: 0)
# Recompensa total en el episodio 190: -59 (Acciones ilegales: 0)
# Recompensa total en el episodio 191: -22 (Acciones ilegales: 0)
# Recompensa total en el episodio 192: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 193: -67 (Acciones ilegales: 0)
# Recompensa total en el episodio 194: -2 (Acciones ilegales: 0)
# Recompensa total en el episodio 195: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 196: -18 (Acciones ilegales: 0)
# Recompensa total en el episodio 197: -6 (Acciones ilegales: 0)
# Recompensa total en el episodio 198: -9 (Acciones ilegales: 0)
# Recompensa total en el episodio 199: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 200: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 201: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 202: -8 (Acciones ilegales: 0)
# Recompensa total en el episodio 203: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 204: -7 (Acciones ilegales: 0)
# Recompensa total en el episodio 205: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 206: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 207: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 208: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 209: -1 (Acciones ilegales: 0)
# Recompensa total en el episodio 210: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 211: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 212: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 213: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 214: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 215: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 216: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 217: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 218: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 219: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 220: -226 (Acciones ilegales: 18)
# Recompensa total en el episodio 221: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 222: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 223: -61 (Acciones ilegales: 0)
# Recompensa total en el episodio 224: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 225: -5 (Acciones ilegales: 0)
# Recompensa total en el episodio 226: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 227: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 228: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 229: -9 (Acciones ilegales: 0)
# Recompensa total en el episodio 230: -12 (Acciones ilegales: 0)
# Recompensa total en el episodio 231: -14 (Acciones ilegales: 2)
# Recompensa total en el episodio 232: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 233: -70 (Acciones ilegales: 6)
# Recompensa total en el episodio 234: -4 (Acciones ilegales: 0)
# Recompensa total en el episodio 235: -1 (Acciones ilegales: 0)
# Recompensa total en el episodio 236: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 237: -7 (Acciones ilegales: 0)
# Recompensa total en el episodio 238: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 239: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 240: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 241: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 242: -54 (Acciones ilegales: 0)
# Recompensa total en el episodio 243: -70 (Acciones ilegales: 6)
# Recompensa total en el episodio 244: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 245: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 246: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 247: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 248: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 249: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 250: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 251: -15 (Acciones ilegales: 0)
# Recompensa total en el episodio 252: -1 (Acciones ilegales: 0)
# Recompensa total en el episodio 253: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 254: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 255: 0 (Acciones ilegales: 0)
# Recompensa total en el episodio 256: -19 (Acciones ilegales: 0)
# Recompensa total en el episodio 257: -37 (Acciones ilegales: 0)
# Recompensa total en el episodio 258: -42 (Acciones ilegales: 0)
# Recompensa total en el episodio 259: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 260: -4 (Acciones ilegales: 0)
# Recompensa total en el episodio 261: -1 (Acciones ilegales: 0)
# Recompensa total en el episodio 262: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 263: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 264: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 265: -36 (Acciones ilegales: 4)
# Recompensa total en el episodio 266: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 267: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 268: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 269: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 270: 0 (Acciones ilegales: 0)
# Recompensa total en el episodio 271: -17 (Acciones ilegales: 0)
# Recompensa total en el episodio 272: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 273: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 274: -11 (Acciones ilegales: 0)
# Recompensa total en el episodio 275: -3 (Acciones ilegales: 0)
# Recompensa total en el episodio 276: 14 (Acciones ilegales: 0)
# Recompensa total en el episodio 277: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 278: -21 (Acciones ilegales: 2)
# Recompensa total en el episodio 279: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 280: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 281: -12 (Acciones ilegales: 0)
# Recompensa total en el episodio 282: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 283: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 284: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 285: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 286: -31 (Acciones ilegales: 0)
# Recompensa total en el episodio 287: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 288: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 289: -18 (Acciones ilegales: 0)
# Recompensa total en el episodio 290: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 291: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 292: -40 (Acciones ilegales: 0)
# Recompensa total en el episodio 293: -45 (Acciones ilegales: 4)
# Recompensa total en el episodio 294: -8 (Acciones ilegales: 0)
# Recompensa total en el episodio 295: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 296: -19 (Acciones ilegales: 0)
# Recompensa total en el episodio 297: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 298: -39 (Acciones ilegales: 4)
# Recompensa total en el episodio 299: -22 (Acciones ilegales: 0)
# Recompensa total en el episodio 300: -3 (Acciones ilegales: 0)
# Recompensa total en el episodio 301: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 302: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 303: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 304: -1 (Acciones ilegales: 0)
# Recompensa total en el episodio 305: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 306: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 307: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 308: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 309: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 310: -15 (Acciones ilegales: 2)
# Recompensa total en el episodio 311: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 312: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 313: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 314: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 315: -32 (Acciones ilegales: 0)
# Recompensa total en el episodio 316: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 317: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 318: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 319: -8 (Acciones ilegales: 0)
# Recompensa total en el episodio 320: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 321: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 322: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 323: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 324: -4 (Acciones ilegales: 0)
# Recompensa total en el episodio 325: -20 (Acciones ilegales: 2)
# Recompensa total en el episodio 326: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 327: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 328: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 329: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 330: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 331: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 332: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 333: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 334: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 335: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 336: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 337: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 338: -17 (Acciones ilegales: 0)
# Recompensa total en el episodio 339: -5 (Acciones ilegales: 0)
# Recompensa total en el episodio 340: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 341: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 342: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 343: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 344: -15 (Acciones ilegales: 0)
# Recompensa total en el episodio 345: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 346: 15 (Acciones ilegales: 0)
# Recompensa total en el episodio 347: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 348: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 349: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 350: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 351: -6 (Acciones ilegales: 0)
# Recompensa total en el episodio 352: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 353: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 354: 0 (Acciones ilegales: 0)
# Recompensa total en el episodio 355: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 356: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 357: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 358: 0 (Acciones ilegales: 0)
# Recompensa total en el episodio 359: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 360: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 361: -2 (Acciones ilegales: 0)
# Recompensa total en el episodio 362: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 363: -1 (Acciones ilegales: 0)
# Recompensa total en el episodio 364: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 365: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 366: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 367: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 368: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 369: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 370: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 371: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 372: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 373: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 374: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 375: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 376: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 377: -1 (Acciones ilegales: 0)
# Recompensa total en el episodio 378: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 379: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 380: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 381: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 382: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 383: -3 (Acciones ilegales: 0)
# Recompensa total en el episodio 384: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 385: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 386: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 387: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 388: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 389: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 390: -1 (Acciones ilegales: 0)
# Recompensa total en el episodio 391: -6 (Acciones ilegales: 0)
# Recompensa total en el episodio 392: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 393: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 394: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 395: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 396: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 397: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 398: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 399: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 400: -6 (Acciones ilegales: 0)
# Recompensa total en el episodio 401: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 402: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 403: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 404: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 405: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 406: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 407: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 408: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 409: -5 (Acciones ilegales: 0)
# Recompensa total en el episodio 410: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 411: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 412: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 413: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 414: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 415: 15 (Acciones ilegales: 0)
# Recompensa total en el episodio 416: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 417: -16 (Acciones ilegales: 2)
# Recompensa total en el episodio 418: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 419: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 420: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 421: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 422: -52 (Acciones ilegales: 4)
# Recompensa total en el episodio 423: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 424: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 425: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 426: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 427: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 428: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 429: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 430: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 431: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 432: 14 (Acciones ilegales: 0)
# Recompensa total en el episodio 433: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 434: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 435: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 436: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 437: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 438: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 439: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 440: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 441: -49 (Acciones ilegales: 4)
# Recompensa total en el episodio 442: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 443: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 444: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 445: 14 (Acciones ilegales: 0)
# Recompensa total en el episodio 446: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 447: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 448: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 449: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 450: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 451: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 452: -5 (Acciones ilegales: 0)
# Recompensa total en el episodio 453: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 454: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 455: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 456: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 457: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 458: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 459: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 460: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 461: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 462: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 463: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 464: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 465: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 466: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 467: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 468: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 469: 0 (Acciones ilegales: 0)
# Recompensa total en el episodio 470: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 471: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 472: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 473: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 474: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 475: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 476: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 477: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 478: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 479: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 480: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 481: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 482: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 483: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 484: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 485: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 486: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 487: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 488: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 489: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 490: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 491: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 492: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 493: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 494: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 495: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 496: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 497: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 498: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 499: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 500: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 501: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 502: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 503: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 504: -43 (Acciones ilegales: 4)
# Recompensa total en el episodio 505: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 506: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 507: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 508: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 509: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 510: -15 (Acciones ilegales: 2)
# Recompensa total en el episodio 511: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 512: 14 (Acciones ilegales: 0)
# Recompensa total en el episodio 513: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 514: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 515: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 516: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 517: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 518: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 519: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 520: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 521: -16 (Acciones ilegales: 2)
# Recompensa total en el episodio 522: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 523: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 524: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 525: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 526: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 527: -2 (Acciones ilegales: 0)
# Recompensa total en el episodio 528: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 529: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 530: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 531: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 532: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 533: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 534: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 535: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 536: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 537: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 538: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 539: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 540: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 541: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 542: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 543: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 544: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 545: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 546: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 547: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 548: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 549: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 550: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 551: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 552: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 553: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 554: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 555: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 556: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 557: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 558: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 559: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 560: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 561: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 562: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 563: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 564: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 565: 0 (Acciones ilegales: 0)
# Recompensa total en el episodio 566: -18 (Acciones ilegales: 2)
# Recompensa total en el episodio 567: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 568: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 569: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 570: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 571: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 572: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 573: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 574: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 575: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 576: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 577: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 578: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 579: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 580: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 581: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 582: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 583: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 584: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 585: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 586: 0 (Acciones ilegales: 0)
# Recompensa total en el episodio 587: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 588: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 589: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 590: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 591: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 592: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 593: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 594: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 595: 15 (Acciones ilegales: 0)
# Recompensa total en el episodio 596: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 597: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 598: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 599: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 600: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 601: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 602: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 603: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 604: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 605: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 606: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 607: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 608: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 609: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 610: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 611: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 612: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 613: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 614: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 615: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 616: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 617: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 618: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 619: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 620: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 621: 14 (Acciones ilegales: 0)
# Recompensa total en el episodio 622: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 623: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 624: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 625: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 626: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 627: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 628: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 629: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 630: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 631: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 632: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 633: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 634: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 635: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 636: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 637: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 638: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 639: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 640: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 641: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 642: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 643: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 644: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 645: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 646: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 647: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 648: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 649: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 650: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 651: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 652: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 653: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 654: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 655: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 656: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 657: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 658: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 659: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 660: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 661: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 662: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 663: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 664: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 665: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 666: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 667: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 668: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 669: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 670: 15 (Acciones ilegales: 0)
# Recompensa total en el episodio 671: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 672: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 673: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 674: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 675: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 676: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 677: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 678: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 679: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 680: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 681: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 682: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 683: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 684: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 685: -1 (Acciones ilegales: 0)
# Recompensa total en el episodio 686: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 687: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 688: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 689: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 690: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 691: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 692: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 693: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 694: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 695: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 696: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 697: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 698: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 699: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 700: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 701: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 702: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 703: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 704: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 705: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 706: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 707: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 708: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 709: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 710: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 711: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 712: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 713: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 714: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 715: 14 (Acciones ilegales: 0)
# Recompensa total en el episodio 716: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 717: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 718: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 719: 14 (Acciones ilegales: 0)
# Recompensa total en el episodio 720: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 721: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 722: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 723: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 724: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 725: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 726: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 727: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 728: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 729: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 730: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 731: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 732: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 733: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 734: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 735: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 736: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 737: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 738: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 739: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 740: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 741: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 742: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 743: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 744: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 745: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 746: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 747: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 748: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 749: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 750: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 751: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 752: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 753: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 754: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 755: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 756: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 757: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 758: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 759: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 760: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 761: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 762: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 763: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 764: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 765: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 766: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 767: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 768: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 769: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 770: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 771: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 772: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 773: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 774: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 775: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 776: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 777: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 778: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 779: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 780: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 781: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 782: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 783: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 784: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 785: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 786: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 787: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 788: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 789: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 790: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 791: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 792: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 793: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 794: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 795: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 796: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 797: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 798: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 799: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 800: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 801: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 802: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 803: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 804: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 805: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 806: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 807: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 808: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 809: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 810: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 811: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 812: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 813: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 814: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 815: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 816: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 817: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 818: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 819: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 820: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 821: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 822: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 823: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 824: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 825: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 826: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 827: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 828: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 829: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 830: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 831: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 832: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 833: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 834: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 835: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 836: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 837: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 838: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 839: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 840: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 841: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 842: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 843: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 844: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 845: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 846: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 847: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 848: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 849: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 850: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 851: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 852: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 853: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 854: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 855: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 856: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 857: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 858: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 859: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 860: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 861: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 862: -2 (Acciones ilegales: 0)
# Recompensa total en el episodio 863: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 864: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 865: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 866: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 867: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 868: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 869: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 870: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 871: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 872: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 873: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 874: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 875: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 876: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 877: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 878: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 879: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 880: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 881: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 882: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 883: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 884: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 885: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 886: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 887: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 888: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 889: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 890: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 891: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 892: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 893: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 894: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 895: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 896: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 897: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 898: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 899: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 900: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 901: 1 (Acciones ilegales: 0)
# Recompensa total en el episodio 902: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 903: 14 (Acciones ilegales: 0)
# Recompensa total en el episodio 904: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 905: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 906: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 907: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 908: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 909: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 910: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 911: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 912: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 913: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 914: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 915: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 916: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 917: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 918: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 919: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 920: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 921: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 922: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 923: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 924: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 925: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 926: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 927: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 928: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 929: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 930: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 931: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 932: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 933: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 934: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 935: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 936: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 937: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 938: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 939: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 940: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 941: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 942: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 943: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 944: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 945: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 946: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 947: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 948: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 949: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 950: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 951: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 952: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 953: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 954: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 955: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 956: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 957: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 958: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 959: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 960: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 961: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 962: 10 (Acciones ilegales: 0)
# Recompensa total en el episodio 963: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 964: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 965: 13 (Acciones ilegales: 0)
# Recompensa total en el episodio 966: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 967: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 968: 15 (Acciones ilegales: 0)
# Recompensa total en el episodio 969: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 970: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 971: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 972: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 973: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 974: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 975: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 976: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 977: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 978: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 979: 3 (Acciones ilegales: 0)
# Recompensa total en el episodio 980: 14 (Acciones ilegales: 0)
# Recompensa total en el episodio 981: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 982: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 983: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 984: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 985: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 986: 2 (Acciones ilegales: 0)
# Recompensa total en el episodio 987: 8 (Acciones ilegales: 0)
# Recompensa total en el episodio 988: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 989: 14 (Acciones ilegales: 0)
# Recompensa total en el episodio 990: 6 (Acciones ilegales: 0)
# Recompensa total en el episodio 991: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 992: 9 (Acciones ilegales: 0)
# Recompensa total en el episodio 993: 7 (Acciones ilegales: 0)
# Recompensa total en el episodio 994: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 995: 5 (Acciones ilegales: 0)
# Recompensa total en el episodio 996: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 997: 4 (Acciones ilegales: 0)
# Recompensa total en el episodio 998: 12 (Acciones ilegales: 0)
# Recompensa total en el episodio 999: 11 (Acciones ilegales: 0)
# Recompensa total en el episodio 1000: 8 (Acciones ilegales: 0)

# %% [markdown]
# ### Análisis del Método UCB en la Gráfica de Recompensas
#
# El método UCB en esta gráfica muestra que el agente explora intensamente al inicio, lo que resulta en recompensas negativas. Esto es característico de UCB, que incentiva la exploración de acciones menos utilizadas para obtener más información. Gracias a este balance entre exploración y explotación, el agente logra aprender rápidamente, evitando penalizaciones innecesarias a medida que avanza el entrenamiento.
#
# Después de aproximadamente 200-300 episodios, la recompensa total se estabiliza cerca de cero, indicando que el agente ha encontrado una política eficiente para completar la tarea. UCB permite que el agente mantenga una mínima exploración en episodios avanzados mientras explota las acciones con altos valores Q. En general, UCB es efectivo para alcanzar una convergencia rápida y estable hacia una estrategia óptima o cercana a óptima.
#
# ### Resumen del Comportamiento de UCB
# - **Exploración temprana:** UCB incentiva la exploración inicial de acciones no probadas, permitiendo al agente recopilar información y reducir la incertidumbre.
# - **Convergencia estable:** La recompensa se estabiliza cerca de cero después de unos 200-300 episodios, lo que indica una política estable y eficiente.
# - **Balance exploración-explotación:** UCB mantiene una mínima exploración en episodios avanzados, evitando que el agente quede atrapado en soluciones subóptimas y permitiéndole explotar las mejores acciones conocidas.
#
# En resumen, el método UCB permite un aprendizaje robusto y estable, ideal para problemas que requieren tanto una convergencia rápida como una política de ejecución confiable y efectiva en el largo plazo.

# %%
# Graficar las recompensas acumuladas por episodio
plt.plot(rewards_per_episode)
plt.xlabel('Episodios')
plt.ylabel('Recompensa total')
plt.title('Recompensas Totales por Episodio (UCB)')
plt.show()

# %%
listaEstados = []
done = False
truncated = False
G, reward = 0,0
state, _ = env.reset()
firstState = state
pasos = 0
listaEstados.append(state)
print("First State: ", firstState)
while reward != 20 and truncated != True:
        action = np.argmax(Q[state]) #1
        state2, reward, done, truncated, info = env.step(action) #2
        pasos += 1
        # Q[state,action] += alpha * (reward + np.max(Q[state2]) - Q[state,action]) #3
        print('State: ', state)
        print('pasos: ', pasos)
        G += reward
        state = state2  
        listaEstados.append(state)
# Out:
# First State:  426
# State:  426
# pasos:  1
# State:  326
# pasos:  2
# State:  226
# pasos:  3
# State:  246
# pasos:  4
# State:  266
# pasos:  5
# State:  286
# pasos:  6
# State:  186
# pasos:  7
# State:  86
# pasos:  8
# State:  98
# pasos:  9
# State:  78
# pasos:  10
# State:  178
# pasos:  11
# State:  278
# pasos:  12
# State:  258
# pasos:  13
# State:  238
# pasos:  14
# State:  218
# pasos:  15
# State:  318
# pasos:  16
# State:  418
# pasos:  17

# %%
for estado in listaEstados:
    env.reset()
    env.unwrapped.s = estado
    decoded_state = decode_taxi_state(estado)
    print(decoded_state)  
    print(env.render())
# Out:
# {'taxi_row': 4, 'taxi_col': 1, 'passenger_location': 1, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 3, 'taxi_col': 1, 'passenger_location': 1, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 1, 'passenger_location': 1, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 2, 'passenger_location': 1, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 3, 'passenger_location': 1, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 4, 'passenger_location': 1, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 1, 'taxi_col': 4, 'passenger_location': 1, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 1, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 4, 'passenger_location': 4, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 0, 'taxi_col': 3, 'passenger_location': 4, 'destination': 2}
# +---------+
# |R: | :_:G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 1, 'taxi_col': 3, 'passenger_location': 4, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | :_: |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 3, 'passenger_location': 4, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 2, 'passenger_location': 4, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : :_: : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 1, 'passenger_location': 4, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | :_: : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 2, 'taxi_col': 0, 'passenger_location': 4, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 3, 'taxi_col': 0, 'passenger_location': 4, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# |_| : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 4, 'taxi_col': 0, 'passenger_location': 4, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
#
# {'taxi_row': 4, 'taxi_col': 0, 'passenger_location': 2, 'destination': 2}
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# # ASCENSO POR GRADIENTE

# %% [markdown]
# ## Logica del metodo de gradiente
# El método de gradiente en aprendizaje por refuerzo es una estrategia en la que el agente aprende a mejorar sus decisiones ajustando directamente la probabilidad de elegir cada acción en función de sus resultados. A diferencia de otros métodos como Q-learning, que buscan aprender el valor esperado de las acciones para decidir cuál es la mejor, el método de gradiente ajusta las "preferencias" hacia cada acción, aumentando la probabilidad de acciones exitosas y reduciendo la de aquellas que han sido menos efectivas.
#
# ### Lógica del Método de Gradiente
# #### Preferencias y Probabilidades:
#  En lugar de una tabla de valores (como en Q-learning), el agente mantiene un vector de preferencias para cada acción. Estas preferencias representan la inclinación del agente hacia cada acción en un momento dado. A partir de estas preferencias, se calcula una probabilidad para cada acción usando la función softmax, que convierte estas preferencias en una distribución de probabilidades. Esto permite que cada acción tenga una probabilidad proporcional a su preferencia, de modo que el agente no elija siempre la misma acción, sino que explore de forma balanceada.
#
# #### Selección de Acción:
# Cada vez que el agente debe tomar una decisión, selecciona una acción según la distribución de probabilidades calculada con softmax. Esto significa que acciones con mayores preferencias tienen más probabilidades de ser seleccionadas, pero todavía hay una posibilidad de que el agente explore acciones menos preferidas. Este balance entre exploración y explotación está integrado en el propio proceso de selección basado en probabilidades.
#
# #### Recompensa y Ajuste de Preferencias:
# Después de tomar una acción y observar la recompensa, el agente ajusta sus preferencias:
#
#  * Si la recompensa obtenida es mayor que la recompensa media acumulada hasta ese punto, se incrementa la preferencia de la acción seleccionada y se reduce la preferencia de las demas acciones. Este aumento es proporcional a la diferencia entre la recompensa obtenida y la recompensa media, y se ajusta por la tasa de aprendizaje (alpha).
#  * Por otro lado, si la recompensa es menor que la media, la preferencia por esa acción disminuye y la preferencia de las demas aumenta.
#
# ### Actualización de Probabilidades:
# Con los ajustes realizados en las preferencias, el agente recalcula las probabilidades para cada acción usando nuevamente la función softmax. De esta forma, la estrategia del agente se ajusta continuamente en función de los resultados obtenidos, aumentando las probabilidades de acciones exitosas y reduciendo las de aquellas menos útiles.

# %% [markdown]
# ## En el Codigo:
#
# ---
#
# ### Importación de Librerías
# ```python
# import numpy as np
# ```
# `numpy` es una biblioteca en Python que facilita las operaciones matemáticas y de matrices. Aquí se usa principalmente para realizar cálculos de `softmax` y manejar vectores.
#
# ### Función `softmax`
# ```python
# def softmax(x):
#     return np.exp(x) / np.sum(np.exp(x))
# ```
# Esta función convierte un conjunto de valores (`x`) en una distribución de probabilidad. La función exponencial enfatiza las diferencias entre los valores, y al dividir entre la suma de las exponenciales, se asegura de que la suma de todas las probabilidades sea 1. En este caso, `softmax` se usa para convertir las preferencias de acción (`H`) en probabilidades de selección (`pi`).
#
# ### Parámetros y Variables Iniciales
# ```python
# episodes = 1000  # Número total de episodios de entrenamiento
# alpha = 0.618  # Tasa de aprendizaje
# H = np.zeros([env.action_space.n])  # Preferencias inicializadas en cero
# rewards_per_episode = []
# ```
#
# - `episodes`: Número total de episodios que se ejecutarán.
# - `alpha`: La tasa de aprendizaje que determina cuánto se ajustan las preferencias en cada paso.
# - `H`: Un vector de preferencias de acción para cada posible acción en el entorno. Inicialmente, todas las preferencias están en cero.
# - `rewards_per_episode`: Lista para almacenar las recompensas totales obtenidas en cada episodio.
#
# ### Bucle de Entrenamiento Principal
# ```python
# for episode in range(1, episodes + 1):
# ```
# Este bucle recorre todos los episodios. En cada episodio, se ejecuta una secuencia de pasos hasta que el entorno indica que el episodio ha terminado.
#
# #### Reseteo de Variables del Episodio
# ```python
# done = False
# truncated = False
# G = 0
# state, _ = env.reset()
# pasos = 0
# recompensas = []
# ```
# - `done` y `truncated`: Estas variables de control indican si el episodio ha terminado.
# - `G`: Variable para acumular la recompensa total del episodio.
# - `state`: El estado inicial del entorno tras el `reset`.
# - `recompensas`: Lista para almacenar las recompensas obtenidas en los pasos de este episodio.
#
# #### Inicialización de las Probabilidades
# ```python
# pi = softmax(H)
# contadorAcciones = 0
# ```
# Se calculan las probabilidades de seleccionar cada acción usando `softmax` aplicado al vector de preferencias `H`. Estas probabilidades (`pi`) reflejan la preferencia relativa de cada acción. `contadorAcciones` es una variable adicional para contar el número de acciones en el episodio.
#
# ### Bucle de Pasos Dentro del Episodio
# ```python
# while not done and not truncated:
# ```
# Este bucle se ejecuta hasta que el episodio termina. En cada iteración, el agente selecciona una acción, observa el resultado y actualiza sus preferencias de acción.
#
# #### Selección de Acción con Softmax
# ```python
# action = np.random.choice(env.action_space.n, p=pi)
# contadorAcciones += 1
# ```
# Aquí se selecciona una acción basada en la distribución de probabilidades `pi`, que refleja la probabilidad de escoger cada acción según las preferencias actuales.
#
# #### Ejecución de la Acción y Observación del Resultado
# ```python
# state2, reward, done, truncated, info = env.step(action)
# recompensas.append(reward)
# ```
# El agente ejecuta la acción `action` en el entorno (`env.step(action)`) y observa el siguiente estado `state2`, la recompensa `reward`, y si el episodio ha terminado (`done` o `truncated`). La recompensa obtenida se agrega a la lista `recompensas`.
#
# #### Actualización de la Recompensa Acumulada
# ```python
# G += reward
# ```
# La recompensa `reward` se suma a `G`, que mantiene un seguimiento de la recompensa total acumulada en el episodio.
#
# #### Cálculo de la Recompensa Media
# ```python
# recompensa_media = np.mean(recompensas)
# ```
# Se calcula la recompensa media hasta el momento en el episodio. Este valor se usa como referencia para ajustar las preferencias de las acciones, comparando la recompensa actual con esta media.
#
# #### Actualización de las Preferencias (Algoritmo de Gradiente)
# ```python
# for a in range(env.action_space.n):
#     if a == action:
#         H[a] += alpha * (reward - recompensa_media) * (1 - pi[a])
#     else:
#         H[a] -= alpha * (reward - recompensa_media) * pi[a]
# ```
# Este es el núcleo del método de gradiente:
#
# - Para la **acción seleccionada** (`a == action`), la preferencia de esa acción se incrementa si la recompensa actual es mayor que la recompensa media y disminuye si es menor. El término `(1 - pi[a])` ajusta la magnitud del cambio en función de la probabilidad de selección de esa acción.
#
# - Para las **acciones no seleccionadas**, las preferencias se reducen proporcionalmente a la probabilidad de esa acción (`pi[a]`), reflejando el hecho de que, si la acción tomada fue exitosa (en comparación con la media), se reduce la preferencia de las acciones alternativas.
#
# En general, esto crea un mecanismo de retroalimentación donde las acciones que tienen mejores recompensas tienden a aumentar sus preferencias, y las probabilidades de selección se ajustan en consecuencia.
#
# #### Actualización de las Probabilidades de Selección
# ```python
# pi = softmax(H)
# ```
# Después de actualizar las preferencias, recalculamos `pi` usando `softmax` para reflejar los cambios en las preferencias. Esto asegura que la distribución de probabilidades se ajuste según las nuevas preferencias.
#
# #### Actualización del Estado
# ```python
# state = state2
# pasos += 1
# ```
# El agente actualiza su estado actual a `state2` para el siguiente paso en el bucle.
#
# ### Finalización del Episodio
# ```python
# rewards_per_episode.append(G)
# ```
# La recompensa total acumulada en el episodio (`G`) se almacena en la lista `rewards_per_episode`.
#
# ### Monitoreo del Progreso
# ```python
# if episode % 100 == 0:
#     print(f"Recompensa total en el episodio {episode}: {G}")
# ```
# Cada 100 episodios, el código imprime la recompensa total obtenida, permitiendo monitorear el progreso del agente.
#
# ### Resumen de la Lógica del Método de Gradiente
#
# 1. **Preferencias**: En lugar de valores Q, el agente usa un vector de preferencias `H` para cada acción. Estas preferencias determinan la probabilidad de seleccionar cada acción.
#
# 2. **Softmax**: Se utiliza `softmax` para convertir las preferencias en probabilidades, de forma que acciones con mayores preferencias sean seleccionadas con mayor frecuencia.
#
# 3. **Actualización de Preferencias**: Las preferencias de las acciones se ajustan después de cada paso, aumentando para la acción seleccionada si produce una recompensa mayor que la media y disminuyendo en caso contrario. Este ajuste crea un "ascenso por gradiente", donde el agente explora las acciones que le generan mejores recompensas.
#
# 4. **Exploración y Explotación**: La selección de acciones se realiza probabilísticamente según `pi`, lo que introduce un balance entre exploración y explotación basado en las probabilidades calculadas.
#
# Este método de gradiente permite que el agente se enfoque en las acciones que han mostrado mayor rendimiento en el pasado, pero también le da la flexibilidad de explorar otras acciones, adaptándose a cambios en el entorno dinámico.

# %%
import numpy as np

def softmax(x):
    return np.exp(x) / np.sum(np.exp(x))

# Parámetros
episodes = 1000  # Número total de episodios de entrenamiento
alpha = 0.618  # Tasa de aprendizaje
H = np.zeros([env.action_space.n])  # Preferencias inicializadas en cero
rewards_per_episode = []

for episode in range(1, episodes + 1):
    done = False
    truncated = False
    G = 0
    state, _ = env.reset()
    pasos = 0
    recompensas = []

    # Inicializa las probabilidades usando softmax
    pi = softmax(H)
    contadorAcciones = 0
    # Bucle de pasos para el episodio actual
    while not done and not truncated:
        # Selección de acción basada en softmax
        action = np.random.choice(env.action_space.n, p=pi)
        contadorAcciones += 1
        
        # Ejecuta la acción en el entorno y observa el nuevo estado y recompensa
        state2, reward, done, truncated, info = env.step(action)
        recompensas.append(reward)
        
        # Acumula la recompensa
        G += reward
        
        # Calcula la recompensa media hasta el momento
        recompensa_media = np.mean(recompensas)
        
        # Actualiza las preferencias de las acciones
        for a in range(env.action_space.n):
            if a == action:
                H[a] += alpha * (reward - recompensa_media) * (1 - pi[a])
            else:
                H[a] -= alpha * (reward - recompensa_media) * pi[a]
        
        # Actualiza las probabilidades usando softmax
        pi = softmax(H)
        
        # Actualiza el estado actual
        state = state2
        pasos += 1

    # Almacenar la recompensa total del episodio
    rewards_per_episode.append(G)

    # Imprimir la recompensa total en episodios específicos (100, 200, 300, etc.)
    if episode % 100 == 0:
        print(f"Recompensa total en el episodio {episode}: {G}")

# El código utiliza las preferencias para ajustar la probabilidad de selección de cada acción,
# logrando así una estrategia de aprendizaje basada en gradiente.
# Out:
# Recompensa total en el episodio 100: -200
# Recompensa total en el episodio 200: -200
# Recompensa total en el episodio 300: -200
# Recompensa total en el episodio 400: -200
# Recompensa total en el episodio 500: -200
# Recompensa total en el episodio 600: -200
# Recompensa total en el episodio 700: -200
# Recompensa total en el episodio 800: -200
# Recompensa total en el episodio 900: -200
# Recompensa total en el episodio 1000: -200

# %%
# Graficar las recompensas acumuladas por episodio
plt.plot(rewards_per_episode)
plt.xlabel('Episodios')
plt.ylabel('Recompensa total')
plt.title('Recompensas Totales por Episodio (Gradiente de Política en Taxi-v3)')
plt.show()

# %%
print(H)
# Out:
# [-0.61068302 -0.79950803 14.6864094  -0.68863645 -6.29019936 -6.29738254]

# %% [markdown]
# ## ¿Por que no funciona para el taxi?
# ### 1. Dependencia de Acciones en Secuencia
# Para completar la tarea en el entorno Taxi, el agente necesita seguir una secuencia específica de acciones: moverse hacia la ubicación del pasajero, recogerlo, moverse al destino y luego dejarlo. Este tipo de entorno es secuencial, donde las acciones tienen que ejecutarse en un orden específico para alcanzar el objetivo.
#
# El método de gradiente no está diseñado para manejar secuencias de acciones de manera efectiva. Debido a que ajusta las preferencias de cada acción sin considerar el contexto de dónde está el taxi o el pasajero, no puede aprender ni reforzar secuencias de acciones específicas. Esto hace que el método tenga dificultades para entender cómo combinar las acciones "mover", "recoger" y "dejar" de manera útil y ordenada, lo que resulta en un comportamiento casi aleatorio en el entorno Taxi.
#
# ### 2. Exploración y Explotación Basada en Probabilidades Globales
# El método de gradiente depende de una probabilidad global para cada acción, ajustada únicamente en función de las recompensas obtenidas. En entornos como Taxi, donde el contexto (es decir, el estado específico) determina qué acción es apropiada, esta estrategia de exploración/explotación global no funciona bien.
#
# En el entorno Taxi, las acciones óptimas dependen del estado actual (ubicación del taxi, pasajero y destino), y no se pueden generalizar a través de todas las situaciones. El método de gradiente no puede adaptarse a esta variabilidad contextual, lo que resulta en un rendimiento deficiente.

# %% [markdown]
# ---
# En la siguiente celda realizaremos la implementación del método de gradiente para una sola partida, en donde se mostrara los valores de `reward` `H` y `pi` en cada paso. Asi podremos observar como el agente aprende muy rapido que las acciones como recoger al pasajero y dejarlo son **"malas"** ya que estas dan penalizaciones de -10 cuando se hace en el momento incorrecto. Por lo que pronto el agente aprendera a no hacer estas acciones y terminara optando por moverse hasta que termine el juego, lo que le lleva a nunca ganar.

# %%
import numpy as np

def softmax(x):
    return np.exp(x) / np.sum(np.exp(x))

# Parámetros
episodes = 1  # Número total de episodios de entrenamiento
alpha = 0.618  # Tasa de aprendizaje
H = np.zeros([env.action_space.n])  # Preferencias inicializadas en cero
rewards_per_episode = []

for episode in range(1, episodes + 1):
    done = False
    truncated = False
    G = 0
    state, _ = env.reset()
    pasos = 0
    recompensas = []

    # Inicializa las probabilidades usando softmax
    pi = softmax(H)
    contadorAcciones = 0
    # Bucle de pasos para el episodio actual
    while not done and not truncated:
        # Selección de acción basada en softmax
        action = np.random.choice(env.action_space.n, p=pi)
        contadorAcciones += 1
        
        # Ejecuta la acción en el entorno y observa el nuevo estado y recompensa
        state2, reward, done, truncated, info = env.step(action)
        # if reward == -1:
        #     reward = 10
        # if reward == -10:
        #     reward = 1
        # if reward == 20:
        #     reward = 100000000
        recompensas.append(reward)
        
        # Acumula la recompensa
        G += reward
        #print(f"recompensa accion {contadorAcciones}: {reward} -- H: {H} -- pi: {pi}")
        
        # Calcula la recompensa media hasta el momento
        recompensa_media = np.mean(recompensas)
        
        # Actualiza las preferencias de las acciones
        for a in range(env.action_space.n):
            if a == action:
                H[a] += alpha * (reward - recompensa_media) * (1 - pi[a])
            else:
                H[a] -= alpha * (reward - recompensa_media) * pi[a]
        
        # Actualiza las probabilidades usando softmax
        pi = softmax(H)

        print(f"recompensa accion {contadorAcciones}: {reward} -- H: {H} -- pi: {pi}")
        
        # Actualiza el estado actual
        state = state2
        pasos += 1

    # Almacenar la recompensa total del episodio
    rewards_per_episode.append(G)

    # Imprimir la recompensa total en episodios específicos (100, 200, 300, etc.)
    if episode % 100 == 0:
        print(f"Recompensa total en el episodio {episode}: {G}")

# El código utiliza las preferencias para ajustar la probabilidad de selección de cada acción,
# logrando así una estrategia de aprendizaje basada en gradiente.
# Out:
# recompensa accion 1: -1 -- H: [0. 0. 0. 0. 0. 0.] -- pi: [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]
# recompensa accion 2: -1 -- H: [0. 0. 0. 0. 0. 0.] -- pi: [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]
# recompensa accion 3: -1 -- H: [0. 0. 0. 0. 0. 0.] -- pi: [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]
# recompensa accion 4: -10 -- H: [ 0.69525  0.69525  0.69525  0.69525  0.69525 -3.47625] -- pi: [0.19938473 0.19938473 0.19938473 0.19938473 0.19938473 0.00307633]
# recompensa accion 5: -10 -- H: [ 1.36063674  1.36063674  1.36063674  1.36063674 -1.97656326 -3.46598368] -- pi: [0.24730745 0.24730745 0.24730745 0.24730745 0.0087884  0.00198181]
# recompensa accion 6: -1 -- H: [ 0.90212873  0.90212873  2.75612873  0.90212873 -1.99285695 -3.46965796] -- pi: [0.10578386 0.10578386 0.67546269 0.10578386 0.00584983 0.00133591]
# recompensa accion 7: -1 -- H: [ 0.73402307  0.73402307  3.27186487  0.73402307 -2.00215316 -3.47178091] -- pi: [0.06356446 0.06356446 0.80423885 0.06356446 0.0041201  0.00094767]
# recompensa accion 8: -1 -- H: [ 0.64563669  0.64563669  3.54407075  0.64563669 -2.00788217 -3.47309865] -- pi: [4.70978844e-02 4.70978844e-02 8.54624462e-01 4.70978844e-02
#  3.31583417e-03 7.66050450e-04]
# recompensa accion 9: -1 -- H: [ 0.5874237   0.5874237   3.72375492  0.5874237  -2.01198054 -3.47404548] -- pi: [3.82983278e-02 3.82983278e-02 8.81599129e-01 3.82983278e-02
#  2.84624902e-03 6.59638745e-04]
# recompensa accion 10: -1 -- H: [ 0.54482064  0.54482064  3.85546405  0.54482064 -2.01514671 -3.47477927] -- pi: [3.27890157e-02 3.27890157e-02 8.98509228e-01 3.27890157e-02
#  2.53482912e-03 5.88895615e-04]
# recompensa accion 11: -1 -- H: [ 0.511662    0.511662    3.9580989   0.511662   -2.01771011 -3.4753748 ] -- pi: [2.89967560e-02 2.89967560e-02 9.10160404e-01 2.89967560e-02
#  2.31130396e-03 5.38023606e-04]
# recompensa accion 12: -1 -- H: [ 0.48478201  0.48478201  4.0413802   0.48478201 -2.01985269 -3.47587355] -- pi: [2.62160733e-02 2.62160733e-02 9.18710352e-01 2.62160733e-02
#  2.14199579e-03 4.99432486e-04]
# recompensa accion 13: -1 -- H: [ 0.46234912  0.46234912  4.11093913  0.46234912 -2.02168558 -3.47630091] -- pi: [2.40828436e-02 2.40828436e-02 9.25273814e-01 2.40828436e-02
#  2.00865432e-03 4.69001024e-04]
# recompensa accion 14: -1 -- H: [ 0.44321358  0.44321358  4.17031442  0.44321358 -2.0232816  -3.47667356] -- pi: [2.23898105e-02 2.23898105e-02 9.30485792e-01 2.23898105e-02
#  1.90048818e-03 4.44288490e-04]
# recompensa accion 15: -1 -- H: [ 0.4266093   0.4266093   4.22186616  0.4266093  -2.024691   -3.47700305] -- pi: [2.10101632e-02 2.10101632e-02 9.34735072e-01 2.10101632e-02
#  1.81068638e-03 4.23752356e-04]
# recompensa accion 16: -1 -- H: [ 0.41200198  0.41200198  4.2672416   0.41200198 -2.02594988 -3.47729766] -- pi: [1.98618670e-02 1.98618670e-02 9.38273305e-01 1.98618670e-02
#  1.73472656e-03 4.06367246e-04]
# recompensa accion 17: -1 -- H: [ 0.39900531  0.39900531  4.30763264  0.39900531 -2.027085   -3.47756357] -- pi: [1.88894486e-02 1.88894486e-02 9.41270749e-01 1.88894486e-02
#  1.66948163e-03 3.91423420e-04]
# recompensa accion 18: -1 -- H: [ 0.38733163  0.38733163  4.34392732  0.38733163 -2.02811674 -3.47780547] -- pi: [1.80540168e-02 1.80540168e-02 9.43846820e-01 1.80540168e-02
#  1.61271618e-03 3.78413070e-04]
# recompensa accion 19: -1 -- H: [ 0.37676148  0.37676148  4.37680353  0.37676148 -2.02906094 -3.47802702] -- pi: [1.73274744e-02 1.73274744e-02 9.46087827e-01 1.73274744e-02
#  1.56278726e-03 3.66962674e-04]
# recompensa accion 20: -1 -- H: [ 0.36712394  0.36712394  4.40678948  0.36712394 -2.02993017 -3.47823112] -- pi: [1.66890009e-02 1.66890009e-02 9.48057748e-01 1.66890009e-02
#  1.51845864e-03 3.56790970e-04]
# recompensa accion 21: -1 -- H: [ 0.35828354  0.35828354  4.43430403  0.35828354 -2.03073452 -3.47842012] -- pi: [1.61228296e-02 1.61228296e-02 9.49805048e-01 1.61228296e-02
#  1.47878115e-03 3.47681864e-04]
# recompensa accion 22: -1 -- H: [ 0.35013125  0.35013125  4.45968442  0.35013125 -2.03148224 -3.47859592] -- pi: [1.56167939e-02 1.56167939e-02 9.51367139e-01 1.56167939e-02
#  1.44301313e-03 3.39466401e-04]
# recompensa accion 23: -1 -- H: [ 0.34257815  0.34257815  4.48320581  0.34257815 -2.03218016 -3.47876011] -- pi: [1.51613497e-02 1.51613497e-02 9.52773374e-01 1.51613497e-02
#  1.41056608e-03 3.32010446e-04]
# recompensa accion 24: -1 -- H: [ 0.33555086  0.33555086  4.50509535  0.33555086 -2.03283396 -3.47891399] -- pi: [1.47489011e-02 1.47489011e-02 9.54047124e-01 1.47489011e-02
#  1.38096669e-03 3.25206055e-04]
# recompensa accion 25: -1 -- H: [ 0.32898819  0.32898819  4.52554255  0.32898819 -2.03344843 -3.4790587 ] -- pi: [1.43733236e-02 1.43733236e-02 9.55207234e-01 1.43733236e-02
#  1.35382963e-03 3.18965310e-04]
# recompensa accion 26: -1 -- H: [ 0.32283862  0.32283862  4.54470696  0.32283862 -2.03402766 -3.47919516] -- pi: [1.40296227e-02 1.40296227e-02 9.56269078e-01 1.40296227e-02
#  1.32883779e-03 3.13215826e-04]
# recompensa accion 27: -1 -- H: [ 0.31705842  0.31705842  4.5627241   0.31705842 -2.03457514 -3.47932421] -- pi: [1.37136821e-02 1.37136821e-02 9.57245329e-01 1.37136821e-02
#  1.30572765e-03 3.07897422e-04]
# recompensa accion 28: -1 -- H: [ 0.31161017  0.31161017  4.57970992  0.31161017 -2.03509389 -3.47944653] -- pi: [1.34220781e-02 1.34220781e-02 9.58146528e-01 1.34220781e-02
#  1.28427828e-03 3.02959625e-04]
# recompensa accion 29: -1 -- H: [ 0.30646164  0.30646164  4.59576433  0.30646164 -2.03558652 -3.47956274] -- pi: [1.31519379e-02 1.31519379e-02 9.58981523e-01 1.31519379e-02
#  1.26430297e-03 2.98359761e-04]
# recompensa accion 30: -1 -- H: [ 0.30158491  0.30158491  4.61097398  0.30158491 -2.03605532 -3.47967338] -- pi: [1.29008329e-02 1.29008329e-02 9.59757797e-01 1.29008329e-02
#  1.24564273e-03 2.94061485e-04]
# recompensa accion 31: -1 -- H: [ 0.29695559  0.29695559  4.62541444  0.29695559 -2.03650231 -3.4797789 ] -- pi: [1.26666948e-02 1.26666948e-02 9.60481721e-01 1.26666948e-02
#  1.22816133e-03 2.90033632e-04]
# recompensa accion 32: -1 -- H: [ 0.29255233  0.29255233  4.63915199  0.29255233 -2.03692925 -3.47987972] -- pi: [1.24477507e-02 1.24477507e-02 9.61158757e-01 1.24477507e-02
#  1.21174123e-03 2.86249317e-04]
# recompensa accion 33: -1 -- H: [ 0.2883563   0.2883563   4.65224502  0.2883563  -2.03733772 -3.47997621] -- pi: [1.22424716e-02 1.22424716e-02 9.61793620e-01 1.22424716e-02
#  1.19628050e-03 2.82685210e-04]
# recompensa accion 34: -1 -- H: [ 0.28435085  0.28435085  4.66474524  0.28435085 -2.03772911 -3.4800687 ] -- pi: [1.20495317e-02 1.20495317e-02 9.62390394e-01 1.20495317e-02
#  1.18169025e-03 2.79320961e-04]
# recompensa accion 35: -1 -- H: [ 0.28052117  0.28052117  4.67669865  0.28052117 -2.03810469 -3.48015748] -- pi: [1.18677751e-02 1.18677751e-02 9.62952643e-01 1.18677751e-02
#  1.16789256e-03 2.76138730e-04]
# recompensa accion 36: -1 -- H: [ 0.27685403  0.27685403  4.68814629  0.27685403 -2.03846556 -3.4802428 ] -- pi: [1.16961894e-02 1.16961894e-02 9.63483490e-01 1.16961894e-02
#  1.15481886e-03 2.73122809e-04]
# recompensa accion 37: -1 -- H: [ 0.27333758  0.27333758  4.69912492  0.27333758 -2.03881276 -3.48032492] -- pi: [1.15338836e-02 1.15338836e-02 9.63985682e-01 1.15338836e-02
#  1.14240851e-03 2.70259303e-04]
# recompensa accion 38: -1 -- H: [ 0.26996119  0.26996119  4.70966764  0.26996119 -2.03914718 -3.48040403] -- pi: [1.13800704e-02 1.13800704e-02 9.64461645e-01 1.13800704e-02
#  1.13060766e-03 2.67535875e-04]
# recompensa accion 39: -1 -- H: [ 0.26671524  0.26671524  4.71980427  0.26671524 -2.03946967 -3.48048034] -- pi: [1.12340514e-02 1.12340514e-02 9.64913536e-01 1.12340514e-02
#  1.11936835e-03 2.64941530e-04]
# recompensa accion 40: -1 -- H: [ 0.26359105  0.26359105  4.72956182  0.26359105 -2.03978096 -3.48055402] -- pi: [1.10952046e-02 1.10952046e-02 9.65343272e-01 1.10952046e-02
#  1.10864769e-03 2.62466433e-04]
# recompensa accion 41: -1 -- H: [ 0.26058074  0.26058074  4.73896478  0.26058074 -2.04008176 -3.48062523] -- pi: [1.09629742e-02 1.09629742e-02 9.65752568e-01 1.09629742e-02
#  1.09840719e-03 2.60101756e-04]
# recompensa accion 42: -1 -- H: [ 0.25767711  0.25767711  4.74803546  0.25767711 -2.04037268 -3.48069412] -- pi: [1.08368620e-02 1.08368620e-02 9.66142962e-01 1.08368620e-02
#  1.08861220e-03 2.57839556e-04]
# recompensa accion 43: -1 -- H: [ 0.25487364  0.25487364  4.7567942   0.25487364 -2.0406543  -3.48076082] -- pi: [1.07164199e-02 1.07164199e-02 9.66515836e-01 1.07164199e-02
#  1.07923147e-03 2.55672657e-04]
# recompensa accion 44: -1 -- H: [ 0.25216434  0.25216434  4.7652596   0.25216434 -2.04092715 -3.48082546] -- pi: [1.06012435e-02 1.06012435e-02 9.66872438e-01 1.06012435e-02
#  1.07023668e-03 2.53594564e-04]
# recompensa accion 45: -1 -- H: [ 0.24954371  0.24954371  4.77344874  0.24954371 -2.04119171 -3.48088815] -- pi: [1.04909674e-02 1.04909674e-02 9.67213896e-01 1.04909674e-02
#  1.06160214e-03 2.51599379e-04]
# recompensa accion 46: -1 -- H: [ 0.24700672  0.24700672  4.78137727  0.24700672 -2.04144844 -3.480949  ] -- pi: [1.03852600e-02 1.03852600e-02 9.67541234e-01 1.03852600e-02
#  1.05330447e-03 2.49681737e-04]
# recompensa accion 47: -1 -- H: [ 0.24454873  0.24454873  4.78905964  0.24454873 -2.04169773 -3.48100809] -- pi: [1.02838198e-02 1.02838198e-02 9.67855382e-01 1.02838198e-02
#  1.04532235e-03 2.47836741e-04]
# recompensa accion 48: -1 -- H: [ 0.24216545  0.24216545  4.79650915  0.24216545 -2.04193999 -3.48106553] -- pi: [1.01863721e-02 1.01863721e-02 9.68157188e-01 1.01863721e-02
#  1.03763628e-03 2.46059913e-04]
# recompensa accion 49: -1 -- H: [ 0.23985294  0.23985294  4.80373812  0.23985294 -2.04217555 -3.48112139] -- pi: [1.00926659e-02 1.00926659e-02 9.68447427e-01 1.00926659e-02
#  1.03022840e-03 2.44347152e-04]
# recompensa accion 50: -1 -- H: [ 0.23760752  0.23760752  4.81075794  0.23760752 -2.04240476 -3.48117575] -- pi: [1.00024716e-02 1.00024716e-02 9.68726808e-01 1.00024716e-02
#  1.02308231e-03 2.42694689e-04]
# recompensa accion 51: -1 -- H: [ 0.23542581  0.23542581  4.81757917  0.23542581 -2.04262791 -3.48122869] -- pi: [9.91557843e-03 9.91557843e-03 9.68995983e-01 9.91557843e-03
#  1.01618293e-03 2.41099060e-04]
# recompensa accion 52: -1 -- H: [ 0.23330464  0.23330464  4.82421165  0.23330464 -2.04284529 -3.48128026] -- pi: [9.83179270e-03 9.83179270e-03 9.69255548e-01 9.83179270e-03
#  1.00951635e-03 2.39557068e-04]
# recompensa accion 53: -1 -- H: [ 0.23124107  0.23124107  4.8306645   0.23124107 -2.04305718 -3.48133054] -- pi: [9.75093610e-03 9.75093610e-03 9.69506056e-01 9.75093610e-03
#  1.00306974e-03 2.38065764e-04]
# recompensa accion 54: -1 -- H: [ 0.22923238  0.22923238  4.83694626  0.22923238 -2.04326381 -3.48137958] -- pi: [9.67284411e-03 9.67284411e-03 9.69748014e-01 9.67284411e-03
#  9.96831224e-04 2.36622418e-04]
# recompensa accion 55: -1 -- H: [ 0.227276    0.227276    4.84306486  0.227276   -2.04346542 -3.48142744] -- pi: [9.59736468e-03 9.59736468e-03 9.69981892e-01 9.59736468e-03
#  9.90789798e-04 2.35224501e-04]
# recompensa accion 56: -1 -- H: [ 0.22536955  0.22536955  4.84902774  0.22536955 -2.04366224 -3.48147417] -- pi: [9.52435711e-03 9.52435711e-03 9.70208124e-01 9.52435711e-03
#  9.84935258e-04 2.33869667e-04]
# recompensa accion 57: -1 -- H: [ 0.2235108   0.2235108   4.85484186  0.2235108  -2.04385446 -3.48151981] -- pi: [9.45369093e-03 9.45369093e-03 9.70427113e-01 9.45369093e-03
#  9.79258117e-04 2.32555733e-04]
# recompensa accion 58: -1 -- H: [ 0.22169765  0.22169765  4.86051374  0.22169765 -2.04404227 -3.48156441] -- pi: [9.38524498e-03 9.38524498e-03 9.70639235e-01 9.38524498e-03
#  9.73749548e-04 2.31280669e-04]
# recompensa accion 59: -1 -- H: [ 0.21992813  0.21992813  4.86604948  0.21992813 -2.04422586 -3.48160802] -- pi: [9.31890662e-03 9.31890662e-03 9.70844836e-01 9.31890662e-03
#  9.68401321e-04 2.30042583e-04]
# recompensa accion 60: -1 -- H: [ 0.21820041  0.21820041  4.87145485  0.21820041 -2.0444054  -3.48165067] -- pi: [9.25457095e-03 9.25457095e-03 9.71044242e-01 9.25457095e-03
#  9.63205759e-04 2.28839707e-04]
# recompensa accion 61: -1 -- H: [ 0.21651274  0.21651274  4.87673524  0.21651274 -2.04458106 -3.4816924 ] -- pi: [9.19214015e-03 9.19214015e-03 9.71237753e-01 9.19214015e-03
#  9.58155683e-04 2.27670391e-04]
# recompensa accion 62: -1 -- H: [ 0.39428284  0.21486349  4.70247639  0.21486349 -2.04475297 -3.48173325] -- pi: [1.29725871e-02 1.08419091e-02 9.63942838e-01 1.08419091e-02
#  1.13179248e-03 2.68964026e-04]
# recompensa accion 63: -1 -- H: [ 0.39199226  0.21294912  4.70884306  0.21294912 -2.04495281 -3.48178074] -- pi: [1.28646214e-02 1.07557218e-02 9.64231888e-01 1.07557218e-02
#  1.12472206e-03 2.67324506e-04]
# recompensa accion 64: -1 -- H: [ 0.38975622  0.21107964  4.71506     0.21107964 -2.0451483  -3.4818272 ] -- pi: [1.27600408e-02 1.06721964e-02 9.64511976e-01 1.06721964e-02
#  1.11785755e-03 2.65732543e-04]
# recompensa accion 65: -1 -- H: [ 0.38757249  0.20925322  4.72113337  0.20925322 -2.04533961 -3.48187268] -- pi: [1.26586768e-02 1.05912016e-02 9.64783545e-01 1.05912016e-02
#  1.11118920e-03 2.64185895e-04]
# recompensa accion 66: -1 -- H: [ 0.38543893  0.20746812  4.72706894  0.20746812 -2.04552689 -3.48191721] -- pi: [1.25603723e-02 1.05126153e-02 9.65047007e-01 1.05126153e-02
#  1.10470792e-03 2.62682465e-04]
# recompensa accion 67: -1 -- H: [ 0.38335353  0.20572271  4.73287218  0.20572271 -2.04571031 -3.48196082] -- pi: [1.24649802e-02 1.04363229e-02 9.65302748e-01 1.04363229e-02
#  1.09840518e-03 2.61220286e-04]
# recompensa accion 68: -1 -- H: [ 0.38131441  0.20401545  4.73854824  0.20401545 -2.04589    -3.48200355] -- pi: [1.23723634e-02 1.03622176e-02 9.65551131e-01 1.03622176e-02
#  1.09227297e-03 2.59797516e-04]
# recompensa accion 69: -1 -- H: [ 0.37931977  0.20234488  4.744102    0.20234488 -2.04606609 -3.48204544] -- pi: [1.22823929e-02 1.02901989e-02 9.65792493e-01 1.02901989e-02
#  1.08630379e-03 2.58412422e-04]
# recompensa accion 70: -1 -- H: [ 0.37736792  0.20070962  4.74953806  0.20070962 -2.04623872 -3.4820865 ] -- pi: [1.21949484e-02 1.02201729e-02 9.66027152e-01 1.02201729e-02
#  1.08049056e-03 2.57063377e-04]
# recompensa accion 71: -1 -- H: [ 0.37545726  0.19910836  4.75486079  0.19910836 -2.04640801 -3.48212678] -- pi: [1.21099165e-02 1.01520511e-02 9.66255406e-01 1.01520511e-02
#  1.07482665e-03 2.55748849e-04]
# recompensa accion 72: -1 -- H: [ 0.37358628  0.19753987  4.76007433  0.19753987 -2.04657407 -3.48216629] -- pi: [1.20271910e-02 1.00857506e-02 9.66477535e-01 1.00857506e-02
#  1.06930580e-03 2.54467394e-04]
# recompensa accion 73: -1 -- H: [ 0.37175353  0.19600297  4.7651826   0.19600297 -2.04673701 -3.48220507] -- pi: [1.19466718e-02 1.00211931e-02 9.66693802e-01 1.00211931e-02
#  1.06392211e-03 2.53217652e-04]
# recompensa accion 74: -1 -- H: [ 0.36995766  0.19449654  4.77018934  0.19449654 -2.04689694 -3.48224313] -- pi: [1.18682647e-02 9.95830514e-03 9.66904457e-01 9.95830514e-03
#  1.05867000e-03 2.51998339e-04]
# recompensa accion 75: -1 -- H: [ 0.36819736  0.19301952  4.77509807  0.19301952 -2.04705397 -3.48228051] -- pi: [1.17918811e-02 9.89701724e-03 9.67109732e-01 9.89701724e-03
#  1.05354423e-03 2.50808241e-04]
# recompensa accion 76: -1 -- H: [ 0.3664714   0.19157091  4.77991216  0.19157091 -2.04720817 -3.48231722] -- pi: [1.17174373e-02 9.83726393e-03 9.67309849e-01 9.83726393e-03
#  1.04853980e-03 2.49646212e-04]
# recompensa accion 77: -1 -- H: [ 0.36477861  0.19014975  4.78463483  0.19014975 -2.04735965 -3.48235329] -- pi: [1.16448543e-02 9.77898336e-03 9.67505016e-01 9.77898336e-03
#  1.04365203e-03 2.48511165e-04]
# recompensa accion 78: -1 -- H: [ 0.36311787  0.18875512  4.78926911  0.18875512 -2.04750849 -3.48238873] -- pi: [1.15740574e-02 9.72211707e-03 9.67695430e-01 9.72211707e-03
#  1.03887645e-03 2.47402073e-04]
# recompensa accion 79: -1 -- H: [ 0.36148813  0.18738614  4.79381792  0.18738614 -2.04765478 -3.48242356] -- pi: [1.15049760e-02 9.66660972e-03 9.67881278e-01 9.66660972e-03
#  1.03420884e-03 2.46317960e-04]
# recompensa accion 80: -1 -- H: [ 0.35988836  0.186042    4.79828403  0.186042   -2.04779858 -3.48245781] -- pi: [1.14375434e-02 9.61240894e-03 9.68062736e-01 9.61240894e-03
#  1.02964520e-03 2.45257904e-04]
# recompensa accion 81: -1 -- H: [ 0.35831761  0.1847219   4.80267008  0.1847219  -2.04793999 -3.4824915 ] -- pi: [1.13716963e-02 9.55946509e-03 9.68239971e-01 9.55946509e-03
#  1.02518172e-03 2.44221026e-04]
# recompensa accion 82: -1 -- H: [ 0.35677494  0.18342507  4.8069786   0.18342507 -2.04807906 -3.48252463] -- pi: [1.13073746e-02 9.50773108e-03 9.68413142e-01 9.50773108e-03
#  1.02081480e-03 2.43206492e-04]
# recompensa accion 83: -1 -- H: [ 0.35525948  0.18215081  4.811212    0.18215081 -2.04821588 -3.48255722] -- pi: [1.12445215e-02 9.45716224e-03 9.68582399e-01 9.45716224e-03
#  1.01654099e-03 2.42213511e-04]
# recompensa accion 84: -1 -- H: [ 0.35377038  0.18089841  4.81537259  0.18089841 -2.0483505  -3.4825893 ] -- pi: [1.11830830e-02 9.40771613e-03 9.68747886e-01 9.40771613e-03
#  1.01235704e-03 2.41241327e-04]
# recompensa accion 85: -1 -- H: [ 0.35230685  0.17966722  4.81946257  0.17966722 -2.04848298 -3.48262087] -- pi: [1.11230077e-02 9.35935241e-03 9.68909738e-01 9.35935241e-03
#  1.00825983e-03 2.40289223e-04]
# recompensa accion 86: -1 -- H: [ 0.3508681   0.17845659  4.82348406  0.17845659 -2.0486134  -3.48265195] -- pi: [1.10642469e-02 9.31203272e-03 9.69068085e-01 9.31203272e-03
#  1.00424640e-03 2.39356516e-04]
# recompensa accion 87: -1 -- H: [ 0.3494534   0.17726594  4.82743908  0.17726594 -2.04874181 -3.48268256] -- pi: [1.10067540e-02 9.26572054e-03 9.69223048e-01 9.26572054e-03
#  1.00031393e-03 2.38442553e-04]
# recompensa accion 88: -1 -- H: [ 0.34806205  0.30250376  4.70492048  0.17609467 -2.04886825 -3.4827127 ] -- pi: [1.23576048e-02 1.18072454e-02 9.64037390e-01 1.04051853e-02
#  1.12450321e-03 2.68071084e-04]
# recompensa accion 89: -1 -- H: [ 0.34651749  0.30102799  4.7094154   0.17479414 -2.0490088  -3.4827462 ] -- pi: [1.22857914e-02 1.17394378e-02 9.64241073e-01 1.03472427e-02
#  1.11953916e-03 2.66916271e-04]
# recompensa accion 90: -1 -- H: [ 0.34499896  0.29957699  4.7138352   0.17351522 -2.04914718 -3.48277919] -- pi: [1.22155735e-02 1.16731307e-02 9.64440263e-01 1.02905697e-02
#  1.11467793e-03 2.65785283e-04]
# recompensa accion 91: -1 -- H: [ 0.34350571  0.29815005  4.71818209  0.17225728 -2.04928344 -3.48281168] -- pi: [1.21468944e-02 1.16082712e-02 9.64635119e-01 1.02351217e-02
#  1.10991606e-03 2.64677320e-04]
# recompensa accion 92: -1 -- H: [ 0.34203699  0.29674646  4.72245816  0.17101972 -2.04941764 -3.48284369] -- pi: [1.20797004e-02 1.15448085e-02 9.64825793e-01 1.01808562e-02
#  1.10525022e-03 2.63591614e-04]
# recompensa accion 93: -1 -- H: [ 0.3405921   0.29536555  4.72666545  0.16980196 -2.04954985 -3.48287522] -- pi: [1.20139399e-02 1.14826945e-02 9.65012428e-01 1.01277328e-02
#  1.10067726e-03 2.62527435e-04]
# recompensa accion 94: -1 -- H: [ 0.33917037  0.29400668  4.7308059   0.16860344 -2.0496801  -3.48290628] -- pi: [1.19495640e-02 1.14218833e-02 9.65195162e-01 1.00757129e-02
#  1.09619416e-03 2.61484085e-04]
# recompensa accion 95: -1 -- H: [ 0.33777114  0.29266924  4.73488136  0.16742363 -2.04980846 -3.4829369 ] -- pi: [1.18865261e-02 1.13623311e-02 9.65374124e-01 1.00247595e-02
#  1.09179803e-03 2.60460896e-04]
# recompensa accion 96: -1 -- H: [ 0.33639379  0.29135263  4.73889363  0.16626201 -2.04993497 -3.48296708] -- pi: [1.18247816e-02 1.13039961e-02 9.65549441e-01 9.97483760e-03
#  1.08748610e-03 2.59457230e-04]
# recompensa accion 97: -1 -- H: [ 0.33503771  0.29005628  4.74284444  0.16511809 -2.05005968 -3.48299684] -- pi: [1.17642879e-02 1.12468384e-02 9.65721232e-01 9.92591351e-03
#  1.08325575e-03 2.58472477e-04]
# recompensa accion 98: -1 -- H: [ 0.33370235  0.28877965  4.74673543  0.1639914  -2.05018264 -3.48302618] -- pi: [1.17050044e-02 1.11908197e-02 9.65889610e-01 9.87795514e-03
#  1.07910445e-03 2.57506053e-04]
# recompensa accion 99: -1 -- H: [ 0.33238713  0.28752221  4.75056819  0.16288147 -2.0503039  -3.48305511] -- pi: [1.16468922e-02 1.11359037e-02 9.66054685e-01 9.83093179e-03
#  1.07502977e-03 2.56557399e-04]
# recompensa accion 100: -1 -- H: [ 0.33109153  0.28628345  4.75434427  0.16178788 -2.05042348 -3.48308365] -- pi: [1.15899142e-02 1.10820554e-02 9.66216561e-01 9.78481409e-03
#  1.07102940e-03 2.55625977e-04]
# recompensa accion 101: -1 -- H: [ 0.32981503  0.28506289  4.75806513  0.16071019 -2.05054144 -3.4831118 ] -- pi: [1.15340347e-02 1.10292415e-02 9.66375337e-01 9.73957389e-03
#  1.06710111e-03 2.54711275e-04]
# recompensa accion 102: -1 -- H: [ 0.32855715  0.28386005  4.7617322   0.15964801 -2.05065782 -3.48313958] -- pi: [1.14792199e-02 1.09774299e-02 9.66531110e-01 9.69518427e-03
#  1.06324278e-03 2.53812799e-04]
# recompensa accion 103: -1 -- H: [ 0.32731739  0.28267449  4.76534684  0.15860093 -2.05077265 -3.48316699] -- pi: [1.14254369e-02 1.09265901e-02 9.66683971e-01 9.65161942e-03
#  1.05945237e-03 2.52930077e-04]
# recompensa accion 104: -1 -- H: [ 0.32609531  0.28150577  4.76891037  0.15756858 -2.05088597 -3.48319405] -- pi: [1.13726546e-02 1.08766927e-02 9.66834008e-01 9.60885459e-03
#  1.05572790e-03 2.52062654e-04]
# recompensa accion 105: -1 -- H: [ 0.32489046  0.28035346  4.77242407  0.15655059 -2.05099782 -3.48322075] -- pi: [1.13208430e-02 1.08277095e-02 9.66981304e-01 9.56686604e-03
#  1.05206749e-03 2.51210094e-04]
# recompensa accion 106: -1 -- H: [ 0.32370241  0.27921716  4.77588917  0.15554661 -2.05110823 -3.48324712] -- pi: [1.12699734e-02 1.07796136e-02 9.67125941e-01 9.52563100e-03
#  1.04846934e-03 2.50371978e-04]
# recompensa accion 107: -1 -- H: [ 0.32253075  0.27809648  4.77930684  0.1545563  -2.05121723 -3.48327314] -- pi: [1.12200181e-02 1.07323790e-02 9.67267996e-01 9.48512760e-03
#  1.04493171e-03 2.49547903e-04]
# recompensa accion 108: -1 -- H: [ 0.32137509  0.27699105  4.78267824  0.15357933 -2.05132486 -3.48329885] -- pi: [1.11709506e-02 1.06859807e-02 9.67407543e-01 9.44533483e-03
#  1.04145291e-03 2.48737482e-04]
# recompensa accion 109: -1 -- H: [ 0.32023504  0.27590049  4.78600446  0.15261538 -2.05143114 -3.48332423] -- pi: [1.11227455e-02 1.06403950e-02 9.67544655e-01 9.40623252e-03
#  1.03803134e-03 2.47940343e-04]
# recompensa accion 110: -1 -- H: [ 0.31911023  0.27482446  4.78928658  0.15166416 -2.05153611 -3.48334931] -- pi: [1.10753784e-02 1.05955988e-02 9.67679400e-01 9.36780126e-03
#  1.03466545e-03 2.47156126e-04]
# recompensa accion 111: -1 -- H: [ 0.31800029  0.27376261  4.79252563  0.15072535 -2.05163981 -3.48337408] -- pi: [1.10288256e-02 1.05515700e-02 9.67811844e-01 9.33002239e-03
#  1.03135375e-03 2.46384486e-04]
# recompensa accion 112: -1 -- H: [ 0.31690489  0.27271461  4.7957226   0.14979868 -2.05174224 -3.48339855] -- pi: [1.09830647e-02 1.05082874e-02 9.67942050e-01 9.29287798e-03
#  1.02809480e-03 2.45625090e-04]
# recompensa accion 113: -1 -- H: [ 0.31582369  0.27168015  4.79887847  0.14888387 -2.05184345 -3.48342273] -- pi: [1.09380738e-02 1.04657305e-02 9.68070080e-01 9.25635073e-03
#  1.02488721e-03 2.44877618e-04]
# recompensa accion 114: -1 -- H: [ 0.31475637  0.27065891  4.80199416  0.14798064 -2.05194346 -3.48344662] -- pi: [1.08938319e-02 1.04238797e-02 9.68195993e-01 9.22042402e-03
#  1.02172965e-03 2.44141760e-04]
# recompensa accion 115: -1 -- H: [ 0.3137026   0.26965061  4.80507057  0.14708875 -2.05204229 -3.48347024] -- pi: [1.08503190e-02 1.03827159e-02 9.68319845e-01 9.18508183e-03
#  1.01862084e-03 2.43417219e-04]
# recompensa accion 116: -1 -- H: [ 0.31266209  0.26865494  4.80810859  0.14620793 -2.05213997 -3.48349358] -- pi: [1.08075156e-02 1.03422208e-02 9.68441692e-01 9.15030871e-03
#  1.01555953e-03 2.42703707e-04]
# recompensa accion 117: -1 -- H: [ 0.31163455  0.26767163  4.81110906  0.14533795 -2.05223653 -3.48351666] -- pi: [1.07654030e-02 1.03023770e-02 9.68561585e-01 9.11608978e-03
#  1.01254452e-03 2.42000946e-04]
# recompensa accion 118: -1 -- H: [ 0.31061968  0.26670042  4.81407279  0.14447856 -2.05233198 -3.48353947] -- pi: [1.07239630e-02 1.02631674e-02 9.68679576e-01 9.08241069e-03
#  1.00957466e-03 2.41308669e-04]
# recompensa accion 119: -1 -- H: [ 0.30961722  0.26574102  4.81700059  0.14362955 -2.05242635 -3.48356203] -- pi: [1.06831784e-02 1.02245756e-02 9.68795713e-01 9.04925759e-03
#  1.00664882e-03 2.40626617e-04]
# recompensa accion 120: -1 -- H: [ 0.30862689  0.26479321  4.81989323  0.14279068 -2.05251967 -3.48358433] -- pi: [1.06430323e-02 1.01865859e-02 9.68910044e-01 9.01661714e-03
#  1.00376595e-03 2.39954540e-04]
# recompensa accion 121: -1 -- H: [ 0.30764843  0.26385671  4.82275145  0.14196175 -2.05261195 -3.48360639] -- pi: [1.06035084e-02 1.01491830e-02 9.69022615e-01 8.98447643e-03
#  1.00092498e-03 2.39292196e-04]
# recompensa accion 122: -1 -- H: [ 0.3066816   0.26293131  4.82557598  0.14114254 -2.05270322 -3.48362821] -- pi: [1.05645913e-02 1.01123522e-02 9.69133469e-01 8.95282301e-03
#  9.98124906e-04 2.38639353e-04]
# recompensa accion 123: -1 -- H: [ 0.30572615  0.26201676  4.82836752  0.14033286 -2.05279349 -3.48364979] -- pi: [1.05262656e-02 1.00760793e-02 9.69242650e-01 8.92164486e-03
#  9.95364765e-04 2.37995784e-04]
# recompensa accion 124: -1 -- H: [ 0.30478184  0.26111284  4.83112675  0.1395325  -2.05288278 -3.48367114] -- pi: [1.04885170e-02 1.00403506e-02 9.69350197e-01 8.89093035e-03
#  9.92643609e-04 2.37361271e-04]
# recompensa accion 125: -1 -- H: [ 0.30384845  0.26021932  4.83385434  0.13874128 -2.05297112 -3.48369227] -- pi: [1.04513312e-02 1.00051527e-02 9.69456152e-01 8.86066825e-03
#  9.89960527e-04 2.36735603e-04]
# recompensa accion 126: -1 -- H: [ 0.30292574  0.25933601  4.83655092  0.13795901 -2.05305852 -3.48371317] -- pi: [1.04146946e-02 9.97047293e-03 9.69560552e-01 8.83084770e-03
#  9.87314636e-04 2.36118575e-04]
# recompensa accion 127: -1 -- H: [ 0.30201351  0.25846269  4.83921713  0.13718551 -2.053145   -3.48373385] -- pi: [1.03785940e-02 9.93629881e-03 9.69663434e-01 8.80145820e-03
#  9.84705083e-04 2.35509990e-04]
# recompensa accion 128: -1 -- H: [ 0.30111155  0.25759917  4.84185357  0.13642061 -2.05323057 -3.48375432] -- pi: [1.03430168e-02 9.90261835e-03 9.69764835e-01 8.77248958e-03
#  9.82131040e-04 2.34909656e-04]
# recompensa accion 129: -1 -- H: [ 0.30021964  0.25674524  4.84446082  0.13566413 -2.05331526 -3.48377457] -- pi: [1.03079505e-02 9.86941995e-03 9.69864788e-01 8.74393201e-03
#  9.79591707e-04 2.34317387e-04]
# recompensa accion 130: -1 -- H: [ 0.2993376   0.25590072  4.84703947  0.13491592 -2.05339909 -3.48379462] -- pi: [1.02733832e-02 9.83669238e-03 9.69963329e-01 8.71577598e-03
#  9.77086307e-04 2.33733003e-04]
# recompensa accion 131: -1 -- H: [ 0.29846523  0.25506543  4.84959007  0.13417581 -2.05348206 -3.48381447] -- pi: [1.02393034e-02 9.80442477e-03 9.70060489e-01 8.68801226e-03
#  9.74614088e-04 2.33156329e-04]
# recompensa accion 132: -1 -- H: [ 0.29760233  0.25423918  4.85211315  0.13344365 -2.05356419 -3.48383412] -- pi: [1.02056999e-02 9.77260657e-03 9.70156300e-01 8.66063193e-03
#  9.72174321e-04 2.32587198e-04]
# recompensa accion 133: -1 -- H: [ 0.29674874  0.25342181  4.85460925  0.13271928 -2.0536455  -3.48385357] -- pi: [1.01725618e-02 9.74122760e-03 9.70250793e-01 8.63362633e-03
#  9.69766299e-04 2.32025445e-04]
# recompensa accion 134: -1 -- H: [ 0.29590426  0.25261314  4.85707888  0.13200256 -2.05372601 -3.48387284] -- pi: [1.01398786e-02 9.71027796e-03 9.70343996e-01 8.60698709e-03
#  9.67389336e-04 2.31470910e-04]
# recompensa accion 135: -1 -- H: [ 0.29506874  0.25181302  4.85952253  0.13129334 -2.05380572 -3.48389191] -- pi: [1.01076402e-02 9.67974807e-03 9.70435939e-01 8.58070609e-03
#  9.65042767e-04 2.30923441e-04]
# recompensa accion 136: -1 -- H: [ 0.29424199  0.25102127  4.8619407   0.13059149 -2.05388466 -3.4839108 ] -- pi: [1.00758367e-02 9.64962864e-03 9.70526650e-01 8.55477543e-03
#  9.62725945e-04 2.30382886e-04]
# recompensa accion 137: -1 -- H: [ 0.29342386  0.25023775  4.86433385  0.12989687 -2.05396283 -3.4839295 ] -- pi: [1.00444586e-02 9.61991068e-03 9.70616156e-01 8.52918749e-03
#  9.60438246e-04 2.29849100e-04]
# recompensa accion 138: -1 -- H: [ 0.29261419  0.2494623   4.86670244  0.12920934 -2.05404025 -3.48394803] -- pi: [1.00134964e-02 9.59058544e-03 9.70704482e-01 8.50393485e-03
#  9.58179059e-04 2.29321944e-04]
# recompensa accion 139: -1 -- H: [ 0.29181282  0.24869478  4.86904693  0.12852878 -2.05411693 -3.48396638] -- pi: [9.98294138e-03 9.56164445e-03 9.70791655e-01 8.47901032e-03
#  9.55947793e-04 2.28801278e-04]
# recompensa accion 140: -1 -- H: [ 0.29101961  0.24793503  4.87136774  0.12785507 -2.05419288 -3.48398456] -- pi: [9.95278464e-03 9.53307949e-03 9.70877698e-01 8.45440692e-03
#  9.53743876e-04 2.28286971e-04]
# recompensa accion 141: -1 -- H: [ 0.2902344   0.24718294  4.8736653   0.12718807 -2.05426813 -3.48400257] -- pi: [9.92301773e-03 9.50488257e-03 9.70962636e-01 8.43011786e-03
#  9.51566749e-04 2.27778893e-04]
# recompensa accion 142: -1 -- H: [ 0.28945705  0.24643834  4.87594003  0.12652767 -2.05434267 -3.48402042] -- pi: [9.89363244e-03 9.47704594e-03 9.71046492e-01 8.40613658e-03
#  9.49415870e-04 2.27276918e-04]
# recompensa accion 143: -1 -- H: [ 0.28868742  0.24570112  4.87819233  0.12587375 -2.05441653 -3.4840381 ] -- pi: [9.86462078e-03 9.44956207e-03 9.71129289e-01 8.38245669e-03
#  9.47290713e-04 2.26780924e-04]
# recompensa accion 144: -1 -- H: [ 0.28792538  0.24497114  4.88042259  0.12522621 -2.05448971 -3.48405562] -- pi: [9.83597496e-03 9.42242365e-03 9.71211048e-01 8.35907196e-03
#  9.45190765e-04 2.26290792e-04]
# recompensa accion 145: -1 -- H: [ 0.28717079  0.24424828  4.8826312   0.12458492 -2.05456222 -3.48407298] -- pi: [9.80768747e-03 9.39562359e-03 9.71291791e-01 8.33597637e-03
#  9.43115528e-04 2.25806407e-04]
# recompensa accion 146: -1 -- H: [ 0.28642352  0.24353241  4.88481853  0.12394979 -2.05463408 -3.48409018] -- pi: [9.77975096e-03 9.36915496e-03 9.71371538e-01 8.31316405e-03
#  9.41064517e-04 2.25327656e-04]
# recompensa accion 147: -1 -- H: [ 0.28568346  0.24282341  4.88698495  0.12332071 -2.05470529 -3.48410723] -- pi: [9.75215833e-03 9.34301108e-03 9.71450310e-01 8.29062930e-03
#  9.39037262e-04 2.24854431e-04]
# recompensa accion 148: -1 -- H: [ 0.28495046  0.24212117  4.8891308   0.12269756 -2.05477587 -3.48412413] -- pi: [9.72490263e-03 9.31718540e-03 9.71528125e-01 8.26836658e-03
#  9.37033303e-04 2.24386623e-04]
# recompensa accion 149: -1 -- H: [ 0.28422442  0.24142557  4.81659873  0.19673798 -2.05484583 -3.48414089] -- pi: [1.04196078e-02 9.98306884e-03 9.68805336e-01 9.54677073e-03
#  1.00462983e-03 2.40586421e-04]
# recompensa accion 150: -1 -- H: [ 0.28345171  0.24068523  4.81891213  0.19603    -2.05492033 -3.48415873] -- pi: [1.03884809e-02 9.95356829e-03 9.68896706e-01 9.51886745e-03
#  1.00232826e-03 2.40048847e-04]
# recompensa accion 151: -1 -- H: [ 0.2826864   0.23995196  4.82120347  0.19532875 -2.05499417 -3.48417641] -- pi: [1.03577400e-02 9.92443235e-03 9.68986949e-01 9.49130791e-03
#  1.00005350e-03 2.39517513e-04]
# recompensa accion 152: -1 -- H: [ 0.28192837  0.23922565  4.82347314  0.19463414 -2.05506736 -3.48419394] -- pi: [1.03273774e-02 9.89565370e-03 9.69076086e-01 9.46408520e-03
#  9.97805046e-04 2.38992299e-04]
# recompensa accion 153: -1 -- H: [ 0.28117751  0.23850618  4.82572149  0.19394604 -2.0551399  -3.48421132] -- pi: [1.02973854e-02 9.86722519e-03 9.69164141e-01 9.43719263e-03
#  9.95582384e-04 2.38473088e-04]
# recompensa accion 154: -1 -- H: [ 0.35266746  0.23779343  4.75571511  0.19326436 -2.05521182 -3.48422854] -- pi: [1.18265967e-02 1.05431560e-02 9.66226818e-01 1.00839783e-02
#  1.06446431e-03 2.54986406e-04]
# recompensa accion 155: -1 -- H: [ 0.35181869  0.23703677  4.75813894  0.19254065 -2.05528821 -3.48424684] -- pi: [1.17892189e-02 1.05108025e-02 9.66330302e-01 1.00533652e-02
#  1.06191996e-03 2.54391699e-04]
# recompensa accion 156: -1 -- H: [ 0.35097803  0.23628727  4.76053985  0.19182377 -2.05536394 -3.48426498] -- pi: [1.17523080e-02 1.04788494e-02 9.66432504e-01 1.00231297e-02
#  1.05940526e-03 2.53803897e-04]
# recompensa accion 157: -1 -- H: [ 0.35014534  0.23554481  4.76291822  0.1911136  -2.055439   -3.48428297] -- pi: [1.17158547e-02 1.04472887e-02 9.66533450e-01 9.99326420e-03
#  1.05691965e-03 2.53222868e-04]
# recompensa accion 158: -1 -- H: [ 0.34932048  0.23480926  4.76527443  0.19041002 -2.05551341 -3.48430079] -- pi: [1.16798498e-02 1.04161126e-02 9.66633165e-01 9.96376146e-03
#  1.05446257e-03 2.52648481e-04]
# recompensa accion 159: -1 -- H: [ 0.34850333  0.23408053  4.76760885  0.18971294 -2.05558718 -3.48431847] -- pi: [1.16442844e-02 1.03853135e-02 9.66731674e-01 9.93461432e-03
#  1.05203348e-03 2.52080613e-04]
# recompensa accion 160: -1 -- H: [ 0.34769377  0.23335849  4.76992183  0.18902223 -2.05566033 -3.484336  ] -- pi: [1.16091499e-02 1.03548841e-02 9.66828999e-01 9.90581581e-03
#  1.04963185e-03 2.51519141e-04]
# recompensa accion 161: -1 -- H: [ 0.34689165  0.23264304  4.77221372  0.18833781 -2.05573285 -3.48435337] -- pi: [1.15744378e-02 1.03248170e-02 9.66925165e-01 9.87735918e-03
#  1.04725717e-03 2.50963945e-04]
# recompensa accion 162: -1 -- H: [ 0.34609687  0.23193407  4.77448486  0.18765956 -2.05580476 -3.48437061] -- pi: [1.15401400e-02 1.02951054e-02 9.67020193e-01 9.84923784e-03
#  1.04490895e-03 2.50414911e-04]
# recompensa accion 163: -1 -- H: [ 0.34530931  0.23123148  4.77673558  0.1869874  -2.05587607 -3.4843877 ] -- pi: [1.15062483e-02 1.02657425e-02 9.67114105e-01 9.82144540e-03
#  1.04258670e-03 2.49871925e-04]
# recompensa accion 164: -1 -- H: [ 0.34452885  0.23053516  4.77896621  0.18632121 -2.05594679 -3.48440464] -- pi: [1.14727551e-02 1.02367215e-02 9.67206923e-01 9.79397561e-03
#  1.04028994e-03 2.49334877e-04]
# recompensa accion 165: -1 -- H: [ 0.34375538  0.22984502  4.78117706  0.18566092 -2.05601692 -3.48442145] -- pi: [1.14396527e-02 1.02080361e-02 9.67298667e-01 9.76682239e-03
#  1.03801821e-03 2.48803660e-04]
# recompensa accion 166: -1 -- H: [ 0.34298879  0.22916095  4.78336844  0.18500643 -2.05608648 -3.48443813] -- pi: [1.14069338e-02 1.01796799e-02 9.67389357e-01 9.73997981e-03
#  1.03577106e-03 2.48278169e-04]
# recompensa accion 167: -1 -- H: [ 0.34222896  0.22848288  4.78554066  0.18435764 -2.05615548 -3.48445467] -- pi: [1.13745913e-02 1.01516469e-02 9.67479013e-01 9.71344211e-03
#  1.03354805e-03 2.47758303e-04]
# recompensa accion 168: -1 -- H: [ 0.3414758   0.22781069  4.78769402  0.18371447 -2.05622391 -3.48447107] -- pi: [1.13426180e-02 1.01239310e-02 9.67567655e-01 9.68720367e-03
#  1.03134876e-03 2.47243960e-04]
# recompensa accion 169: -1 -- H: [ 0.3407292   0.22714431  4.78982879  0.18307684 -2.0562918  -3.48448734] -- pi: [1.13110071e-02 1.00965264e-02 9.67655300e-01 9.66125900e-03
#  1.02917276e-03 2.46735045e-04]
# recompensa accion 170: -1 -- H: [ 0.33998906  0.22648364  4.79194528  0.18244465 -2.05635914 -3.48450349] -- pi: [1.12797521e-02 1.00694275e-02 9.67741967e-01 9.63560275e-03
#  1.02701965e-03 2.46231463e-04]
# recompensa accion 171: -1 -- H: [ 0.33925528  0.2258286   4.79404375  0.18181783 -2.05642595 -3.48451951] -- pi: [1.12488464e-02 1.00426287e-02 9.67827673e-01 9.61022971e-03
#  1.02488903e-03 2.45733120e-04]
# recompensa accion 172: -1 -- H: [ 0.33852777  0.2251791   4.79612448  0.18119629 -2.05649224 -3.4845354 ] -- pi: [1.12182837e-02 1.00161245e-02 9.67912436e-01 9.58513481e-03
#  1.02278051e-03 2.45239928e-04]
# recompensa accion 173: -1 -- H: [ 0.33780643  0.22453506  4.79818772  0.18057996 -2.056558   -3.48455117] -- pi: [1.11880578e-02 9.98990986e-03 9.67996274e-01 9.56031308e-03
#  1.02069372e-03 2.44751797e-04]
# recompensa accion 174: -1 -- H: [ 0.33709117  0.22389639  4.80023376  0.17996876 -2.05662326 -3.48456682] -- pi: [1.11581627e-02 9.96397949e-03 9.68079201e-01 9.53575968e-03
#  1.01862827e-03 2.44268642e-04]
# recompensa accion 175: -1 -- H: [ 0.33638189  0.22326302  4.80226282  0.17936261 -2.05668801 -3.48458234] -- pi: [1.11285926e-02 9.93832841e-03 9.68161235e-01 9.51146990e-03
#  1.01658382e-03 2.43790378e-04]
# recompensa accion 176: -1 -- H: [ 0.33567851  0.22263488  4.80427518  0.17876145 -2.05675226 -3.48459775] -- pi: [1.10993416e-02 9.91295172e-03 9.68242391e-01 9.48743912e-03
#  1.01456000e-03 2.43316924e-04]
# recompensa accion 177: -1 -- H: [ 0.33498095  0.22201187  4.80627106  0.17816518 -2.05681602 -3.48461304] -- pi: [1.10704043e-02 9.88784466e-03 9.68322684e-01 9.46366286e-03
#  1.01255648e-03 2.42848199e-04]
# recompensa accion 178: -1 -- H: [ 0.33428911  0.22139394  4.74575634  0.24006814 -2.0568793  -3.48462822] -- pi: [1.17223592e-02 1.04709304e-02 9.65808221e-01 1.06683039e-02
#  1.07286179e-03 2.57324004e-04]
# recompensa accion 179: -1 -- H: [ 0.33356062  0.22074322  4.74788119  0.23940516 -2.05694597 -3.48464421] -- pi: [1.16900697e-02 1.04429002e-02 9.65900002e-01 1.06396147e-02
#  1.07061489e-03 2.56798103e-04]
# recompensa accion 180: -1 -- H: [ 0.33283817  0.22009785  4.74998857  0.23874763 -2.05701214 -3.48466008] -- pi: [1.16581313e-02 1.04151719e-02 9.65990793e-01 1.06112351e-02
#  1.06839080e-03 2.56277522e-04]
# recompensa accion 181: -1 -- H: [ 0.33212168  0.21945775  4.75207873  0.23809548 -2.0570778  -3.48467583] -- pi: [1.16265378e-02 1.03877403e-02 9.66080611e-01 1.05831597e-02
#  1.06618915e-03 2.55762172e-04]
# recompensa accion 182: -1 -- H: [ 0.33141106  0.21882284  4.75415191  0.23744862 -2.05714297 -3.48469147] -- pi: [1.15952833e-02 1.03606003e-02 9.66169472e-01 1.05553830e-02
#  1.06400956e-03 2.55251965e-04]
# recompensa accion 183: -1 -- H: [ 0.33070622  0.21819305  4.75620836  0.236807   -2.05720764 -3.48470698] -- pi: [1.15643617e-02 1.03337469e-02 9.66257393e-01 1.05279001e-02
#  1.06185167e-03 2.54746819e-04]
# recompensa accion 184: -1 -- H: [ 0.33000707  0.21756831  4.75824833  0.23617052 -2.05727184 -3.48472238] -- pi: [1.15337674e-02 1.03071751e-02 9.66344390e-01 1.05007058e-02
#  1.05971512e-03 2.54246649e-04]
# recompensa accion 185: -1 -- H: [ 0.32931355  0.21694854  4.76027203  0.23553911 -2.05733556 -3.48473767] -- pi: [1.15034948e-02 1.02808802e-02 9.66430479e-01 1.04737953e-02
#  1.05759956e-03 2.53751374e-04]
# recompensa accion 186: -1 -- H: [ 0.32862557  0.21633368  4.7622797   0.23491271 -2.05739881 -3.48475285] -- pi: [1.14735385e-02 1.02548575e-02 9.66515675e-01 1.04471637e-02
#  1.05550466e-03 2.53260916e-04]
# recompensa accion 187: -1 -- H: [ 0.32794305  0.21572365  4.76427157  0.23429124 -2.0574616  -3.48476791] -- pi: [1.14438930e-02 1.02291024e-02 9.66599993e-01 1.04208064e-02
#  1.05343008e-03 2.52775198e-04]
# recompensa accion 188: -1 -- H: [ 0.32726591  0.21511839  4.76624786  0.23367464 -2.05752393 -3.48478287] -- pi: [1.14145532e-02 1.02036104e-02 9.66683448e-01 1.03947188e-02
#  1.05137549e-03 2.52294143e-04]
# recompensa accion 189: -1 -- H: [ 0.32659408  0.21451784  4.76820877  0.23306284 -2.05758581 -3.48479772] -- pi: [1.13855140e-02 1.01783773e-02 9.66766054e-01 1.03688965e-02
#  1.04934058e-03 2.51817677e-04]
# recompensa accion 190: -1 -- H: [ 0.32592749  0.21392192  4.71160717  0.29100314 -2.05764725 -3.48481246] -- pi: [1.20095816e-02 1.07370376e-02 9.64282665e-01 1.15973943e-02
#  1.10752751e-03 2.65793615e-04]
# recompensa accion 191: -1 -- H: [ 0.32522804  0.21329658  4.71368737  0.29032769 -2.05771175 -3.48482794] -- pi: [1.19774095e-02 1.07090682e-02 9.64376393e-01 1.15666041e-02
#  1.10526215e-03 2.65262959e-04]
# recompensa accion 192: -1 -- H: [ 0.3245341   0.21267613  4.71575132  0.28965755 -2.05777579 -3.48484331] -- pi: [1.19455716e-02 1.06813867e-02 9.64469153e-01 1.15361327e-02
#  1.10301876e-03 2.64737429e-04]
# recompensa accion 193: -1 -- H: [ 0.32384559  0.21206048  4.71779922  0.28899264 -2.05783936 -3.48485857] -- pi: [1.19140623e-02 1.06539882e-02 9.64560961e-01 1.15059749e-02
#  1.10079699e-03 2.64216945e-04]
# recompensa accion 194: -1 -- H: [ 0.32316243  0.21144958  4.7198313   0.28833289 -2.05790248 -3.48487372] -- pi: [1.18828760e-02 1.06268681e-02 9.64651833e-01 1.14761254e-02
#  1.09859650e-03 2.63701426e-04]
# recompensa accion 195: -1 -- H: [ 0.32248456  0.21084336  4.72184778  0.28767822 -2.05796515 -3.48488876] -- pi: [1.18520076e-02 1.06000219e-02 9.64741784e-01 1.14465792e-02
#  1.09641696e-03 2.63190794e-04]
# recompensa accion 196: -1 -- H: [ 0.3218119   0.21024175  4.72384886  0.28702857 -2.05802738 -3.4849037 ] -- pi: [1.18214517e-02 1.05734450e-02 9.64830829e-01 1.14173312e-02
#  1.09425803e-03 2.62684974e-04]
# recompensa accion 197: -1 -- H: [ 0.32114438  0.2096447   4.72583476  0.28638386 -2.05808917 -3.48491853] -- pi: [1.17912032e-02 1.05471332e-02 9.64918984e-01 1.13883767e-02
#  1.09211940e-03 2.62183891e-04]
# recompensa accion 198: -1 -- H: [ 0.32048193  0.20905214  4.72780567  0.28574404 -2.05815053 -3.48493326] -- pi: [1.17612572e-02 1.05210821e-02 9.65006262e-01 1.13597109e-02
#  1.09000075e-03 2.61687471e-04]
# recompensa accion 199: -1 -- H: [ 0.31982448  0.20846402  4.72976181  0.28510904 -2.05821146 -3.48494789] -- pi: [1.17316088e-02 1.04952875e-02 9.65092677e-01 1.13313290e-02
#  1.08790178e-03 2.61195643e-04]
# recompensa accion 200: -1 -- H: [ 0.31917197  0.20788027  4.73170335  0.28447879 -2.05827197 -3.48496242] -- pi: [1.17022532e-02 1.04697455e-02 9.65178244e-01 1.13032267e-02
#  1.08582219e-03 2.60708338e-04]

# %% [markdown]
# ### Primeras Acciones:
# Para las primeras acciones, recibes una recompensa de -1. Como no hay recompensas anteriores para calcular una media significativa, la recompensa_media es también -1 (es el único valor en recompensas hasta ese punto).
# El ajuste de H depende de la expresión (reward - recompensa_media). En este caso, reward y recompensa_media son ambos -1, por lo que (reward - recompensa_media) = 0.
# Al tener este valor de 0, el término de ajuste para H se vuelve cero, y por lo tanto, no se realizan cambios en las preferencias para estas primeras dos acciones. Esto explica por qué H y pi permanecen constantes.
#
# ### Acciones Posteriores:
#
# Una vez que ya obtiene una recompensa diferente ya empieza a actualizar las preferencias, ya que la media ya va cambiar y por lo tanto el valor de (reward - recompensa_media) sera diferente de 0.
#
# A partir de este punto el agente le ira reduciendo la preferencia a las acciones de recoger y dejar al pasajero, ya que estas acciones le dan una penalizacion de -10 (que es mucho menor a la recompensa de -1 por moverse a cualquier direccion), por lo que el agente pronto aprendera a no hacer estas acciones y optara por moverse hasta que termine el juego.
